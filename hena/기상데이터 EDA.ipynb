# %%
import pandas as pd
import os

# 파일 경로 설정
base_path = r'C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터'
input_file = os.path.join(base_path, '기상데이터_20150630-20250630_원본.csv')
output_file = os.path.join(base_path, '일별_기상데이터.csv')

# CSV 불러오기
df = pd.read_csv(input_file, encoding='cp949')

# '지역(시)', '지역(군)' 컬럼 삭제 (존재할 때만 삭제)
df = df.drop(columns=['지역(시)', '지역(군)'], errors='ignore')

# '조회일자' 기준으로 그룹화해서 나머지 컬럼 평균 계산
df_daily = df.groupby('조회일자', as_index=False).mean(numeric_only=True)

# 결과 저장
df_daily.to_csv(output_file, index=False, encoding='utf-8-sig')

print("✅ 작업 완료! 결과 파일이 저장되었습니다:", output_file)
# Out:
# ✅ 작업 완료! 결과 파일이 저장되었습니다: C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터\일별_기상데이터.csv

# %%
# -*- coding: utf-8 -*-
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import math

# ---------- 설정 ----------
base_path = r'C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터'
input_file = os.path.join(base_path, '일별_기상데이터.csv')
output_excel = os.path.join(base_path, '일별_기상데이터_EDA.xlsx')
plots_folder = os.path.join(base_path, 'EDA_plots')

os.makedirs(plots_folder, exist_ok=True)

# 분석할 열 목록 (질문에서 주신 열 그대로)
cols = [
    '평균 기온(°C)', '최고 기온(°C)', '최저 기온(°C)', '전년 기온(°C)', '평년 기온(°C)', '평년 최고 기온(°C)', '평년 최저 기온(°C)',
    '평균 강수량(mm)', '전년 강수량(mm)', '평년 강수량(mm)',
    '평균 일조시간(hr)', '전년 일조시간(hr)', '평년 일조시간(hr)',
    '평균 일사량(MJ/㎡)', '전년 일사량(MJ/㎡)', '평년 일사량(MJ/㎡)',
    '평균 습도(%)', '전년 습도(%)', '평년 습도(%)',
    '평균 운량(1/10)', '전년 운량(1/10)', '평년 운량(1/10)',
    '평균 적설량(cm)', '전년 적설량(cm)', '평년 적설량(cm)',
    '평균 순간최대풍속(m/s)', '전년 순간최대풍속(m/s)', '평년 순간최대풍속(m/s)'
]

# ---------- 데이터 불러오기 ----------
# 인코딩 문제 발생 시 encoding='cp949'로 변경하세요.
df = pd.read_csv(input_file, encoding='utf-8-sig')

# '조회일자' 기준 정렬(필요시)
if '조회일자' in df.columns:
    # 조회일자 숫자형(예: 20250630) -> 문자열로 변환 후 날짜 타입으로 바꾸면 편함
    try:
        df['조회일자_dt'] = pd.to_datetime(df['조회일자'].astype(str), format='%Y%m%d')
        df = df.sort_values('조회일자_dt', ascending=False).drop(columns=['조회일자_dt'])
    except Exception:
        # 변환 실패하면 그냥 넘어감
        pass

# 필요한 열만 남기되, 존재하지 않는 열은 제외
available_cols = [c for c in cols if c in df.columns]
if len(available_cols) < 1:
    raise ValueError("분석할 열이 데이터에 없습니다. 파일의 열 이름을 확인해 주세요.")

df_sub = df[ ['조회일자'] + available_cols ].copy()

# 숫자형으로 변환 (문자열 중 쉼표, 공백 등 제거)
for c in available_cols:
    # 쉼표 제거, 공백 제거 후 numeric 변환
    df_sub[c] = pd.to_numeric(df_sub[c].astype(str).str.replace(',', '').str.strip(), errors='coerce')

# ---------- 요약 통계 ----------
summary = df_sub[available_cols].agg(['count','mean','median','min','max','std']).transpose()
summary = summary.rename(columns={'count':'N','median':'median','min':'min','max':'max','std':'std'})

# 결측치 정보
summary['missing_count'] = df_sub.shape[0] - summary['N']

# ---------- 정규성 검사 ----------
# 샘플 수가 5000 이하이면 Shapiro 권장, 그보다 크면 normaltest(D'Agostino) 사용
normality_results = []
n_rows = df_sub.shape[0]
for c in available_cols:
    series = df_sub[c].dropna()
    n = len(series)
    if n < 3:
        normality_results.append({'variable':c, 'test':'none', 'stat':np.nan, 'pvalue':np.nan, 'note':'not enough data'})
        continue
    try:
        if n <= 5000:
            stat, p = stats.shapiro(series)
            normality_results.append({'variable':c, 'test':'shapiro', 'stat':stat, 'pvalue':p,
                                      'note':('normal' if p>0.05 else 'not_normal')})
        else:
            # normaltest requires n>=8
            stat, p = stats.normaltest(series)
            normality_results.append({'variable':c, 'test':'normaltest', 'stat':stat, 'pvalue':p,
                                      'note':('normal' if p>0.05 else 'not_normal')})
    except Exception as e:
        normality_results.append({'variable':c, 'test':'error', 'stat':np.nan, 'pvalue':np.nan, 'note':str(e)})

normality_df = pd.DataFrame(normality_results).set_index('variable')

# ---------- 이상치 탐지 (IQR 방법) ----------
outlier_info = []
iqr_details = {}
for c in available_cols:
    s = df_sub[c].dropna()
    if len(s) == 0:
        outlier_info.append({'variable':c, 'n_outliers':0, 'pct_outliers':0.0, 'lower_bound':np.nan, 'upper_bound':np.nan})
        iqr_details[c] = {'Q1':np.nan,'Q3':np.nan,'IQR':np.nan}
        continue
    Q1 = s.quantile(0.25)
    Q3 = s.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = s[(s < lower) | (s > upper)]
    n_out = outliers.shape[0]
    pct = n_out / df_sub.shape[0] * 100
    outlier_info.append({'variable':c, 'n_outliers':n_out, 'pct_outliers':pct, 'lower_bound':lower, 'upper_bound':upper})
    iqr_details[c] = {'Q1':Q1,'Q3':Q3,'IQR':IQR}

outliers_df = pd.DataFrame(outlier_info).set_index('variable')

# ---------- 상관관계 (Pearson) 및 p-values ----------
vars_for_corr = available_cols.copy()
corr_matrix = df_sub[vars_for_corr].corr(method='pearson')

# p-value matrix
pval_matrix = pd.DataFrame(index=vars_for_corr, columns=vars_for_corr, dtype=float)
for i in range(len(vars_for_corr)):
    for j in range(len(vars_for_corr)):
        x = df_sub[vars_for_corr[i]].dropna()
        y = df_sub[vars_for_corr[j]].dropna()
        # To compute pearsonr, need aligned data: drop NaN pairs
        common = df_sub[[vars_for_corr[i], vars_for_corr[j]]].dropna()
        if common.shape[0] < 3:
            pval_matrix.iloc[i,j] = np.nan
        else:
            try:
                r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
                pval_matrix.iloc[i,j] = p
            except Exception:
                pval_matrix.iloc[i,j] = np.nan

# ---------- 시각화 생성 ----------
# 1) 각 변수별 히스토그램 + 밀도
hist_files = []
for c in available_cols:
    fig, ax = plt.subplots(figsize=(6,4))
    series = df_sub[c].dropna()
    if len(series) > 0:
        ax.hist(series, bins=30, density=True, alpha=0.6)
        try:
            density = stats.gaussian_kde(series)
            xs = np.linspace(series.min(), series.max(), 200)
            ax.plot(xs, density(xs))
        except Exception:
            pass
    ax.set_title(f'Histogram & Density: {c}')
    ax.set_xlabel(c)
    ax.set_ylabel('Density')
    fname = os.path.join(plots_folder, f'hist_{c.replace("/", "_").replace(" ", "_")}.png')
    fig.tight_layout()
    fig.savefig(fname, dpi=150)
    plt.close(fig)
    hist_files.append(fname)


# 2) 박스플롯: 여러 변수 한 장에 (그리드)
n_vars = len(available_cols)
cols_grid = 4
rows_grid = math.ceil(n_vars / cols_grid)
fig, axes = plt.subplots(rows_grid, cols_grid, figsize=(cols_grid*4, rows_grid*3))
axes = axes.flatten()
for i, c in enumerate(available_cols):
    ax = axes[i]
    series = df_sub[c].dropna()
    if len(series) > 0:
        ax.boxplot(series, vert=True, patch_artist=False)
    ax.set_title(c)
    ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
# 빈 축 숨기기
for k in range(n_vars, len(axes)):
    axes[k].axis('off')
fig.tight_layout()
boxplot_file = os.path.join(plots_folder, 'boxplots_all_vars.png')
fig.savefig(boxplot_file, dpi=150)
plt.close(fig)

# 3) 상관행렬 히트맵 (matplotlib만 사용)
# 간단한 heatmap을 직접 그림
fig, ax = plt.subplots(figsize=(max(8, n_vars*0.25), max(6, n_vars*0.25)))
cax = ax.imshow(corr_matrix.values, interpolation='nearest', vmin=-1, vmax=1)
ax.set_xticks(np.arange(len(vars_for_corr)))
ax.set_yticks(np.arange(len(vars_for_corr)))
ax.set_xticklabels(vars_for_corr, rotation=90, fontsize=8)
ax.set_yticklabels(vars_for_corr, fontsize=8)
fig.colorbar(cax, ax=ax, fraction=0.03)
ax.set_title('Pearson Correlation Matrix')
fig.tight_layout()
corr_file = os.path.join(plots_folder, 'correlation_matrix.png')
fig.savefig(corr_file, dpi=150)
plt.close(fig)

# ---------- 엑셀로 저장 (숫자 결과 + 이미지 삽입) ----------
with pd.ExcelWriter(output_excel, engine='xlsxwriter') as writer:
    # 요약 통계
    summary.to_excel(writer, sheet_name='summary_stats')
    # 정규성
    normality_df.to_excel(writer, sheet_name='normality_tests')
    # 이상치
    outliers_df.to_excel(writer, sheet_name='outlier_summary')
    # 상관계수 및 p-value
    corr_matrix.to_excel(writer, sheet_name='correlation_matrix')
    pval_matrix.to_excel(writer, sheet_name='correlation_pvalues')
    # 원본(선택한 열)도 저장
    df_sub.to_excel(writer, sheet_name='data_sample', index=False)

    # 이미지 삽입: 새로운 시트 생성
    workbook  = writer.book
    try:
        worksheet = workbook.add_worksheet('Plots')
    except Exception:
        worksheet = writer.sheets.get('Plots') or workbook.add_worksheet('Plots')

    # 이미지 위치 지정 (행, 열)
    row = 0
    col = 0
    # 먼저 히스토그램들 (한 행에 2개씩)
    for i, fpath in enumerate(hist_files):
        # Excel cell 위치 (row, col) in pixels offset handled by xlsxwriter
        worksheet.insert_image(row, col, fpath, {'x_scale':0.9, 'y_scale':0.9})
        col += 8  # 다음 이미지 위한 열 이동
        if (i+1) % 2 == 0:
            row += 20
            col = 0
    # 박스플롯
    row += 22
    col = 0
    worksheet.insert_image(row, col, boxplot_file, {'x_scale':0.9, 'y_scale':0.9})
    row += 30
    # 상관행렬 이미지
    worksheet.insert_image(row, 0, corr_file, {'x_scale':0.9, 'y_scale':0.9})

# ---------- 콘솔 출력 요약 ----------
print("EDA 완료.")
print(f"결과 엑셀 파일: {output_excel}")
print(f"플롯 이미지 폴더: {plots_folder}")
print("\n요약 통계 (상위 10개 변수):")
print(summary.head(10))
print("\n정규성 테스트 결과 (샘플):")
print(normality_df.head(10))
print("\n이상치 요약 (상위 10개 변수):")
print(outliers_df.sort_values('n_outliers', ascending=False).head(10))
print("\n상관계수(일부):")
print(corr_matrix.iloc[:5,:5])

# 끝
# Out:
# C:\Users\henaj\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:125: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 13217 (\N{SQUARE M SQUARED}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 13217 (\N{SQUARE M SQUARED}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 54413 (\N{HANGUL SYLLABLE PUNG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:148: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 54413 (\N{HANGUL SYLLABLE PUNG}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:149: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 13217 (\N{SQUARE M SQUARED}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 54413 (\N{HANGUL SYLLABLE PUNG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:169: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 13217 (\N{SQUARE M SQUARED}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 54413 (\N{HANGUL SYLLABLE PUNG}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:171: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 13217 (\N{SQUARE M SQUARED}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 54413 (\N{HANGUL SYLLABLE PUNG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:184: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 13217 (\N{SQUARE M SQUARED}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 54413 (\N{HANGUL SYLLABLE PUNG}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_13684\93539023.py:186: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from font(s) DejaVu Sans.
#   fig.savefig(corr_file, dpi=150)
# EDA 완료.
# 결과 엑셀 파일: C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터\일별_기상데이터_EDA.xlsx
# 플롯 이미지 폴더: C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터\EDA_plots
#
# 요약 통계 (상위 10개 변수):
#                    N       mean     median        min         max       std  \
# 평균 기온(°C)     3652.0  13.398069  14.111268 -99.000000   29.888235  9.765127
# 최고 기온(°C)     3652.0  18.845144  20.236050  -7.229412   36.364706  9.369548
# 최저 기온(°C)     3652.0   8.847502   8.954478 -15.794030   26.304225  9.875944
# 전년 기온(°C)     3652.0  13.257304  13.931102 -99.000000   29.888235  9.432100
# 평년 기온(°C)     3652.0  12.088742  12.817647  -1.268657   25.350746  8.597256
# 평년 최고 기온(°C)  3652.0  17.332790  18.764464   3.597059   29.841791  8.374253
# 평년 최저 기온(°C)  3652.0   7.576064   7.246479  -5.788060   22.002817  8.977317
# 평균 강수량(mm)    3652.0   3.594690   0.205926   0.000000  108.938028  9.043281
# 전년 강수량(mm)    3652.0   3.555772   0.194242   0.000000  104.902985  8.857365
# 평년 강수량(mm)    3652.0   3.517436   2.281690   0.354412   13.552239  2.956121
#
#               missing_count
# 평균 기온(°C)               0.0
# 최고 기온(°C)               0.0
# 최저 기온(°C)               0.0
# 전년 기온(°C)               0.0
# 평년 기온(°C)               0.0
# 평년 최고 기온(°C)            0.0
# 평년 최저 기온(°C)            0.0
# 평균 강수량(mm)              0.0
# 전년 강수량(mm)              0.0
# 평년 강수량(mm)              0.0
#
# 정규성 테스트 결과 (샘플):
#                  test      stat        pvalue        note
# variable
# 평균 기온(°C)     shapiro  0.929049  1.529145e-38  not_normal
# 최고 기온(°C)     shapiro  0.960476  1.864414e-30  not_normal
# 최저 기온(°C)     shapiro  0.960658  2.141119e-30  not_normal
# 전년 기온(°C)     shapiro  0.944835  6.090726e-35  not_normal
# 평년 기온(°C)     shapiro  0.921583  5.033699e-40  not_normal
# 평년 최고 기온(°C)  shapiro  0.913117  1.420036e-41  not_normal
# 평년 최저 기온(°C)  shapiro  0.923433  1.143814e-39  not_normal
# 평균 강수량(mm)    shapiro  0.446495  7.721945e-75  not_normal
# 전년 강수량(mm)    shapiro  0.452161  1.259526e-74  not_normal
# 평년 강수량(mm)    shapiro  0.836059  7.472259e-52  not_normal
#
# 이상치 요약 (상위 10개 변수):
#                 n_outliers  pct_outliers  lower_bound  upper_bound
# variable
# 전년 강수량(mm)             595     16.292442    -3.221127     5.376388
# 평균 강수량(mm)             588     16.100767    -3.269871     5.461053
# 평균 적설량(cm)             510     13.964951     0.000000     0.000000
# 전년 적설량(cm)             486     13.307777     0.000000     0.000000
# 전년 순간최대풍속(m/s)         107      2.929901     2.359965    13.074568
# 평균 순간최대풍속(m/s)          87      2.382256     2.217966    13.375691
# 평년 강수량(mm)              84      2.300110    -4.382429    10.802087
# 평균 일사량(MJ/㎡)            68      1.861993    -2.435822    13.441118
# 전년 일사량(MJ/㎡)            41      1.122673    -2.167943    12.430410
# 전년 습도(%)                 2      0.054765    29.973460   107.904159
#
# 상관계수(일부):
#            평균 기온(°C)  최고 기온(°C)  최저 기온(°C)  전년 기온(°C)  평년 기온(°C)
# 평균 기온(°C)   1.000000   0.959477   0.956621   0.881557   0.930497
# 최고 기온(°C)   0.959477   1.000000   0.949154   0.885373   0.936548
# 최저 기온(°C)   0.956621   0.949154   1.000000   0.903740   0.954281
# 전년 기온(°C)   0.881557   0.885373   0.903740   1.000000   0.943794
# 평년 기온(°C)   0.930497   0.936548   0.954281   0.943794   1.000000

# %%
# 위에서 EDA를 다해 해서 결과물을 엑셀파일과 폴더로 다 EXPORT해서 저장했지만, BOX PLOT들이 깨져 나왔으므로
# 깨지지 않게 박스플롯 그리는 부분만 코딩을 좀더 추가해서 처음부터 다시 EDA해 엑셀파일과 폴더 같은 곳으로 다시 EXPORT합니다.

# -*- coding: utf-8 -*-
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import math

# ---------- 설정 ----------
base_path = r'C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터'
input_file = os.path.join(base_path, '일별_기상데이터.csv')
output_excel = os.path.join(base_path, '일별_기상데이터_EDA.xlsx')
plots_folder = os.path.join(base_path, 'EDA_plots')

os.makedirs(plots_folder, exist_ok=True)

# 분석할 열 목록 (질문에서 주신 열 그대로)
cols = [
    '평균 기온(°C)', '최고 기온(°C)', '최저 기온(°C)', '전년 기온(°C)', '평년 기온(°C)', '평년 최고 기온(°C)', '평년 최저 기온(°C)',
    '평균 강수량(mm)', '전년 강수량(mm)', '평년 강수량(mm)',
    '평균 일조시간(hr)', '전년 일조시간(hr)', '평년 일조시간(hr)',
    '평균 일사량(MJ/㎡)', '전년 일사량(MJ/㎡)', '평년 일사량(MJ/㎡)',
    '평균 습도(%)', '전년 습도(%)', '평년 습도(%)',
    '평균 운량(1/10)', '전년 운량(1/10)', '평년 운량(1/10)',
    '평균 적설량(cm)', '전년 적설량(cm)', '평년 적설량(cm)',
    '평균 순간최대풍속(m/s)', '전년 순간최대풍속(m/s)', '평년 순간최대풍속(m/s)'
]

# ---------- 데이터 불러오기 ----------
# 인코딩 문제 발생 시 encoding='cp949'로 변경하세요.
df = pd.read_csv(input_file, encoding='utf-8-sig')

# '조회일자' 기준 정렬(필요시)
if '조회일자' in df.columns:
    # 조회일자 숫자형(예: 20250630) -> 문자열로 변환 후 날짜 타입으로 바꾸면 편함
    try:
        df['조회일자_dt'] = pd.to_datetime(df['조회일자'].astype(str), format='%Y%m%d')
        df = df.sort_values('조회일자_dt', ascending=False).drop(columns=['조회일자_dt'])
    except Exception:
        # 변환 실패하면 그냥 넘어감
        pass

# 필요한 열만 남기되, 존재하지 않는 열은 제외
available_cols = [c for c in cols if c in df.columns]
if len(available_cols) < 1:
    raise ValueError("분석할 열이 데이터에 없습니다. 파일의 열 이름을 확인해 주세요.")

df_sub = df[ ['조회일자'] + available_cols ].copy()

# 숫자형으로 변환 (문자열 중 쉼표, 공백 등 제거)
for c in available_cols:
    # 쉼표 제거, 공백 제거 후 numeric 변환
    df_sub[c] = pd.to_numeric(df_sub[c].astype(str).str.replace(',', '').str.strip(), errors='coerce')

# ---------- 요약 통계 ----------
summary = df_sub[available_cols].agg(['count','mean','median','min','max','std']).transpose()
summary = summary.rename(columns={'count':'N','median':'median','min':'min','max':'max','std':'std'})

# 결측치 정보
summary['missing_count'] = df_sub.shape[0] - summary['N']

# ---------- 정규성 검사 ----------
# 샘플 수가 5000 이하이면 Shapiro 권장, 그보다 크면 normaltest(D'Agostino) 사용
normality_results = []
n_rows = df_sub.shape[0]
for c in available_cols:
    series = df_sub[c].dropna()
    n = len(series)
    if n < 3:
        normality_results.append({'variable':c, 'test':'none', 'stat':np.nan, 'pvalue':np.nan, 'note':'not enough data'})
        continue
    try:
        if n <= 5000:
            stat, p = stats.shapiro(series)
            normality_results.append({'variable':c, 'test':'shapiro', 'stat':stat, 'pvalue':p,
                                      'note':('normal' if p>0.05 else 'not_normal')})
        else:
            # normaltest requires n>=8
            stat, p = stats.normaltest(series)
            normality_results.append({'variable':c, 'test':'normaltest', 'stat':stat, 'pvalue':p,
                                      'note':('normal' if p>0.05 else 'not_normal')})
    except Exception as e:
        normality_results.append({'variable':c, 'test':'error', 'stat':np.nan, 'pvalue':np.nan, 'note':str(e)})

normality_df = pd.DataFrame(normality_results).set_index('variable')

# ---------- 이상치 탐지 (IQR 방법) ----------
outlier_info = []
iqr_details = {}
for c in available_cols:
    s = df_sub[c].dropna()
    if len(s) == 0:
        outlier_info.append({'variable':c, 'n_outliers':0, 'pct_outliers':0.0, 'lower_bound':np.nan, 'upper_bound':np.nan})
        iqr_details[c] = {'Q1':np.nan,'Q3':np.nan,'IQR':np.nan}
        continue
    Q1 = s.quantile(0.25)
    Q3 = s.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = s[(s < lower) | (s > upper)]
    n_out = outliers.shape[0]
    pct = n_out / df_sub.shape[0] * 100
    outlier_info.append({'variable':c, 'n_outliers':n_out, 'pct_outliers':pct, 'lower_bound':lower, 'upper_bound':upper})
    iqr_details[c] = {'Q1':Q1,'Q3':Q3,'IQR':IQR}

outliers_df = pd.DataFrame(outlier_info).set_index('variable')

# ---------- 상관관계 (Pearson) 및 p-values ----------
vars_for_corr = available_cols.copy()
corr_matrix = df_sub[vars_for_corr].corr(method='pearson')

# p-value matrix
pval_matrix = pd.DataFrame(index=vars_for_corr, columns=vars_for_corr, dtype=float)
for i in range(len(vars_for_corr)):
    for j in range(len(vars_for_corr)):
        x = df_sub[vars_for_corr[i]].dropna()
        y = df_sub[vars_for_corr[j]].dropna()
        # To compute pearsonr, need aligned data: drop NaN pairs
        common = df_sub[[vars_for_corr[i], vars_for_corr[j]]].dropna()
        if common.shape[0] < 3:
            pval_matrix.iloc[i,j] = np.nan
        else:
            try:
                r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
                pval_matrix.iloc[i,j] = p
            except Exception:
                pval_matrix.iloc[i,j] = np.nan

# ---------- 시각화 생성 ----------
# 1) 각 변수별 히스토그램 + 밀도 - 한글 폰트 적용
hist_files = []
for c in available_cols:
    fig, ax = plt.subplots(figsize=(8,5))
    series = df_sub[c].dropna()
    if len(series) > 0:
        ax.hist(series, bins=30, density=True, alpha=0.6, color='skyblue', edgecolor='black')
        try:
            density = stats.gaussian_kde(series)
            xs = np.linspace(series.min(), series.max(), 200)
            ax.plot(xs, density(xs), color='red', linewidth=2)
        except Exception:
            pass
    ax.set_title(f'Histogram & Density: {c}', fontsize=12, pad=15)
    ax.set_xlabel(c, fontsize=10)
    ax.set_ylabel('Density', fontsize=10)
    ax.grid(True, alpha=0.3)
    
    fname = os.path.join(plots_folder, f'hist_{c.replace("/", "_").replace(" ", "_").replace("(", "").replace(")", "").replace("°", "deg").replace("㎡", "m2")}.png')
    fig.tight_layout()
    fig.savefig(fname, dpi=150, bbox_inches='tight')
    plt.close(fig)
    hist_files.append(fname)

# 2) 박스플롯: 여러 변수 한 장에 (그리드)
fig, ax = plt.subplots(figsize=(max(8, len(available_cols)*0.25), 
                                max(6, len(available_cols)*0.25)))
df_sub[available_cols].boxplot(ax=ax, rot=90)  # rot=90 → x축 레이블 회전
ax.set_title('Boxplots of Selected Variables')
fig.tight_layout()

boxplot_file = os.path.join(plots_folder, 'boxplots_all_vars.png')
fig.savefig(boxplot_file, dpi=150)
plt.close(fig)

# 3) 상관행렬 히트맵 (matplotlib만 사용)
# 간단한 heatmap을 직접 그림
fig, ax = plt.subplots(figsize=(max(8, len(available_cols)*0.25), max(6, len(available_cols)*0.25)))
cax = ax.imshow(corr_matrix.values, interpolation='nearest', vmin=-1, vmax=1)
ax.set_xticks(np.arange(len(vars_for_corr)))
ax.set_yticks(np.arange(len(vars_for_corr)))
ax.set_xticklabels(vars_for_corr, rotation=90, fontsize=8)
ax.set_yticklabels(vars_for_corr, fontsize=8)
fig.colorbar(cax, ax=ax, fraction=0.03)
ax.set_title('Pearson Correlation Matrix')
fig.tight_layout()
corr_file = os.path.join(plots_folder, 'correlation_matrix.png')
fig.savefig(corr_file, dpi=150)
plt.close(fig)

# ---------- 엑셀로 저장 (숫자 결과 + 이미지 삽입) ----------
with pd.ExcelWriter(output_excel, engine='xlsxwriter') as writer:
    # 요약 통계
    summary.to_excel(writer, sheet_name='summary_stats')
    # 정규성
    normality_df.to_excel(writer, sheet_name='normality_tests')
    # 이상치
    outliers_df.to_excel(writer, sheet_name='outlier_summary')
    # 상관계수 및 p-value
    corr_matrix.to_excel(writer, sheet_name='correlation_matrix')
    pval_matrix.to_excel(writer, sheet_name='correlation_pvalues')
    # 원본(선택한 열)도 저장
    df_sub.to_excel(writer, sheet_name='data_sample', index=False)

    # 이미지 삽입: 새로운 시트 생성
    workbook  = writer.book
    try:
        worksheet = workbook.add_worksheet('Plots')
    except Exception:
        worksheet = writer.sheets.get('Plots') or workbook.add_worksheet('Plots')

    # 이미지 위치 지정 (행, 열)
    row = 0
    col = 0
    # 먼저 히스토그램들 (한 행에 2개씩)
    for i, fpath in enumerate(hist_files):
        # Excel cell 위치 (row, col) in pixels offset handled by xlsxwriter
        worksheet.insert_image(row, col, fpath, {'x_scale':0.9, 'y_scale':0.9})
        col += 8  # 다음 이미지 위한 열 이동
        if (i+1) % 2 == 0:
            row += 20
            col = 0
    # 박스플롯
    row += 22
    col = 0
    worksheet.insert_image(row, col, boxplot_file, {'x_scale':0.9, 'y_scale':0.9})
    row += 30
    # 상관행렬 이미지
    worksheet.insert_image(row, 0, corr_file, {'x_scale':0.9, 'y_scale':0.9})

# ---------- 콘솔 출력 요약 ----------
print("EDA 완료.")
print(f"결과 엑셀 파일: {output_excel}")
print(f"플롯 이미지 폴더: {plots_folder}")
print("\n요약 통계 (모든 변수):")
print(summary)
print("\n정규성 테스트 결과:")
print(normality_df)
print("\n이상치 요약 (모든 변수):")
print(outliers_df.sort_values('n_outliers', ascending=False))
print("\n상관계수:")
print(corr_matrix)

# 끝
# Out:
# C:\Users\henaj\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:128: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 13217 (\N{SQUARE M SQUARED}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 13217 (\N{SQUARE M SQUARED}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 54413 (\N{HANGUL SYLLABLE PUNG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:153: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 54413 (\N{HANGUL SYLLABLE PUNG}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:154: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from font(s) DejaVu Sans.
#   fig.savefig(fname, dpi=150, bbox_inches='tight')
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 13217 (\N{SQUARE M SQUARED}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 54413 (\N{HANGUL SYLLABLE PUNG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:163: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 51312 (\N{HANGUL SYLLABLE JO}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 49324 (\N{HANGUL SYLLABLE SA}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 13217 (\N{SQUARE M SQUARED}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 50868 (\N{HANGUL SYLLABLE UN}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 51201 (\N{HANGUL SYLLABLE JEOG}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 49444 (\N{HANGUL SYLLABLE SEOL}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 45824 (\N{HANGUL SYLLABLE DAE}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 54413 (\N{HANGUL SYLLABLE PUNG}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:166: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from font(s) DejaVu Sans.
#   fig.savefig(boxplot_file, dpi=150)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:179: UserWarning: Glyph 54217 (\N{HANGUL SYLLABLE PYEONG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:179: UserWarning: Glyph 44512 (\N{HANGUL SYLLABLE GYUN}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:179: UserWarning: Glyph 44592 (\N{HANGUL SYLLABLE GI}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:179: UserWarning: Glyph 50728 (\N{HANGUL SYLLABLE ON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:179: UserWarning: Glyph 52572 (\N{HANGUL SYLLABLE COE}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:179: UserWarning: Glyph 44256 (\N{HANGUL SYLLABLE GO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:179: UserWarning: Glyph 51200 (\N{HANGUL SYLLABLE JEO}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:179: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:179: UserWarning: Glyph 45380 (\N{HANGUL SYLLABLE NYEON}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# C:\Users\henaj\AppData\Local\Temp\ipykernel_37308\3458932083.py:179: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from font(s) DejaVu Sans.
#   fig.tight_layout()
# ...
# 전년 습도(%)        3652.0  68.875950  70.097059   0.000000   95.585075
# 평년 습도(%)        3652.0  65.964239  64.357463  55.500000   79.695522
# 평균 운량(1/10)     3652.0   3.966012   3.312687   0.000000    9.964179
# 전년 운량(1/10)     3652.0   3.707365   2.845588   0.000000    9.918310
# 평년 운량(1/10)     3652.0   3.133896   3.538235   0.000000    7.404478
# 평균 적설량(cm)      3652.0   0.029826   0.000000   0.000000    4.507042
# 전년 적설량(cm)      3652.0   0.025361   0.000000   0.000000    4.507042
# 평년 적설량(cm)      3652.0   0.000000   0.000000   0.000000    0.000000
# 평균 순간최대풍속(m/s)  3652.0   7.995145   7.527941   3.719718   19.513433
# 전년 순간최대풍속(m/s)  3652.0   7.916840   7.439437   0.378082   19.513433
# 평년 순간최대풍속(m/s)  3652.0   2.053504   2.026668   1.573239    2.631343
#
#                       std  missing_count
# 평균 기온(°C)        9.765127            0.0
# 최고 기온(°C)        9.369548            0.0
# 최저 기온(°C)        9.875944            0.0
# 전년 기온(°C)        9.432100            0.0
# 평년 기온(°C)        8.597256            0.0
# 평년 최고 기온(°C)     8.374253            0.0
# 평년 최저 기온(°C)     8.977317            0.0
# 평균 강수량(mm)       9.043281            0.0
# 전년 강수량(mm)       8.857365            0.0
# 평년 강수량(mm)       2.956121            0.0
# 평균 일조시간(hr)      3.301193            0.0
# 전년 일조시간(hr)      3.304887            0.0
# 평년 일조시간(hr)      0.808785            0.0
# 평균 일사량(MJ/㎡)     2.939695            0.0
# 전년 일사량(MJ/㎡)     2.621508            0.0
# 평년 일사량(MJ/㎡)     0.000000            0.0
# 평균 습도(%)        12.718799            0.0
# 전년 습도(%)        12.823115            0.0
# 평년 습도(%)         6.601598            0.0
# 평균 운량(1/10)      2.740791            0.0
# 전년 운량(1/10)      2.644454            0.0
# 평년 운량(1/10)      1.854601            0.0
# 평균 적설량(cm)       0.149680            0.0
# 전년 적설량(cm)       0.136234            0.0
# 평년 적설량(cm)       0.000000            0.0
# 평균 순간최대풍속(m/s)   2.207858            0.0
# 전년 순간최대풍속(m/s)   2.193919            0.0
# 평년 순간최대풍속(m/s)   0.248243            0.0
#
# 정규성 테스트 결과:
#                    test      stat        pvalue        note
# variable
# 평균 기온(°C)       shapiro  0.929049  1.529145e-38  not_normal
# 최고 기온(°C)       shapiro  0.960476  1.864414e-30  not_normal
# 최저 기온(°C)       shapiro  0.960658  2.141119e-30  not_normal
# 전년 기온(°C)       shapiro  0.944835  6.090726e-35  not_normal
# 평년 기온(°C)       shapiro  0.921583  5.033699e-40  not_normal
# 평년 최고 기온(°C)    shapiro  0.913117  1.420036e-41  not_normal
# 평년 최저 기온(°C)    shapiro  0.923433  1.143814e-39  not_normal
# 평균 강수량(mm)      shapiro  0.446495  7.721945e-75  not_normal
# 전년 강수량(mm)      shapiro  0.452161  1.259526e-74  not_normal
# 평년 강수량(mm)      shapiro  0.836059  7.472259e-52  not_normal
# 평균 일조시간(hr)     shapiro  0.960027  1.330713e-30  not_normal
# 전년 일조시간(hr)     shapiro  0.959819  1.138671e-30  not_normal
# 평년 일조시간(hr)     shapiro  0.984711  1.896658e-19  not_normal
# 평균 일사량(MJ/㎡)    shapiro  0.955224  4.264029e-32  not_normal
# 전년 일사량(MJ/㎡)    shapiro  0.964203  3.475743e-29  not_normal
# 평년 일사량(MJ/㎡)    shapiro  1.000000  1.000000e+00      normal
# 평균 습도(%)        shapiro  0.980225  3.587425e-22  not_normal
# 전년 습도(%)        shapiro  0.982789  1.118298e-20  not_normal
# 평년 습도(%)        shapiro  0.915239  3.379435e-41  not_normal
# 평균 운량(1/10)     shapiro  0.928503  1.179730e-38  not_normal
# 전년 운량(1/10)     shapiro  0.922061  6.212012e-40  not_normal
# 평년 운량(1/10)     shapiro  0.879566  1.030207e-46  not_normal
# 평균 적설량(cm)      shapiro  0.195570  9.048500e-83  not_normal
# 전년 적설량(cm)      shapiro  0.178647  3.183723e-83  not_normal
# 평년 적설량(cm)      shapiro  1.000000  1.000000e+00      normal
# 평균 순간최대풍속(m/s)  shapiro  0.935186  3.162153e-37  not_normal
# 전년 순간최대풍속(m/s)  shapiro  0.931239  4.395592e-38  not_normal
# 평년 순간최대풍속(m/s)  shapiro  0.935657  4.027226e-37  not_normal
#
# 이상치 요약 (모든 변수):
#                 n_outliers  pct_outliers  lower_bound  upper_bound
# variable
# 전년 강수량(mm)             595     16.292442    -3.221127     5.376388
# 평균 강수량(mm)             588     16.100767    -3.269871     5.461053
# 평균 적설량(cm)             510     13.964951     0.000000     0.000000
# 전년 적설량(cm)             486     13.307777     0.000000     0.000000
# 전년 순간최대풍속(m/s)         107      2.929901     2.359965    13.074568
# 평균 순간최대풍속(m/s)          87      2.382256     2.217966    13.375691
# 평년 강수량(mm)              84      2.300110    -4.382429    10.802087
# 평균 일사량(MJ/㎡)            68      1.861993    -2.435822    13.441118
# 전년 일사량(MJ/㎡)            41      1.122673    -2.167943    12.430410
# 전년 습도(%)                 2      0.054765    29.973460   107.904159
# 평균 습도(%)                 2      0.054765    30.430750   108.683961
# 평균 기온(°C)                2      0.054765   -19.032142    46.098565
# 전년 기온(°C)                1      0.027382   -18.666519    45.445179
# 평년 일조시간(hr)              0      0.000000     3.428499     8.132895
# 전년 일조시간(hr)              0      0.000000    -3.876471    16.294118
# 최고 기온(°C)                0      0.000000   -13.175735    50.794853
# 평년 일사량(MJ/㎡)             0      0.000000     0.000000     0.000000
# 평균 일조시간(hr)              0      0.000000    -3.770572    16.264108
# 평년 최저 기온(°C)             0      0.000000   -26.437744    41.257273
# 평년 습도(%)                 0      0.000000    43.168877    89.111027
# 평균 운량(1/10)              0      0.000000    -5.298979    13.145358
# 전년 운량(1/10)              0      0.000000    -4.796093    12.104522
# 평년 운량(1/10)              0      0.000000    -3.828180     9.606170
# 평년 최고 기온(°C)             0      0.000000   -15.011589    49.138718
# 평년 기온(°C)                0      0.000000   -20.895651    44.693861
# 평년 적설량(cm)               0      0.000000     0.000000     0.000000
# 최저 기온(°C)                0      0.000000   -25.614692    43.674487
# 평년 순간최대풍속(m/s)           0      0.000000     1.154225     2.962676
#
# 상관계수:
#                 평균 기온(°C)  최고 기온(°C)  최저 기온(°C)  전년 기온(°C)  평년 기온(°C)  \
# 평균 기온(°C)        1.000000   0.959477   0.956621   0.881557   0.930497
# 최고 기온(°C)        0.959477   1.000000   0.949154   0.885373   0.936548
# 최저 기온(°C)        0.956621   0.949154   1.000000   0.903740   0.954281
# 전년 기온(°C)        0.881557   0.885373   0.903740   1.000000   0.943794
# 평년 기온(°C)        0.930497   0.936548   0.954281   0.943794   1.000000
# 평년 최고 기온(°C)     0.928521   0.938247   0.947668   0.941865   0.997426
# 평년 최저 기온(°C)     0.927340   0.929184   0.956415   0.940148   0.997160
# 평균 강수량(mm)       0.239655   0.168174   0.308757   0.237224   0.252585
# 전년 강수량(mm)       0.233663   0.224985   0.249687   0.244295   0.253297
# 평년 강수량(mm)       0.770109   0.752215   0.814456   0.780844   0.826914
# 평균 일조시간(hr)      0.014664   0.125938  -0.108094   0.019986   0.026713
# 전년 일조시간(hr)      0.032807   0.048661   0.017238   0.007152   0.021611
# 평년 일조시간(hr)      0.077388   0.128158   0.017502   0.088101   0.077188
# 평균 일사량(MJ/㎡)     0.391547   0.479634   0.303683   0.391391   0.408897
# 전년 일사량(MJ/㎡)     0.404045   0.428905   0.390166   0.406076   0.420926
# 평년 일사량(MJ/㎡)          NaN        NaN        NaN        NaN        NaN
# 평균 습도(%)         0.594862   0.506108   0.657232   0.500409   0.533049
# 전년 습도(%)         0.473194   0.459865   0.504084   0.577203   0.516049
# 평년 습도(%)         0.774409   0.750485   0.830588   0.780132   0.839141
# 평균 운량(1/10)      0.227291   0.148442   0.292047   0.194722   0.204854
# 전년 운량(1/10)      0.187980   0.176537   0.203764   0.223967   0.203847
# 평년 운량(1/10)      0.273664   0.262432   0.281149   0.292544   0.303116
# 평균 적설량(cm)      -0.320763  -0.352280  -0.304638  -0.261900  -0.263363
# 전년 적설량(cm)      -0.246643  -0.261410  -0.239434  -0.313383  -0.248099
# 평년 적설량(cm)            NaN        NaN        NaN        NaN        NaN
# 평균 순간최대풍속(m/s)  -0.243551  -0.296586  -0.231997  -0.185372  -0.212479
# 전년 순간최대풍속(m/s)  -0.209192  -0.205499  -0.218760  -0.245609  -0.210279
# 평년 순간최대풍속(m/s)  -0.663450  -0.656455  -0.704731  -0.667414  -0.722177
#
#                 평년 최고 기온(°C)  평년 최저 기온(°C)  평균 강수량(mm)  전년 강수량(mm)  \
# 평균 기온(°C)           0.928521      0.927340    0.239655    0.233663
# 최고 기온(°C)           0.938247      0.929184    0.168174    0.224985
# 최저 기온(°C)           0.947668      0.956415    0.308757    0.249687
# 전년 기온(°C)           0.941865      0.940148    0.237224    0.244295
# 평년 기온(°C)           0.997426      0.997160    0.252585    0.253297
# 평년 최고 기온(°C)        1.000000      0.989477    0.243058    0.243566
# 평년 최저 기온(°C)        0.989477      1.000000    0.260535    0.261474
# 평균 강수량(mm)          0.243058      0.260535    1.000000    0.092697
# 전년 강수량(mm)          0.243566      0.261474    0.092697    1.000000
# 평년 강수량(mm)          0.792736      0.854370    0.295670    0.297183
# 평균 일조시간(hr)         0.039436      0.010478   -0.513479   -0.031860
# 전년 일조시간(hr)         0.035492      0.004474   -0.043956   -0.516258
# 평년 일조시간(hr)         0.134558      0.011005   -0.111109   -0.110098
# 평균 일사량(MJ/㎡)        0.422896      0.384366   -0.308489    0.079908
# 전년 일사량(MJ/㎡)        0.436133      0.394990    0.067747   -0.325159
# 평년 일사량(MJ/㎡)             NaN           NaN         NaN         NaN
# 평균 습도(%)            0.519507      0.548798    0.494907    0.158949
# 전년 습도(%)            0.501530      0.532816    0.152296    0.498023
# 평년 습도(%)            0.809170      0.872524    0.266571    0.263495
# 평균 운량(1/10)         0.198676      0.209653    0.385031    0.094136
# 전년 운량(1/10)         0.196788      0.209156    0.103695    0.374305
# 평년 운량(1/10)         0.291353      0.313985    0.090247    0.066411
# 평균 적설량(cm)         -0.273153     -0.252305   -0.051554   -0.050433
# 전년 적설량(cm)         -0.257611     -0.237106   -0.052203   -0.047986
# 평년 적설량(cm)               NaN           NaN         NaN         NaN
# 평균 순간최대풍속(m/s)     -0.208764     -0.219790    0.208985   -0.041754
# 전년 순간최대풍속(m/s)     -0.206712     -0.216995   -0.051958    0.206052
# 평년 순간최대풍속(m/s)     -0.717829     -0.735511   -0.167112   -0.163567
#
#                 평년 강수량(mm)  ...  평년 습도(%)  평균 운량(1/10)  전년 운량(1/10)  \
# 평균 기온(°C)         0.770109  ...  0.774409     0.227291     0.187980
# 최고 기온(°C)         0.752215  ...  0.750485     0.148442     0.176537
# 최저 기온(°C)         0.814456  ...  0.830588     0.292047     0.203764
# 전년 기온(°C)         0.780844  ...  0.780132     0.194722     0.223967
# 평년 기온(°C)         0.826914  ...  0.839141     0.204854     0.203847
# 평년 최고 기온(°C)      0.792736  ...  0.809170     0.198676     0.196788
# 평년 최저 기온(°C)      0.854370  ...  0.872524     0.209653     0.209156
# 평균 강수량(mm)        0.295670  ...  0.266571     0.385031     0.103695
# 전년 강수량(mm)        0.297183  ...  0.263495     0.094136     0.374305
# 평년 강수량(mm)        1.000000  ...  0.852110     0.208860     0.214776
# 평균 일조시간(hr)      -0.061801  ... -0.106293    -0.620585    -0.054902
# 전년 일조시간(hr)      -0.073984  ... -0.108129    -0.019137    -0.600156
# 평년 일조시간(hr)      -0.329949  ... -0.415659    -0.057600    -0.064778
# 평균 일사량(MJ/㎡)      0.255800  ...  0.115275    -0.209833     0.197802
# 전년 일사량(MJ/㎡)      0.260123  ...  0.124029     0.182570    -0.212267
# 평년 일사량(MJ/㎡)           NaN  ...       NaN          NaN          NaN
# 평균 습도(%)          0.499395  ...  0.593510     0.480406     0.176657
# 전년 습도(%)          0.489149  ...  0.577306     0.112214     0.455227
# 평년 습도(%)          0.852110  ...  1.000000     0.191608     0.185323
# 평균 운량(1/10)       0.208860  ...  0.191608     1.000000     0.372731
# 전년 운량(1/10)       0.214776  ...  0.185323     0.372731     1.000000
# 평년 운량(1/10)       0.358343  ...  0.395919    -0.262038    -0.356700
# 평균 적설량(cm)       -0.169809  ... -0.171472    -0.039149    -0.017362
# 전년 적설량(cm)       -0.161352  ... -0.152337    -0.051373    -0.056862
# 평년 적설량(cm)             NaN  ...       NaN          NaN          NaN
# 평균 순간최대풍속(m/s)   -0.151686  ... -0.263635    -0.024399    -0.018583
# 전년 순간최대풍속(m/s)   -0.152399  ... -0.254631    -0.071971    -0.057027
# 평년 순간최대풍속(m/s)   -0.511528  ... -0.810331    -0.182612    -0.184706
#
#                 평년 운량(1/10)  평균 적설량(cm)  전년 적설량(cm)  평년 적설량(cm)  \
# 평균 기온(°C)          0.273664   -0.320763   -0.246643         NaN
# 최고 기온(°C)          0.262432   -0.352280   -0.261410         NaN
# 최저 기온(°C)          0.281149   -0.304638   -0.239434         NaN
# 전년 기온(°C)          0.292544   -0.261900   -0.313383         NaN
# 평년 기온(°C)          0.303116   -0.263363   -0.248099         NaN
# 평년 최고 기온(°C)       0.291353   -0.273153   -0.257611         NaN
# 평년 최저 기온(°C)       0.313985   -0.252305   -0.237106         NaN
# 평균 강수량(mm)         0.090247   -0.051554   -0.052203         NaN
# 전년 강수량(mm)         0.066411   -0.050433   -0.047986         NaN
# 평년 강수량(mm)         0.358343   -0.169809   -0.161352         NaN
# 평균 일조시간(hr)       -0.004509   -0.014755   -0.022899         NaN
# 전년 일조시간(hr)        0.011664   -0.033627   -0.012085         NaN
# 평년 일조시간(hr)       -0.115322   -0.098814   -0.103193         NaN
# 평균 일사량(MJ/㎡)      -0.166124   -0.100603   -0.119313         NaN
# 전년 일사량(MJ/㎡)      -0.089752   -0.120448   -0.130315         NaN
# 평년 일사량(MJ/㎡)            NaN         NaN         NaN         NaN
# 평균 습도(%)           0.145762   -0.147497   -0.117654         NaN
# 전년 습도(%)           0.154117   -0.098683   -0.141119         NaN
# 평년 습도(%)           0.395919   -0.171472   -0.152337         NaN
# 평균 운량(1/10)       -0.262038   -0.039149   -0.051373         NaN
# 전년 운량(1/10)       -0.356700   -0.017362   -0.056862         NaN
# 평년 운량(1/10)        1.000000   -0.115026   -0.069092         NaN
# 평균 적설량(cm)        -0.115026    1.000000    0.214054         NaN
# 전년 적설량(cm)        -0.069092    0.214054    1.000000         NaN
# 평년 적설량(cm)              NaN         NaN         NaN         NaN
# 평균 순간최대풍속(m/s)    -0.073070    0.234602    0.089659         NaN
# 전년 순간최대풍속(m/s)    -0.037684    0.077238    0.231722         NaN
# 평년 순간최대풍속(m/s)    -0.092788    0.148828    0.146065         NaN
#
#                 평균 순간최대풍속(m/s)  전년 순간최대풍속(m/s)  평년 순간최대풍속(m/s)
# 평균 기온(°C)            -0.243551       -0.209192       -0.663450
# 최고 기온(°C)            -0.296586       -0.205499       -0.656455
# 최저 기온(°C)            -0.231997       -0.218760       -0.704731
# 전년 기온(°C)            -0.185372       -0.245609       -0.667414
# 평년 기온(°C)            -0.212479       -0.210279       -0.722177
# 평년 최고 기온(°C)         -0.208764       -0.206712       -0.717829
# 평년 최저 기온(°C)         -0.219790       -0.216995       -0.735511
# 평균 강수량(mm)            0.208985       -0.051958       -0.167112
# 전년 강수량(mm)           -0.041754        0.206052       -0.163567
# 평년 강수량(mm)           -0.151686       -0.152399       -0.511528
# 평균 일조시간(hr)          -0.035959        0.039231        0.071760
# 전년 일조시간(hr)           0.000284       -0.017387        0.070272
# 평년 일조시간(hr)           0.088510        0.083627        0.200950
# 평균 일사량(MJ/㎡)         -0.065786       -0.024256       -0.128270
# 전년 일사량(MJ/㎡)         -0.016544       -0.085036       -0.123063
# 평년 일사량(MJ/㎡)               NaN             NaN             NaN
# 평균 습도(%)             -0.284584       -0.190772       -0.525392
# 전년 습도(%)             -0.136034       -0.272644       -0.513295
# 평년 습도(%)             -0.263635       -0.254631       -0.810331
# 평균 운량(1/10)          -0.024399       -0.071971       -0.182612
# 전년 운량(1/10)          -0.018583       -0.057027       -0.184706
# 평년 운량(1/10)          -0.073070       -0.037684       -0.092788
# 평균 적설량(cm)            0.234602        0.077238        0.148828
# 전년 적설량(cm)            0.089659        0.231722        0.146065
# 평년 적설량(cm)                 NaN             NaN             NaN
# 평균 순간최대풍속(m/s)        1.000000        0.091918        0.289068
# 전년 순간최대풍속(m/s)        0.091918        1.000000        0.286698
# 평년 순간최대풍속(m/s)        0.289068        0.286698        1.000000
#
# [28 rows x 28 columns]

# %%
## 깨져 나와서 다시 한 번 더 최종수정


# -*- coding: utf-8 -*-
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import math

# ---------- 한글 폰트 설정 추가 ----------
# 이 부분이 가장 중요합니다.
# matplotlib에 시스템의 한글 폰트를 설정하여 글씨 깨짐을 방지합니다.

from matplotlib import font_manager, rc

# 폰트 경로를 찾아서 설정합니다.
# Windows 환경의 경우
font_path = 'C:/Windows/Fonts/malgun.ttf'
# 만약 'malgun.ttf' 폰트가 없다면, 다른 한글 폰트(ex: NanumGothic.ttf) 경로를 지정해주세요.
if os.path.exists(font_path):
    font_name = font_manager.FontProperties(fname=font_path).get_name()
    rc('font', family=font_name)
else:
    print("맑은 고딕 폰트를 찾을 수 없습니다. 다른 한글 폰트를 사용하거나 설치해주세요.")
    # 기본 fallback 폰트로 설정하거나 다른 폰트 경로를 지정
    rc('font', family='AppleGothic') # macOS 환경
    # rc('font', family='NanumGothic') # 리눅스 환경 등

# 마이너스 부호가 깨지는 현상을 방지합니다.
plt.rcParams['axes.unicode_minus'] = False
# ---------------------------------------------


# ---------- 설정 ----------
base_path = r'C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터'
input_file = os.path.join(base_path, '일별_기상데이터.csv')
output_excel = os.path.join(base_path, '일별_기상데이터_EDA.xlsx')
plots_folder = os.path.join(base_path, 'EDA_plots')

os.makedirs(plots_folder, exist_ok=True)

# 분석할 열 목록 (질문에서 주신 열 그대로)
cols = [
    '평균 기온(°C)', '최고 기온(°C)', '최저 기온(°C)', '전년 기온(°C)', '평년 기온(°C)', '평년 최고 기온(°C)', '평년 최저 기온(°C)',
    '평균 강수량(mm)', '전년 강수량(mm)', '평년 강수량(mm)',
    '평균 일조시간(hr)', '전년 일조시간(hr)', '평년 일조시간(hr)',
    '평균 일사량(MJ/㎡)', '전년 일사량(MJ/㎡)', '평년 일사량(MJ/㎡)',
    '평균 습도(%)', '전년 습도(%)', '평년 습도(%)',
    '평균 운량(1/10)', '전년 운량(1/10)', '평년 운량(1/10)',
    '평균 적설량(cm)', '전년 적설량(cm)', '평년 적설량(cm)',
    '평균 순간최대풍속(m/s)', '전년 순간최대풍속(m/s)', '평년 순간최대풍속(m/s)'
]

# ---------- 데이터 불러오기 ----------
# 인코딩 문제 발생 시 encoding='cp949'로 변경하세요.
df = pd.read_csv(input_file, encoding='utf-8-sig')

# '조회일자' 기준 정렬(필요시)
if '조회일자' in df.columns:
    # 조회일자 숫자형(예: 20250630) -> 문자열로 변환 후 날짜 타입으로 바꾸면 편함
    try:
        df['조회일자_dt'] = pd.to_datetime(df['조회일자'].astype(str), format='%Y%m%d')
        df = df.sort_values('조회일자_dt', ascending=False).drop(columns=['조회일자_dt'])
    except Exception:
        # 변환 실패하면 그냥 넘어감
        pass

# 필요한 열만 남기되, 존재하지 않는 열은 제외
available_cols = [c for c in cols if c in df.columns]
if len(available_cols) < 1:
    raise ValueError("분석할 열이 데이터에 없습니다. 파일의 열 이름을 확인해 주세요.")

df_sub = df[ ['조회일자'] + available_cols ].copy()

# 숫자형으로 변환 (문자열 중 쉼표, 공백 등 제거)
for c in available_cols:
    # 쉼표 제거, 공백 제거 후 numeric 변환
    df_sub[c] = pd.to_numeric(df_sub[c].astype(str).str.replace(',', '').str.strip(), errors='coerce')

# ---------- 요약 통계 ----------
summary = df_sub[available_cols].agg(['count','mean','median','min','max','std']).transpose()
summary = summary.rename(columns={'count':'N','median':'median','min':'min','max':'max','std':'std'})

# 결측치 정보
summary['missing_count'] = df_sub.shape[0] - summary['N']

# ---------- 정규성 검사 ----------
# 샘플 수가 5000 이하이면 Shapiro 권장, 그보다 크면 normaltest(D'Agostino) 사용
normality_results = []
n_rows = df_sub.shape[0]
for c in available_cols:
    series = df_sub[c].dropna()
    n = len(series)
    if n < 3:
        normality_results.append({'variable':c, 'test':'none', 'stat':np.nan, 'pvalue':np.nan, 'note':'not enough data'})
        continue
    try:
        if n <= 5000:
            stat, p = stats.shapiro(series)
            normality_results.append({'variable':c, 'test':'shapiro', 'stat':stat, 'pvalue':p,
                                     'note':('normal' if p>0.05 else 'not_normal')})
        else:
            # normaltest requires n>=8
            stat, p = stats.normaltest(series)
            normality_results.append({'variable':c, 'test':'normaltest', 'stat':stat, 'pvalue':p,
                                     'note':('normal' if p>0.05 else 'not_normal')})
    except Exception as e:
        normality_results.append({'variable':c, 'test':'error', 'stat':np.nan, 'pvalue':np.nan, 'note':str(e)})

normality_df = pd.DataFrame(normality_results).set_index('variable')

# ---------- 이상치 탐지 (IQR 방법) ----------
outlier_info = []
iqr_details = {}
for c in available_cols:
    s = df_sub[c].dropna()
    if len(s) == 0:
        outlier_info.append({'variable':c, 'n_outliers':0, 'pct_outliers':0.0, 'lower_bound':np.nan, 'upper_bound':np.nan})
        iqr_details[c] = {'Q1':np.nan,'Q3':np.nan,'IQR':np.nan}
        continue
    Q1 = s.quantile(0.25)
    Q3 = s.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = s[(s < lower) | (s > upper)]
    n_out = outliers.shape[0]
    pct = n_out / df_sub.shape[0] * 100
    outlier_info.append({'variable':c, 'n_outliers':n_out, 'pct_outliers':pct, 'lower_bound':lower, 'upper_bound':upper})
    iqr_details[c] = {'Q1':Q1,'Q3':Q3,'IQR':IQR}

outliers_df = pd.DataFrame(outlier_info).set_index('variable')

# ---------- 상관관계 (Pearson) 및 p-values ----------
vars_for_corr = available_cols.copy()
corr_matrix = df_sub[vars_for_corr].corr(method='pearson')

# p-value matrix
pval_matrix = pd.DataFrame(index=vars_for_corr, columns=vars_for_corr, dtype=float)
for i in range(len(vars_for_corr)):
    for j in range(len(vars_for_corr)):
        x = df_sub[vars_for_corr[i]].dropna()
        y = df_sub[vars_for_corr[j]].dropna()
        # To compute pearsonr, need aligned data: drop NaN pairs
        common = df_sub[[vars_for_corr[i], vars_for_corr[j]]].dropna()
        if common.shape[0] < 3:
            pval_matrix.iloc[i,j] = np.nan
        else:
            try:
                r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
                pval_matrix.iloc[i,j] = p
            except Exception:
                pval_matrix.iloc[i,j] = np.nan

# ---------- 시각화 생성 ----------
# 1) 각 변수별 히스토그램 + 밀도 - 한글 폰트 적용
hist_files = []
for c in available_cols:
    fig, ax = plt.subplots(figsize=(8,5))
    series = df_sub[c].dropna()
    if len(series) > 0:
        ax.hist(series, bins=30, density=True, alpha=0.6, color='skyblue', edgecolor='black')
        try:
            density = stats.gaussian_kde(series)
            xs = np.linspace(series.min(), series.max(), 200)
            ax.plot(xs, density(xs), color='red', linewidth=2)
        except Exception:
            pass
    ax.set_title(f'Histogram & Density: {c}', fontsize=12, pad=15)
    ax.set_xlabel(c, fontsize=10)
    ax.set_ylabel('Density', fontsize=10)
    ax.grid(True, alpha=0.3)
    
    fname = os.path.join(plots_folder, f'hist_{c.replace("/", "_").replace(" ", "_").replace("(", "").replace(")", "").replace("°", "deg").replace("㎡", "m2")}.png')
    fig.tight_layout()
    fig.savefig(fname, dpi=150, bbox_inches='tight')
    plt.close(fig)
    hist_files.append(fname)

# 2) 박스플롯: 여러 변수 한 장에 (그리드)
fig, ax = plt.subplots(figsize=(max(8, len(available_cols)*0.25), 
                                max(6, len(available_cols)*0.25)))
df_sub[available_cols].boxplot(ax=ax, rot=90) # rot=90 → x축 레이블 회전
ax.set_title('Boxplots of Selected Variables')
fig.tight_layout()

boxplot_file = os.path.join(plots_folder, 'boxplots_all_vars.png')
fig.savefig(boxplot_file, dpi=150)
plt.close(fig)

# 3) 상관행렬 히트맵 (matplotlib만 사용)
# 간단한 heatmap을 직접 그림
fig, ax = plt.subplots(figsize=(max(8, len(available_cols)*0.25), max(6, len(available_cols)*0.25)))
cax = ax.imshow(corr_matrix.values, interpolation='nearest', vmin=-1, vmax=1)
ax.set_xticks(np.arange(len(vars_for_corr)))
ax.set_yticks(np.arange(len(vars_for_corr)))
ax.set_xticklabels(vars_for_corr, rotation=90, fontsize=8)
ax.set_yticklabels(vars_for_corr, fontsize=8)
fig.colorbar(cax, ax=ax, fraction=0.03)
ax.set_title('Pearson Correlation Matrix')
fig.tight_layout()
corr_file = os.path.join(plots_folder, 'correlation_matrix.png')
fig.savefig(corr_file, dpi=150)
plt.close(fig)

# ---------- 엑셀로 저장 (숫자 결과 + 이미지 삽입) ----------
with pd.ExcelWriter(output_excel, engine='xlsxwriter') as writer:
    # 요약 통계
    summary.to_excel(writer, sheet_name='summary_stats')
    # 정규성
    normality_df.to_excel(writer, sheet_name='normality_tests')
    # 이상치
    outliers_df.to_excel(writer, sheet_name='outlier_summary')
    # 상관계수 및 p-value
    corr_matrix.to_excel(writer, sheet_name='correlation_matrix')
    pval_matrix.to_excel(writer, sheet_name='correlation_pvalues')
    # 원본(선택한 열)도 저장
    df_sub.to_excel(writer, sheet_name='data_sample', index=False)

    # 이미지 삽입: 새로운 시트 생성
    workbook  = writer.book
    try:
        worksheet = workbook.add_worksheet('Plots')
    except Exception:
        worksheet = writer.sheets.get('Plots') or workbook.add_worksheet('Plots')

    # 이미지 위치 지정 (행, 열)
    row = 0
    col = 0
    # 먼저 히스토그램들 (한 행에 2개씩)
    for i, fpath in enumerate(hist_files):
        # Excel cell 위치 (row, col) in pixels offset handled by xlsxwriter
        worksheet.insert_image(row, col, fpath, {'x_scale':0.9, 'y_scale':0.9})
        col += 8  # 다음 이미지 위한 열 이동
        if (i+1) % 2 == 0:
            row += 20
            col = 0
    # 박스플롯
    row += 22
    col = 0
    worksheet.insert_image(row, col, boxplot_file, {'x_scale':0.9, 'y_scale':0.9})
    row += 30
    # 상관행렬 이미지
    worksheet.insert_image(row, 0, corr_file, {'x_scale':0.9, 'y_scale':0.9})

# ---------- 콘솔 출력 요약 ----------
print("EDA 완료.")
print(f"결과 엑셀 파일: {output_excel}")
print(f"플롯 이미지 폴더: {plots_folder}")
print("\n요약 통계 (모든 변수):")
print(summary)
print("\n정규성 테스트 결과:")
print(normality_df)
print("\n이상치 요약 (모든 변수):")
print(outliers_df.sort_values('n_outliers', ascending=False))
print("\n상관계수:")
print(corr_matrix)

# 끝
# Out:
# C:\Users\henaj\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# C:\Users\henaj\AppData\Local\Temp\ipykernel_4168\4037755060.py:152: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
# EDA 완료.
# 결과 엑셀 파일: C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터\일별_기상데이터_EDA.xlsx
# 플롯 이미지 폴더: C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터\EDA_plots
#
# 요약 통계 (모든 변수):
#                      N       mean     median        min         max  \
# 평균 기온(°C)       3652.0  13.398069  14.111268 -99.000000   29.888235
# 최고 기온(°C)       3652.0  18.845144  20.236050  -7.229412   36.364706
# 최저 기온(°C)       3652.0   8.847502   8.954478 -15.794030   26.304225
# 전년 기온(°C)       3652.0  13.257304  13.931102 -99.000000   29.888235
# 평년 기온(°C)       3652.0  12.088742  12.817647  -1.268657   25.350746
# 평년 최고 기온(°C)    3652.0  17.332790  18.764464   3.597059   29.841791
# 평년 최저 기온(°C)    3652.0   7.576064   7.246479  -5.788060   22.002817
# 평균 강수량(mm)      3652.0   3.594690   0.205926   0.000000  108.938028
# 전년 강수량(mm)      3652.0   3.555772   0.194242   0.000000  104.902985
# 평년 강수량(mm)      3652.0   3.517436   2.281690   0.354412   13.552239
# 평균 일조시간(hr)     3652.0   6.247519   6.858347   0.000000   12.922535
# 전년 일조시간(hr)     3652.0   6.211464   6.809341   0.000000   12.922535
# 평년 일조시간(hr)     3652.0   5.815775   5.782353   3.688235    7.738806
# 평균 일사량(MJ/㎡)    3652.0   5.688838   5.238897   0.000000   23.015000
# 전년 일사량(MJ/㎡)    3652.0   5.255681   4.880154   0.000000   23.905000
# 평년 일사량(MJ/㎡)    3652.0   0.000000   0.000000   0.000000    0.000000
# 평균 습도(%)        3652.0  69.493573  70.805054   0.000000   95.585075
# 전년 습도(%)        3652.0  68.875950  70.097059   0.000000   95.585075
# 평년 습도(%)        3652.0  65.964239  64.357463  55.500000   79.695522
# 평균 운량(1/10)     3652.0   3.966012   3.312687   0.000000    9.964179
# 전년 운량(1/10)     3652.0   3.707365   2.845588   0.000000    9.918310
# 평년 운량(1/10)     3652.0   3.133896   3.538235   0.000000    7.404478
# 평균 적설량(cm)      3652.0   0.029826   0.000000   0.000000    4.507042
# 전년 적설량(cm)      3652.0   0.025361   0.000000   0.000000    4.507042
# 평년 적설량(cm)      3652.0   0.000000   0.000000   0.000000    0.000000
# 평균 순간최대풍속(m/s)  3652.0   7.995145   7.527941   3.719718   19.513433
# 전년 순간최대풍속(m/s)  3652.0   7.916840   7.439437   0.378082   19.513433
# 평년 순간최대풍속(m/s)  3652.0   2.053504   2.026668   1.573239    2.631343
#
#                       std  missing_count
# 평균 기온(°C)        9.765127            0.0
# 최고 기온(°C)        9.369548            0.0
# 최저 기온(°C)        9.875944            0.0
# 전년 기온(°C)        9.432100            0.0
# 평년 기온(°C)        8.597256            0.0
# 평년 최고 기온(°C)     8.374253            0.0
# 평년 최저 기온(°C)     8.977317            0.0
# 평균 강수량(mm)       9.043281            0.0
# 전년 강수량(mm)       8.857365            0.0
# 평년 강수량(mm)       2.956121            0.0
# 평균 일조시간(hr)      3.301193            0.0
# 전년 일조시간(hr)      3.304887            0.0
# 평년 일조시간(hr)      0.808785            0.0
# 평균 일사량(MJ/㎡)     2.939695            0.0
# 전년 일사량(MJ/㎡)     2.621508            0.0
# 평년 일사량(MJ/㎡)     0.000000            0.0
# 평균 습도(%)        12.718799            0.0
# 전년 습도(%)        12.823115            0.0
# 평년 습도(%)         6.601598            0.0
# 평균 운량(1/10)      2.740791            0.0
# 전년 운량(1/10)      2.644454            0.0
# 평년 운량(1/10)      1.854601            0.0
# 평균 적설량(cm)       0.149680            0.0
# 전년 적설량(cm)       0.136234            0.0
# 평년 적설량(cm)       0.000000            0.0
# 평균 순간최대풍속(m/s)   2.207858            0.0
# 전년 순간최대풍속(m/s)   2.193919            0.0
# 평년 순간최대풍속(m/s)   0.248243            0.0
#
# 정규성 테스트 결과:
#                    test      stat        pvalue        note
# variable
# 평균 기온(°C)       shapiro  0.929049  1.529145e-38  not_normal
# 최고 기온(°C)       shapiro  0.960476  1.864414e-30  not_normal
# 최저 기온(°C)       shapiro  0.960658  2.141119e-30  not_normal
# 전년 기온(°C)       shapiro  0.944835  6.090726e-35  not_normal
# 평년 기온(°C)       shapiro  0.921583  5.033699e-40  not_normal
# 평년 최고 기온(°C)    shapiro  0.913117  1.420036e-41  not_normal
# 평년 최저 기온(°C)    shapiro  0.923433  1.143814e-39  not_normal
# 평균 강수량(mm)      shapiro  0.446495  7.721945e-75  not_normal
# 전년 강수량(mm)      shapiro  0.452161  1.259526e-74  not_normal
# 평년 강수량(mm)      shapiro  0.836059  7.472259e-52  not_normal
# 평균 일조시간(hr)     shapiro  0.960027  1.330713e-30  not_normal
# 전년 일조시간(hr)     shapiro  0.959819  1.138671e-30  not_normal
# 평년 일조시간(hr)     shapiro  0.984711  1.896658e-19  not_normal
# 평균 일사량(MJ/㎡)    shapiro  0.955224  4.264029e-32  not_normal
# 전년 일사량(MJ/㎡)    shapiro  0.964203  3.475743e-29  not_normal
# 평년 일사량(MJ/㎡)    shapiro  1.000000  1.000000e+00      normal
# 평균 습도(%)        shapiro  0.980225  3.587425e-22  not_normal
# 전년 습도(%)        shapiro  0.982789  1.118298e-20  not_normal
# 평년 습도(%)        shapiro  0.915239  3.379435e-41  not_normal
# 평균 운량(1/10)     shapiro  0.928503  1.179730e-38  not_normal
# 전년 운량(1/10)     shapiro  0.922061  6.212012e-40  not_normal
# 평년 운량(1/10)     shapiro  0.879566  1.030207e-46  not_normal
# 평균 적설량(cm)      shapiro  0.195570  9.048500e-83  not_normal
# 전년 적설량(cm)      shapiro  0.178647  3.183723e-83  not_normal
# 평년 적설량(cm)      shapiro  1.000000  1.000000e+00      normal
# 평균 순간최대풍속(m/s)  shapiro  0.935186  3.162153e-37  not_normal
# 전년 순간최대풍속(m/s)  shapiro  0.931239  4.395592e-38  not_normal
# 평년 순간최대풍속(m/s)  shapiro  0.935657  4.027226e-37  not_normal
#
# 이상치 요약 (모든 변수):
#                 n_outliers  pct_outliers  lower_bound  upper_bound
# variable
# 전년 강수량(mm)             595     16.292442    -3.221127     5.376388
# 평균 강수량(mm)             588     16.100767    -3.269871     5.461053
# 평균 적설량(cm)             510     13.964951     0.000000     0.000000
# 전년 적설량(cm)             486     13.307777     0.000000     0.000000
# 전년 순간최대풍속(m/s)         107      2.929901     2.359965    13.074568
# 평균 순간최대풍속(m/s)          87      2.382256     2.217966    13.375691
# 평년 강수량(mm)              84      2.300110    -4.382429    10.802087
# 평균 일사량(MJ/㎡)            68      1.861993    -2.435822    13.441118
# 전년 일사량(MJ/㎡)            41      1.122673    -2.167943    12.430410
# 전년 습도(%)                 2      0.054765    29.973460   107.904159
# 평균 습도(%)                 2      0.054765    30.430750   108.683961
# 평균 기온(°C)                2      0.054765   -19.032142    46.098565
# 전년 기온(°C)                1      0.027382   -18.666519    45.445179
# 평년 일조시간(hr)              0      0.000000     3.428499     8.132895
# 전년 일조시간(hr)              0      0.000000    -3.876471    16.294118
# 최고 기온(°C)                0      0.000000   -13.175735    50.794853
# 평년 일사량(MJ/㎡)             0      0.000000     0.000000     0.000000
# 평균 일조시간(hr)              0      0.000000    -3.770572    16.264108
# 평년 최저 기온(°C)             0      0.000000   -26.437744    41.257273
# 평년 습도(%)                 0      0.000000    43.168877    89.111027
# 평균 운량(1/10)              0      0.000000    -5.298979    13.145358
# 전년 운량(1/10)              0      0.000000    -4.796093    12.104522
# 평년 운량(1/10)              0      0.000000    -3.828180     9.606170
# 평년 최고 기온(°C)             0      0.000000   -15.011589    49.138718
# 평년 기온(°C)                0      0.000000   -20.895651    44.693861
# 평년 적설량(cm)               0      0.000000     0.000000     0.000000
# 최저 기온(°C)                0      0.000000   -25.614692    43.674487
# 평년 순간최대풍속(m/s)           0      0.000000     1.154225     2.962676
#
# 상관계수:
#                 평균 기온(°C)  최고 기온(°C)  최저 기온(°C)  전년 기온(°C)  평년 기온(°C)  \
# 평균 기온(°C)        1.000000   0.959477   0.956621   0.881557   0.930497
# 최고 기온(°C)        0.959477   1.000000   0.949154   0.885373   0.936548
# 최저 기온(°C)        0.956621   0.949154   1.000000   0.903740   0.954281
# 전년 기온(°C)        0.881557   0.885373   0.903740   1.000000   0.943794
# 평년 기온(°C)        0.930497   0.936548   0.954281   0.943794   1.000000
# 평년 최고 기온(°C)     0.928521   0.938247   0.947668   0.941865   0.997426
# 평년 최저 기온(°C)     0.927340   0.929184   0.956415   0.940148   0.997160
# 평균 강수량(mm)       0.239655   0.168174   0.308757   0.237224   0.252585
# 전년 강수량(mm)       0.233663   0.224985   0.249687   0.244295   0.253297
# 평년 강수량(mm)       0.770109   0.752215   0.814456   0.780844   0.826914
# 평균 일조시간(hr)      0.014664   0.125938  -0.108094   0.019986   0.026713
# 전년 일조시간(hr)      0.032807   0.048661   0.017238   0.007152   0.021611
# 평년 일조시간(hr)      0.077388   0.128158   0.017502   0.088101   0.077188
# 평균 일사량(MJ/㎡)     0.391547   0.479634   0.303683   0.391391   0.408897
# 전년 일사량(MJ/㎡)     0.404045   0.428905   0.390166   0.406076   0.420926
# 평년 일사량(MJ/㎡)          NaN        NaN        NaN        NaN        NaN
# 평균 습도(%)         0.594862   0.506108   0.657232   0.500409   0.533049
# 전년 습도(%)         0.473194   0.459865   0.504084   0.577203   0.516049
# 평년 습도(%)         0.774409   0.750485   0.830588   0.780132   0.839141
# 평균 운량(1/10)      0.227291   0.148442   0.292047   0.194722   0.204854
# 전년 운량(1/10)      0.187980   0.176537   0.203764   0.223967   0.203847
# 평년 운량(1/10)      0.273664   0.262432   0.281149   0.292544   0.303116
# 평균 적설량(cm)      -0.320763  -0.352280  -0.304638  -0.261900  -0.263363
# 전년 적설량(cm)      -0.246643  -0.261410  -0.239434  -0.313383  -0.248099
# 평년 적설량(cm)            NaN        NaN        NaN        NaN        NaN
# 평균 순간최대풍속(m/s)  -0.243551  -0.296586  -0.231997  -0.185372  -0.212479
# 전년 순간최대풍속(m/s)  -0.209192  -0.205499  -0.218760  -0.245609  -0.210279
# 평년 순간최대풍속(m/s)  -0.663450  -0.656455  -0.704731  -0.667414  -0.722177
#
#                 평년 최고 기온(°C)  평년 최저 기온(°C)  평균 강수량(mm)  전년 강수량(mm)  \
# 평균 기온(°C)           0.928521      0.927340    0.239655    0.233663
# 최고 기온(°C)           0.938247      0.929184    0.168174    0.224985
# 최저 기온(°C)           0.947668      0.956415    0.308757    0.249687
# 전년 기온(°C)           0.941865      0.940148    0.237224    0.244295
# 평년 기온(°C)           0.997426      0.997160    0.252585    0.253297
# 평년 최고 기온(°C)        1.000000      0.989477    0.243058    0.243566
# 평년 최저 기온(°C)        0.989477      1.000000    0.260535    0.261474
# 평균 강수량(mm)          0.243058      0.260535    1.000000    0.092697
# 전년 강수량(mm)          0.243566      0.261474    0.092697    1.000000
# 평년 강수량(mm)          0.792736      0.854370    0.295670    0.297183
# 평균 일조시간(hr)         0.039436      0.010478   -0.513479   -0.031860
# 전년 일조시간(hr)         0.035492      0.004474   -0.043956   -0.516258
# 평년 일조시간(hr)         0.134558      0.011005   -0.111109   -0.110098
# 평균 일사량(MJ/㎡)        0.422896      0.384366   -0.308489    0.079908
# 전년 일사량(MJ/㎡)        0.436133      0.394990    0.067747   -0.325159
# 평년 일사량(MJ/㎡)             NaN           NaN         NaN         NaN
# 평균 습도(%)            0.519507      0.548798    0.494907    0.158949
# 전년 습도(%)            0.501530      0.532816    0.152296    0.498023
# 평년 습도(%)            0.809170      0.872524    0.266571    0.263495
# 평균 운량(1/10)         0.198676      0.209653    0.385031    0.094136
# 전년 운량(1/10)         0.196788      0.209156    0.103695    0.374305
# 평년 운량(1/10)         0.291353      0.313985    0.090247    0.066411
# 평균 적설량(cm)         -0.273153     -0.252305   -0.051554   -0.050433
# 전년 적설량(cm)         -0.257611     -0.237106   -0.052203   -0.047986
# 평년 적설량(cm)               NaN           NaN         NaN         NaN
# 평균 순간최대풍속(m/s)     -0.208764     -0.219790    0.208985   -0.041754
# 전년 순간최대풍속(m/s)     -0.206712     -0.216995   -0.051958    0.206052
# 평년 순간최대풍속(m/s)     -0.717829     -0.735511   -0.167112   -0.163567
#
#                 평년 강수량(mm)  ...  평년 습도(%)  평균 운량(1/10)  전년 운량(1/10)  \
# 평균 기온(°C)         0.770109  ...  0.774409     0.227291     0.187980
# 최고 기온(°C)         0.752215  ...  0.750485     0.148442     0.176537
# 최저 기온(°C)         0.814456  ...  0.830588     0.292047     0.203764
# 전년 기온(°C)         0.780844  ...  0.780132     0.194722     0.223967
# 평년 기온(°C)         0.826914  ...  0.839141     0.204854     0.203847
# 평년 최고 기온(°C)      0.792736  ...  0.809170     0.198676     0.196788
# 평년 최저 기온(°C)      0.854370  ...  0.872524     0.209653     0.209156
# 평균 강수량(mm)        0.295670  ...  0.266571     0.385031     0.103695
# 전년 강수량(mm)        0.297183  ...  0.263495     0.094136     0.374305
# 평년 강수량(mm)        1.000000  ...  0.852110     0.208860     0.214776
# 평균 일조시간(hr)      -0.061801  ... -0.106293    -0.620585    -0.054902
# 전년 일조시간(hr)      -0.073984  ... -0.108129    -0.019137    -0.600156
# 평년 일조시간(hr)      -0.329949  ... -0.415659    -0.057600    -0.064778
# 평균 일사량(MJ/㎡)      0.255800  ...  0.115275    -0.209833     0.197802
# 전년 일사량(MJ/㎡)      0.260123  ...  0.124029     0.182570    -0.212267
# 평년 일사량(MJ/㎡)           NaN  ...       NaN          NaN          NaN
# 평균 습도(%)          0.499395  ...  0.593510     0.480406     0.176657
# 전년 습도(%)          0.489149  ...  0.577306     0.112214     0.455227
# 평년 습도(%)          0.852110  ...  1.000000     0.191608     0.185323
# 평균 운량(1/10)       0.208860  ...  0.191608     1.000000     0.372731
# 전년 운량(1/10)       0.214776  ...  0.185323     0.372731     1.000000
# 평년 운량(1/10)       0.358343  ...  0.395919    -0.262038    -0.356700
# 평균 적설량(cm)       -0.169809  ... -0.171472    -0.039149    -0.017362
# 전년 적설량(cm)       -0.161352  ... -0.152337    -0.051373    -0.056862
# 평년 적설량(cm)             NaN  ...       NaN          NaN          NaN
# 평균 순간최대풍속(m/s)   -0.151686  ... -0.263635    -0.024399    -0.018583
# 전년 순간최대풍속(m/s)   -0.152399  ... -0.254631    -0.071971    -0.057027
# 평년 순간최대풍속(m/s)   -0.511528  ... -0.810331    -0.182612    -0.184706
#
#                 평년 운량(1/10)  평균 적설량(cm)  전년 적설량(cm)  평년 적설량(cm)  \
# 평균 기온(°C)          0.273664   -0.320763   -0.246643         NaN
# 최고 기온(°C)          0.262432   -0.352280   -0.261410         NaN
# 최저 기온(°C)          0.281149   -0.304638   -0.239434         NaN
# 전년 기온(°C)          0.292544   -0.261900   -0.313383         NaN
# 평년 기온(°C)          0.303116   -0.263363   -0.248099         NaN
# 평년 최고 기온(°C)       0.291353   -0.273153   -0.257611         NaN
# 평년 최저 기온(°C)       0.313985   -0.252305   -0.237106         NaN
# 평균 강수량(mm)         0.090247   -0.051554   -0.052203         NaN
# 전년 강수량(mm)         0.066411   -0.050433   -0.047986         NaN
# 평년 강수량(mm)         0.358343   -0.169809   -0.161352         NaN
# 평균 일조시간(hr)       -0.004509   -0.014755   -0.022899         NaN
# 전년 일조시간(hr)        0.011664   -0.033627   -0.012085         NaN
# 평년 일조시간(hr)       -0.115322   -0.098814   -0.103193         NaN
# 평균 일사량(MJ/㎡)      -0.166124   -0.100603   -0.119313         NaN
# 전년 일사량(MJ/㎡)      -0.089752   -0.120448   -0.130315         NaN
# 평년 일사량(MJ/㎡)            NaN         NaN         NaN         NaN
# 평균 습도(%)           0.145762   -0.147497   -0.117654         NaN
# 전년 습도(%)           0.154117   -0.098683   -0.141119         NaN
# 평년 습도(%)           0.395919   -0.171472   -0.152337         NaN
# 평균 운량(1/10)       -0.262038   -0.039149   -0.051373         NaN
# 전년 운량(1/10)       -0.356700   -0.017362   -0.056862         NaN
# 평년 운량(1/10)        1.000000   -0.115026   -0.069092         NaN
# 평균 적설량(cm)        -0.115026    1.000000    0.214054         NaN
# 전년 적설량(cm)        -0.069092    0.214054    1.000000         NaN
# 평년 적설량(cm)              NaN         NaN         NaN         NaN
# 평균 순간최대풍속(m/s)    -0.073070    0.234602    0.089659         NaN
# 전년 순간최대풍속(m/s)    -0.037684    0.077238    0.231722         NaN
# 평년 순간최대풍속(m/s)    -0.092788    0.148828    0.146065         NaN
#
#                 평균 순간최대풍속(m/s)  전년 순간최대풍속(m/s)  평년 순간최대풍속(m/s)
# 평균 기온(°C)            -0.243551       -0.209192       -0.663450
# 최고 기온(°C)            -0.296586       -0.205499       -0.656455
# 최저 기온(°C)            -0.231997       -0.218760       -0.704731
# 전년 기온(°C)            -0.185372       -0.245609       -0.667414
# 평년 기온(°C)            -0.212479       -0.210279       -0.722177
# 평년 최고 기온(°C)         -0.208764       -0.206712       -0.717829
# 평년 최저 기온(°C)         -0.219790       -0.216995       -0.735511
# 평균 강수량(mm)            0.208985       -0.051958       -0.167112
# 전년 강수량(mm)           -0.041754        0.206052       -0.163567
# 평년 강수량(mm)           -0.151686       -0.152399       -0.511528
# 평균 일조시간(hr)          -0.035959        0.039231        0.071760
# 전년 일조시간(hr)           0.000284       -0.017387        0.070272
# 평년 일조시간(hr)           0.088510        0.083627        0.200950
# 평균 일사량(MJ/㎡)         -0.065786       -0.024256       -0.128270
# 전년 일사량(MJ/㎡)         -0.016544       -0.085036       -0.123063
# 평년 일사량(MJ/㎡)               NaN             NaN             NaN
# 평균 습도(%)             -0.284584       -0.190772       -0.525392
# 전년 습도(%)             -0.136034       -0.272644       -0.513295
# 평년 습도(%)             -0.263635       -0.254631       -0.810331
# 평균 운량(1/10)          -0.024399       -0.071971       -0.182612
# 전년 운량(1/10)          -0.018583       -0.057027       -0.184706
# 평년 운량(1/10)          -0.073070       -0.037684       -0.092788
# 평균 적설량(cm)            0.234602        0.077238        0.148828
# 전년 적설량(cm)            0.089659        0.231722        0.146065
# 평년 적설량(cm)                 NaN             NaN             NaN
# 평균 순간최대풍속(m/s)        1.000000        0.091918        0.289068
# 전년 순간최대풍속(m/s)        0.091918        1.000000        0.286698
# 평년 순간최대풍속(m/s)        0.289068        0.286698        1.000000
#
# [28 rows x 28 columns]

# %%
# -90도씨 이하 데이터 2개를 앞뒤평균보간법으로 대체해서 새로운 파일 '일별_기상데이터_이상치 처리.csv'로 저장
import pandas as pd
import numpy as np

# 파일 경로
input_path = r"C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터\일별_기상데이터.csv"
output_path = r"C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터\일별_기상데이터_이상치 처리.csv"

# 데이터 불러오기
df = pd.read_csv(input_path)

# 대상 열
target_cols = ['평균 기온(°C)', '전년 기온(°C)']

# 이상치 탐색 및 처리
for col in target_cols:
    # 이상치 조건 (-50 이하인 값)
    outliers = df[df[col] <= -50]

    for idx, value in outliers[col].items():
        # 전날, 다음날 값 가져오기
        prev_val = df[col][idx - 1] if idx - 1 >= 0 else np.nan
        next_val = df[col][idx + 1] if idx + 1 < len(df) else np.nan

        # 앞뒤 평균 구하기 (둘 중 하나가 NaN이면 다른 하나 값으로 대체)
        if pd.notna(prev_val) and pd.notna(next_val):
            new_val = (prev_val + next_val) / 2
        elif pd.notna(prev_val):
            new_val = prev_val
        elif pd.notna(next_val):
            new_val = next_val
        else:
            new_val = np.nan  # 둘 다 없으면 NaN 처리

        # 변경 적용
        df.at[idx, col] = new_val

        # 변경 사항 출력
        print(f"({idx},{col}) {value} -> {new_val} 로 대체")

print("대체 완료!")

# 새로운 CSV 파일로 저장
df.to_csv(output_path, index=False, encoding='utf-8-sig')
# Out:
# (3108,평균 기온(°C)) -99.0 -> 3.3605633802816897 로 대체
# (3514,평균 기온(°C)) -99.0 -> -1.036619718309859 로 대체
# (3474,전년 기온(°C)) -99.0 -> 3.3605633802816897 로 대체
# 대체 완료!

# %%
import pandas as pd

# 파일 경로
input_path = r"C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터\일별_기상데이터_이상치 처리.csv"
output_path = r"C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터\일별_기상데이터_주간평균.csv"

# 데이터 불러오기
df = pd.read_csv(input_path)

# 조회일자를 datetime으로 변환
df['조회일자'] = pd.to_datetime(df['조회일자'], format='%Y%m%d')

# '평년 일사량(MJ/㎡)’, ‘평년 적설량(cm)’ 열 삭제 (있을 때만)   
if '평년 일사량(MJ/㎡)' in df.columns:
    df = df.drop(columns=['평년 일사량(MJ/㎡)'])

if '평년 적설량(cm)' in df.columns:
    df = df.drop(columns=['평년 적설량(cm)'])



# 7일 단위 그룹핑 (0부터 시작하는 주차 번호 생성)
df['week_group'] = (df.index // 7)

# 그룹별로 평균 계산
weekly_df = df.groupby('week_group').mean(numeric_only=True)

# 각 그룹의 시작일과 종료일 가져오기
group_ranges = df.groupby('week_group')['조회일자'].agg(['min', 'max'])

# 새로운 조회일자 형식으로 변환
weekly_df['조회일자'] = group_ranges['min'].dt.strftime('%Y%m%d') + '-' + group_ranges['max'].dt.strftime('%Y%m%d')

# 열 순서 조정 (조회일자가 맨 앞으로 오게)
cols = ['조회일자'] + [col for col in weekly_df.columns if col != '조회일자']
weekly_df = weekly_df[cols]

# 결과 저장
weekly_df.to_csv(output_path, index=False, encoding='utf-8-sig')

print("주간 평균 데이터 생성 완료!")
# Out:
# 주간 평균 데이터 생성 완료!

# %%
# -*- coding: utf-8 -*-
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import math

# ---------- 한글 폰트 설정 추가 ----------
# 이 부분이 가장 중요합니다.
# matplotlib에 시스템의 한글 폰트를 설정하여 글씨 깨짐을 방지합니다.

from matplotlib import font_manager, rc

# 폰트 경로를 찾아서 설정합니다.
# Windows 환경의 경우
font_path = 'C:/Windows/Fonts/malgun.ttf'
# 만약 'malgun.ttf' 폰트가 없다면, 다른 한글 폰트(ex: NanumGothic.ttf) 경로를 지정해주세요.
if os.path.exists(font_path):
    font_name = font_manager.FontProperties(fname=font_path).get_name()
    rc('font', family=font_name)
else:
    print("맑은 고딕 폰트를 찾을 수 없습니다. 다른 한글 폰트를 사용하거나 설치해주세요.")
    # 기본 fallback 폰트로 설정하거나 다른 폰트 경로를 지정
    rc('font', family='AppleGothic') # macOS 환경
    # rc('font', family='NanumGothic') # 리눅스 환경 등

# 마이너스 부호가 깨지는 현상을 방지합니다.
plt.rcParams['axes.unicode_minus'] = False
# ---------------------------------------------


# ---------- 설정 ----------
base_path = r'C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터'
input_file = os.path.join(base_path, '일별_기상데이터_주간평균.csv')
output_excel = os.path.join(base_path, '일별_기상데이터_주간평균_EDA.xlsx')
plots_folder = os.path.join(base_path, 'EDA_주간평균_plots')

os.makedirs(plots_folder, exist_ok=True)

# 분석할 열 목록 (질문에서 주신 열 그대로)
cols = [
    '평균 기온(°C)', '최고 기온(°C)', '최저 기온(°C)', '전년 기온(°C)', '평년 기온(°C)', '평년 최고 기온(°C)', '평년 최저 기온(°C)',
    '평균 강수량(mm)', '전년 강수량(mm)', '평년 강수량(mm)',
    '평균 일조시간(hr)', '전년 일조시간(hr)', '평년 일조시간(hr)',
    '평균 일사량(MJ/㎡)', '전년 일사량(MJ/㎡)', 
    '평균 습도(%)', '전년 습도(%)', '평년 습도(%)',
    '평균 운량(1/10)', '전년 운량(1/10)', '평년 운량(1/10)',
    '평균 적설량(cm)', '전년 적설량(cm)', 
    '평균 순간최대풍속(m/s)', '전년 순간최대풍속(m/s)', '평년 순간최대풍속(m/s)'
]

# ---------- 데이터 불러오기 ----------
# 인코딩 문제 발생 시 encoding='cp949'로 변경하세요.
df = pd.read_csv(input_file, encoding='utf-8-sig')

# '조회일자' 기준 정렬(필요시)
#if '조회일자' in df.columns:
    # 조회일자 숫자형(예: 20250630) -> 문자열로 변환 후 날짜 타입으로 바꾸면 편함
    #try:
        #df['조회일자_dt'] = pd.to_datetime(df['조회일자'].astype(str), format='%Y%m%d')
        #df = df.sort_values('조회일자_dt', ascending=False).drop(columns=['조회일자_dt'])
    #except Exception:
        # 변환 실패하면 그냥 넘어감
        #pass

# 필요한 열만 남기되, 존재하지 않는 열은 제외
available_cols = [c for c in cols if c in df.columns]
if len(available_cols) < 1:
    raise ValueError("분석할 열이 데이터에 없습니다. 파일의 열 이름을 확인해 주세요.")

df_sub = df[ ['조회일자'] + available_cols ].copy()

# 숫자형으로 변환 (문자열 중 쉼표, 공백 등 제거)
for c in available_cols:
    # 쉼표 제거, 공백 제거 후 numeric 변환
    df_sub[c] = pd.to_numeric(df_sub[c].astype(str).str.replace(',', '').str.strip(), errors='coerce')

# ---------- 요약 통계 ----------
summary = df_sub[available_cols].agg(['count','mean','median','min','max','std']).transpose()
summary = summary.rename(columns={'count':'N','median':'median','min':'min','max':'max','std':'std'})

# 결측치 정보
summary['missing_count'] = df_sub.shape[0] - summary['N']

# ---------- 정규성 검사 ----------
# 샘플 수가 5000 이하이면 Shapiro 권장, 그보다 크면 normaltest(D'Agostino) 사용
normality_results = []
n_rows = df_sub.shape[0]
for c in available_cols:
    series = df_sub[c].dropna()
    n = len(series)
    if n < 3:
        normality_results.append({'variable':c, 'test':'none', 'stat':np.nan, 'pvalue':np.nan, 'note':'not enough data'})
        continue
    try:
        if n <= 5000:
            stat, p = stats.shapiro(series)
            normality_results.append({'variable':c, 'test':'shapiro', 'stat':stat, 'pvalue':p,
                                     'note':('normal' if p>0.05 else 'not_normal')})
        else:
            # normaltest requires n>=8
            stat, p = stats.normaltest(series)
            normality_results.append({'variable':c, 'test':'normaltest', 'stat':stat, 'pvalue':p,
                                     'note':('normal' if p>0.05 else 'not_normal')})
    except Exception as e:
        normality_results.append({'variable':c, 'test':'error', 'stat':np.nan, 'pvalue':np.nan, 'note':str(e)})

normality_df = pd.DataFrame(normality_results).set_index('variable')

# ---------- 이상치 탐지 (IQR 방법) ----------
outlier_info = []
iqr_details = {}
for c in available_cols:
    s = df_sub[c].dropna()
    if len(s) == 0:
        outlier_info.append({'variable':c, 'n_outliers':0, 'pct_outliers':0.0, 'lower_bound':np.nan, 'upper_bound':np.nan})
        iqr_details[c] = {'Q1':np.nan,'Q3':np.nan,'IQR':np.nan}
        continue
    Q1 = s.quantile(0.25)
    Q3 = s.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = s[(s < lower) | (s > upper)]
    n_out = outliers.shape[0]
    pct = n_out / df_sub.shape[0] * 100
    outlier_info.append({'variable':c, 'n_outliers':n_out, 'pct_outliers':pct, 'lower_bound':lower, 'upper_bound':upper})
    iqr_details[c] = {'Q1':Q1,'Q3':Q3,'IQR':IQR}

outliers_df = pd.DataFrame(outlier_info).set_index('variable')

# ---------- 상관관계 (Pearson) 및 p-values ----------
vars_for_corr = available_cols.copy()
corr_matrix = df_sub[vars_for_corr].corr(method='pearson')

# p-value matrix
pval_matrix = pd.DataFrame(index=vars_for_corr, columns=vars_for_corr, dtype=float)
for i in range(len(vars_for_corr)):
    for j in range(len(vars_for_corr)):
        x = df_sub[vars_for_corr[i]].dropna()
        y = df_sub[vars_for_corr[j]].dropna()
        # To compute pearsonr, need aligned data: drop NaN pairs
        common = df_sub[[vars_for_corr[i], vars_for_corr[j]]].dropna()
        if common.shape[0] < 3:
            pval_matrix.iloc[i,j] = np.nan
        else:
            try:
                r, p = stats.pearsonr(common[vars_for_corr[i]], common[vars_for_corr[j]])
                pval_matrix.iloc[i,j] = p
            except Exception:
                pval_matrix.iloc[i,j] = np.nan

# ---------- 시각화 생성 ----------
# 1) 각 변수별 히스토그램 + 밀도 - 한글 폰트 적용
hist_files = []
for c in available_cols:
    fig, ax = plt.subplots(figsize=(8,5))
    series = df_sub[c].dropna()
    if len(series) > 0:
        ax.hist(series, bins=30, density=True, alpha=0.6, color='skyblue', edgecolor='black')
        try:
            density = stats.gaussian_kde(series)
            xs = np.linspace(series.min(), series.max(), 200)
            ax.plot(xs, density(xs), color='red', linewidth=2)
        except Exception:
            pass
    ax.set_title(f'Histogram & Density: {c}', fontsize=12, pad=15)
    ax.set_xlabel(c, fontsize=10)
    ax.set_ylabel('Density', fontsize=10)
    ax.grid(True, alpha=0.3)
    
    fname = os.path.join(plots_folder, f'hist_{c.replace("/", "_").replace(" ", "_").replace("(", "").replace(")", "").replace("°", "deg").replace("㎡", "m2")}.png')
    fig.tight_layout()
    fig.savefig(fname, dpi=150, bbox_inches='tight')
    plt.close(fig)
    hist_files.append(fname)

# 2) 박스플롯: 여러 변수 한 장에 (그리드)
fig, ax = plt.subplots(figsize=(max(8, len(available_cols)*0.25), 
                                max(6, len(available_cols)*0.25)))
df_sub[available_cols].boxplot(ax=ax, rot=90) # rot=90 → x축 레이블 회전
ax.set_title('Boxplots of Selected Variables')
fig.tight_layout()

boxplot_file = os.path.join(plots_folder, 'boxplots_all_vars.png')
fig.savefig(boxplot_file, dpi=150)
plt.close(fig)

# 3) 상관행렬 히트맵 (matplotlib만 사용)
# 간단한 heatmap을 직접 그림
fig, ax = plt.subplots(figsize=(max(8, len(available_cols)*0.25), max(6, len(available_cols)*0.25)))
cax = ax.imshow(corr_matrix.values, interpolation='nearest', vmin=-1, vmax=1)
ax.set_xticks(np.arange(len(vars_for_corr)))
ax.set_yticks(np.arange(len(vars_for_corr)))
ax.set_xticklabels(vars_for_corr, rotation=90, fontsize=8)
ax.set_yticklabels(vars_for_corr, fontsize=8)
fig.colorbar(cax, ax=ax, fraction=0.03)
ax.set_title('Pearson Correlation Matrix')
fig.tight_layout()
corr_file = os.path.join(plots_folder, 'correlation_matrix.png')
fig.savefig(corr_file, dpi=150)
plt.close(fig)

# ---------- 엑셀로 저장 (숫자 결과 + 이미지 삽입) ----------
with pd.ExcelWriter(output_excel, engine='xlsxwriter') as writer:
    # 요약 통계
    summary.to_excel(writer, sheet_name='summary_stats')
    # 정규성
    normality_df.to_excel(writer, sheet_name='normality_tests')
    # 이상치
    outliers_df.to_excel(writer, sheet_name='outlier_summary')
    # 상관계수 및 p-value
    corr_matrix.to_excel(writer, sheet_name='correlation_matrix')
    pval_matrix.to_excel(writer, sheet_name='correlation_pvalues')
    # 원본(선택한 열)도 저장
    df_sub.to_excel(writer, sheet_name='data_sample', index=False)

    # 이미지 삽입: 새로운 시트 생성
    workbook  = writer.book
    try:
        worksheet = workbook.add_worksheet('Plots')
    except Exception:
        worksheet = writer.sheets.get('Plots') or workbook.add_worksheet('Plots')

    # 이미지 위치 지정 (행, 열)
    row = 0
    col = 0
    # 먼저 히스토그램들 (한 행에 2개씩)
    for i, fpath in enumerate(hist_files):
        # Excel cell 위치 (row, col) in pixels offset handled by xlsxwriter
        worksheet.insert_image(row, col, fpath, {'x_scale':0.9, 'y_scale':0.9})
        col += 8  # 다음 이미지 위한 열 이동
        if (i+1) % 2 == 0:
            row += 20
            col = 0
    # 박스플롯
    row += 22
    col = 0
    worksheet.insert_image(row, col, boxplot_file, {'x_scale':0.9, 'y_scale':0.9})
    row += 30
    # 상관행렬 이미지
    worksheet.insert_image(row, 0, corr_file, {'x_scale':0.9, 'y_scale':0.9})

# ---------- 콘솔 출력 요약 ----------
print("EDA 완료.")
print(f"결과 엑셀 파일: {output_excel}")
print(f"플롯 이미지 폴더: {plots_folder}")
print("\n요약 통계 (모든 변수):")
print(summary)
print("\n정규성 테스트 결과:")
print(normality_df)
print("\n이상치 요약 (모든 변수):")
print(outliers_df.sort_values('n_outliers', ascending=False))
print("\n상관계수:")
print(corr_matrix)

# 끝
# Out:
# EDA 완료.
# 결과 엑셀 파일: C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터\일별_기상데이터_주간평균_EDA.xlsx
# 플롯 이미지 폴더: C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터\EDA_주간평균_plots
#
# 요약 통계 (모든 변수):
#                     N       mean     median        min        max        std  \
# 평균 기온(°C)       522.0  13.459362  14.507425  -7.148529  29.510504   9.224417
# 최고 기온(°C)       522.0  18.851459  20.480462  -2.423950  35.200840   9.072099
# 최저 기온(°C)       522.0   8.854430   8.911713 -11.844989  25.492354   9.669864
# 전년 기온(°C)       522.0  13.290803  13.812395  -6.444350  29.500840   9.052659
# 평년 기온(°C)       522.0  12.093951  12.773667  -1.172708  25.217697   8.597635
# 평년 최고 기온(°C)    522.0  17.337426  18.754070   3.832983  29.646482   8.372922
# 평년 최저 기온(°C)    522.0   7.581882   7.279104  -5.608529  21.883501   8.977884
# 평균 강수량(mm)      522.0   3.593123   1.576047   0.000000  34.896177   5.085037
# 전년 강수량(mm)      522.0   3.562007   1.821271   0.000000  29.985513   4.748664
# 평년 강수량(mm)      522.0   3.520580   2.291444   0.525420  12.257983   2.908352
# 평균 일조시간(hr)     522.0   6.248137   6.263685   1.200201  11.807983   1.880689
# 전년 일조시간(hr)     522.0   6.211394   6.166225   0.852113  11.684454   1.831984
# 평년 일조시간(hr)     522.0   5.815006   5.779922   3.933199   7.465458   0.782053
# 평균 일사량(MJ/㎡)    522.0   5.692859   5.410693   1.527752  14.652012   2.363072
# 전년 일사량(MJ/㎡)    522.0   5.257981   5.038326   1.504076  13.861308   2.044087
# 평균 습도(%)        522.0  69.499243  69.951944  45.140756  90.909256   9.995188
# 전년 습도(%)        522.0  68.880597  69.074568  42.961555  89.910448  10.043638
# 평년 습도(%)        522.0  65.969602  64.287923  56.516205  78.510235   6.576192
# 평균 운량(1/10)     522.0   3.966591   4.029211   0.453571   9.107847   2.123478
# 전년 운량(1/10)     522.0   3.708818   3.517785   0.505882   9.102817   2.075368
# 평년 운량(1/10)     522.0   3.133158   3.554202   0.917304   7.123529   1.849865
# 평균 적설량(cm)      522.0   0.029810   0.000000   0.000000   1.200402   0.102599
# 전년 적설량(cm)      522.0   0.025347   0.000000   0.000000   1.148491   0.089254
# 평균 순간최대풍속(m/s)  522.0   7.994219   7.799234   5.071855  12.728785   1.255656
# 전년 순간최대풍속(m/s)  522.0   7.916891   7.772226   4.622535  12.915352   1.250056
# 평년 순간최대풍속(m/s)  522.0   2.053384   2.024790   1.614487   2.544350   0.244356
#
#                 missing_count
# 평균 기온(°C)                 0.0
# 최고 기온(°C)                 0.0
# 최저 기온(°C)                 0.0
# 전년 기온(°C)                 0.0
# 평년 기온(°C)                 0.0
# 평년 최고 기온(°C)              0.0
# 평년 최저 기온(°C)              0.0
# 평균 강수량(mm)                0.0
# 전년 강수량(mm)                0.0
# 평년 강수량(mm)                0.0
# 평균 일조시간(hr)               0.0
# 전년 일조시간(hr)               0.0
# 평년 일조시간(hr)               0.0
# 평균 일사량(MJ/㎡)              0.0
# 전년 일사량(MJ/㎡)              0.0
# 평균 습도(%)                  0.0
# 전년 습도(%)                  0.0
# 평년 습도(%)                  0.0
# 평균 운량(1/10)               0.0
# 전년 운량(1/10)               0.0
# 평년 운량(1/10)               0.0
# 평균 적설량(cm)                0.0
# 전년 적설량(cm)                0.0
# 평균 순간최대풍속(m/s)            0.0
# 전년 순간최대풍속(m/s)            0.0
# 평년 순간최대풍속(m/s)            0.0
#
# 정규성 테스트 결과:
#                    test      stat        pvalue        note
# variable
# 평균 기온(°C)       shapiro  0.955126  1.666400e-11  not_normal
# 최고 기온(°C)       shapiro  0.953531  9.393575e-12  not_normal
# 최저 기온(°C)       shapiro  0.954498  1.327450e-11  not_normal
# 전년 기온(°C)       shapiro  0.953881  1.063945e-11  not_normal
# 평년 기온(°C)       shapiro  0.920804  6.259490e-16  not_normal
# 평년 최고 기온(°C)    shapiro  0.912022  7.754296e-17  not_normal
# 평년 최저 기온(°C)    shapiro  0.922687  1.000460e-15  not_normal
# 평균 강수량(mm)      shapiro  0.689733  7.517018e-30  not_normal
# 전년 강수량(mm)      shapiro  0.723413  1.685642e-28  not_normal
# 평년 강수량(mm)      shapiro  0.831136  4.487868e-23  not_normal
# 평균 일조시간(hr)     shapiro  0.997175  5.117904e-01      normal
# 전년 일조시간(hr)     shapiro  0.996301  2.677382e-01      normal
# 평년 일조시간(hr)     shapiro  0.977711  3.795045e-07  not_normal
# 평균 일사량(MJ/㎡)    shapiro  0.944501  4.570112e-13  not_normal
# 전년 일사량(MJ/㎡)    shapiro  0.956588  2.852410e-11  not_normal
# 평균 습도(%)        shapiro  0.983667  1.353176e-05  not_normal
# 전년 습도(%)        shapiro  0.985121  3.559867e-05  not_normal
# 평년 습도(%)        shapiro  0.907620  2.878257e-17  not_normal
# 평균 운량(1/10)     shapiro  0.952542  6.625074e-12  not_normal
# 전년 운량(1/10)     shapiro  0.944833  5.076268e-13  not_normal
# 평년 운량(1/10)     shapiro  0.875809  5.290746e-20  not_normal
# 평균 적설량(cm)      shapiro  0.321798  6.400064e-40  not_normal
# 전년 적설량(cm)      shapiro  0.311654  3.982827e-40  not_normal
# 평균 순간최대풍속(m/s)  shapiro  0.976192  1.658417e-07  not_normal
# 전년 순간최대풍속(m/s)  shapiro  0.972856  2.974876e-08  not_normal
# 평년 순간최대풍속(m/s)  shapiro  0.923732  1.302611e-15  not_normal
#
# 이상치 요약 (모든 변수):
#                 n_outliers  pct_outliers  lower_bound  upper_bound
# variable
# 전년 적설량(cm)             116     22.222222    -0.003319     0.005532
# 평균 적설량(cm)             115     22.030651    -0.004884     0.008141
# 평균 강수량(mm)              38      7.279693    -6.375776    11.699751
# 전년 강수량(mm)              35      6.704981    -6.132340    11.319027
# 평균 일사량(MJ/㎡)            13      2.490421    -0.802903    11.720539
# 평년 강수량(mm)               6      1.149425    -4.379756    11.006803
# 평균 일조시간(hr)              6      1.149425     1.578611    10.933558
# 전년 일사량(MJ/㎡)             6      1.149425    -0.552721    10.699389
# 전년 일조시간(hr)              4      0.766284     1.507709    10.959051
# 전년 순간최대풍속(m/s)           3      0.574713     4.377314    11.281745
# 평균 순간최대풍속(m/s)           3      0.574713     4.448400    11.497221
# 전년 습도(%)                 0      0.000000    37.521901   100.444441
# 평년 운량(1/10)              0      0.000000    -3.914609     9.754396
# 전년 운량(1/10)              0      0.000000    -3.860165    11.044533
# 평균 운량(1/10)              0      0.000000    -3.932998    11.391831
# 평년 습도(%)                 0      0.000000    42.604220    89.642997
# 평균 기온(°C)                0      0.000000   -20.072735    46.659231
# 평균 습도(%)                 0      0.000000    38.123568   101.192174
# 최고 기온(°C)                0      0.000000   -13.043153    50.307217
# 평년 일조시간(hr)              0      0.000000     3.512134     8.002466
# 평년 최저 기온(°C)             0      0.000000   -26.154192    41.058375
# 평년 최고 기온(°C)             0      0.000000   -14.936265    49.114700
# 평년 기온(°C)                0      0.000000   -20.827224    44.783532
# 전년 기온(°C)                0      0.000000   -19.694233    46.155891
# 최저 기온(°C)                0      0.000000   -26.181789    44.225671
# 평년 순간최대풍속(m/s)           0      0.000000     1.150170     2.971688
#
# 상관계수:
#                 평균 기온(°C)  최고 기온(°C)  최저 기온(°C)  전년 기온(°C)  평년 기온(°C)  \
# 평균 기온(°C)        1.000000   0.994392   0.994232   0.960360   0.977530
# 최고 기온(°C)        0.994392   1.000000   0.978328   0.950594   0.968011
# 최저 기온(°C)        0.994232   0.978328   1.000000   0.957669   0.975277
# 전년 기온(°C)        0.960360   0.950594   0.957669   1.000000   0.978968
# 평년 기온(°C)        0.977530   0.968011   0.975277   0.978968   1.000000
# 평년 최고 기온(°C)     0.975282   0.969952   0.968670   0.976785   0.997519
# 평년 최저 기온(°C)     0.974471   0.960370   0.977484   0.975526   0.997234
# 평균 강수량(mm)       0.445563   0.392478   0.488540   0.443523   0.448360
# 전년 강수량(mm)       0.457037   0.435174   0.471882   0.472661   0.472217
# 평년 강수량(mm)       0.824103   0.790405   0.846251   0.824469   0.841486
# 평균 일조시간(hr)      0.033693   0.116229  -0.050234   0.040182   0.046483
# 전년 일조시간(hr)      0.055974   0.080676   0.024311   0.033430   0.039748
# 평년 일조시간(hr)      0.083338   0.137906   0.017503   0.090511   0.079406
# 평균 일사량(MJ/㎡)     0.507644   0.553095   0.452927   0.508627   0.510128
# 전년 일사량(MJ/㎡)     0.544290   0.563899   0.510016   0.541488   0.541358
# 평균 습도(%)         0.710378   0.660007   0.760934   0.662472   0.679210
# 전년 습도(%)         0.634721   0.609015   0.659160   0.691071   0.658702
# 평년 습도(%)         0.816956   0.778722   0.852591   0.813846   0.842387
# 평균 운량(1/10)      0.272191   0.232952   0.307972   0.256007   0.265608
# 전년 운량(1/10)      0.252746   0.236714   0.267589   0.260165   0.260236
# 평년 운량(1/10)      0.282848   0.270680   0.287271   0.301728   0.303293
# 평균 적설량(cm)      -0.448002  -0.468264  -0.422316  -0.401036  -0.384784
# 전년 적설량(cm)      -0.381057  -0.391437  -0.362329  -0.443484  -0.378119
# 평균 순간최대풍속(m/s)  -0.424922  -0.430325  -0.432533  -0.353107  -0.377344
# 전년 순간최대풍속(m/s)  -0.370104  -0.360800  -0.383569  -0.413509  -0.370862
# 평년 순간최대풍속(m/s)  -0.708106  -0.688051  -0.732170  -0.703018  -0.733434
#
#                 평년 최고 기온(°C)  평년 최저 기온(°C)  평균 강수량(mm)  전년 강수량(mm)  \
# 평균 기온(°C)           0.975282      0.974471    0.445563    0.457037
# 최고 기온(°C)           0.969952      0.960370    0.392478    0.435174
# 최저 기온(°C)           0.968670      0.977484    0.488540    0.471882
# 전년 기온(°C)           0.976785      0.975526    0.443523    0.472661
# 평년 기온(°C)           0.997519      0.997234    0.448360    0.472217
# 평년 최고 기온(°C)        1.000000      0.989795    0.431336    0.453691
# 평년 최저 기온(°C)        0.989795      1.000000    0.462597    0.487745
# 평균 강수량(mm)          0.431336      0.462597    1.000000    0.303742
# 전년 강수량(mm)          0.453691      0.487745    0.303742    1.000000
# 평년 강수량(mm)          0.808002      0.868458    0.531272    0.559586
# 평균 일조시간(hr)         0.069334      0.017471   -0.562787   -0.096693
# 전년 일조시간(hr)         0.065371      0.008227   -0.082304   -0.520824
# 평년 일조시간(hr)         0.136214      0.013220   -0.207522   -0.217093
# 평균 일사량(MJ/㎡)        0.527484      0.479659   -0.065468    0.202771
# 전년 일사량(MJ/㎡)        0.560862      0.508092    0.190169   -0.028563
# 평균 습도(%)            0.661942      0.699460    0.613615    0.363908
# 전년 습도(%)            0.640081      0.680383    0.341061    0.627316
# 평년 습도(%)            0.812924      0.875378    0.477044    0.495440
# 평균 운량(1/10)         0.257402      0.271958    0.434614    0.226040
# 전년 운량(1/10)         0.250891      0.267275    0.215596    0.416547
# 평년 운량(1/10)         0.292220      0.313622    0.160965    0.123594
# 평균 적설량(cm)         -0.398909     -0.368815   -0.143792   -0.137875
# 전년 적설량(cm)         -0.392391     -0.361401   -0.143890   -0.147607
# 평균 순간최대풍속(m/s)     -0.370965     -0.390116    0.033234   -0.147281
# 전년 순간최대풍속(m/s)     -0.364320     -0.382965   -0.178851    0.000281
# 평년 순간최대풍속(m/s)     -0.727896     -0.747826   -0.307408   -0.315567
#
#                 평년 강수량(mm)  ...  전년 습도(%)  평년 습도(%)  평균 운량(1/10)  전년 운량(1/10)  \
# 평균 기온(°C)         0.824103  ...  0.634721  0.816956     0.272191     0.252746
# 최고 기온(°C)         0.790405  ...  0.609015  0.778722     0.232952     0.236714
# 최저 기온(°C)         0.846251  ...  0.659160  0.852591     0.307972     0.267589
# 전년 기온(°C)         0.824469  ...  0.691071  0.813846     0.256007     0.260165
# 평년 기온(°C)         0.841486  ...  0.658702  0.842387     0.265608     0.260236
# 평년 최고 기온(°C)      0.808002  ...  0.640081  0.812924     0.257402     0.250891
# 평년 최저 기온(°C)      0.868458  ...  0.680383  0.875378     0.271958     0.267275
# 평균 강수량(mm)        0.531272  ...  0.341061  0.477044     0.434614     0.215596
# 전년 강수량(mm)        0.559586  ...  0.627316  0.495440     0.226040     0.416547
# 평년 강수량(mm)        1.000000  ...  0.639405  0.862656     0.277993     0.279536
# 평균 일조시간(hr)      -0.118412  ... -0.136354 -0.192522    -0.436696    -0.097590
# 전년 일조시간(hr)      -0.139416  ... -0.551177 -0.199871    -0.036801    -0.416519
# 평년 일조시간(hr)      -0.316302  ... -0.292324 -0.414355    -0.083096    -0.092098
# 평균 일사량(MJ/㎡)      0.324012  ...  0.159613  0.144003     0.138316     0.333396
# 전년 일사량(MJ/㎡)      0.340420  ... -0.029743  0.159515     0.311006     0.142044
# 평균 습도(%)          0.651503  ...  0.573758  0.761924     0.432569     0.271114
# 전년 습도(%)          0.639405  ...  1.000000  0.742411     0.192836     0.389005
# 평년 습도(%)          0.862656  ...  0.742411  1.000000     0.250587     0.239269
# 평균 운량(1/10)       0.277993  ...  0.192836  0.250587     1.000000     0.597676
# 전년 운량(1/10)       0.279536  ...  0.389005  0.239269     0.597676     1.000000
# 평년 운량(1/10)       0.358255  ...  0.196704  0.394332    -0.339001    -0.456976
# 평균 적설량(cm)       -0.251445  ... -0.178929 -0.252943    -0.074098    -0.018388
# 전년 적설량(cm)       -0.249953  ... -0.220779 -0.231567    -0.105889    -0.090352
# 평균 순간최대풍속(m/s)   -0.281270  ... -0.310279 -0.472759    -0.113245    -0.041661
# 전년 순간최대풍속(m/s)   -0.281391  ... -0.493394 -0.456372    -0.143429    -0.173643
# 평년 순간최대풍속(m/s)   -0.538197  ... -0.664212 -0.824643    -0.240530    -0.240608
#
#                 평년 운량(1/10)  평균 적설량(cm)  전년 적설량(cm)  평균 순간최대풍속(m/s)  \
# 평균 기온(°C)          0.282848   -0.448002   -0.381057       -0.424922
# 최고 기온(°C)          0.270680   -0.468264   -0.391437       -0.430325
# 최저 기온(°C)          0.287271   -0.422316   -0.362329       -0.432533
# 전년 기온(°C)          0.301728   -0.401036   -0.443484       -0.353107
# 평년 기온(°C)          0.303293   -0.384784   -0.378119       -0.377344
# 평년 최고 기온(°C)       0.292220   -0.398909   -0.392391       -0.370965
# 평년 최저 기온(°C)       0.313622   -0.368815   -0.361401       -0.390116
# 평균 강수량(mm)         0.160965   -0.143792   -0.143890        0.033234
# 전년 강수량(mm)         0.123594   -0.137875   -0.147607       -0.147281
# 평년 강수량(mm)         0.358255   -0.251445   -0.249953       -0.281270
# 평균 일조시간(hr)       -0.011996   -0.053367   -0.069959        0.071525
# 전년 일조시간(hr)        0.019007   -0.105781   -0.076786        0.019261
# 평년 일조시간(hr)       -0.103775   -0.146188   -0.163170        0.170223
# 평균 일사량(MJ/㎡)      -0.209630   -0.182769   -0.226088       -0.017113
# 전년 일사량(MJ/㎡)      -0.116875   -0.232558   -0.264116       -0.030911
# 평균 습도(%)           0.185696   -0.236698   -0.209226       -0.513053
# 전년 습도(%)           0.196704   -0.178929   -0.220779       -0.310279
# 평년 습도(%)           0.394332   -0.252943   -0.231567       -0.472759
# 평균 운량(1/10)       -0.339001   -0.074098   -0.105889       -0.113245
# 전년 운량(1/10)       -0.456976   -0.018388   -0.090352       -0.041661
# 평년 운량(1/10)        1.000000   -0.171215   -0.106431       -0.130407
# 평균 적설량(cm)        -0.171215    1.000000    0.368113        0.325533
# 전년 적설량(cm)        -0.106431    0.368113    1.000000        0.135681
# 평균 순간최대풍속(m/s)    -0.130407    0.325533    0.135681        1.000000
# 전년 순간최대풍속(m/s)    -0.069286    0.178817    0.320157        0.302390
# 평년 순간최대풍속(m/s)    -0.094941    0.215615    0.219535        0.514350
#
#                 전년 순간최대풍속(m/s)  평년 순간최대풍속(m/s)
# 평균 기온(°C)            -0.370104       -0.708106
# 최고 기온(°C)            -0.360800       -0.688051
# 최저 기온(°C)            -0.383569       -0.732170
# 전년 기온(°C)            -0.413509       -0.703018
# 평년 기온(°C)            -0.370862       -0.733434
# 평년 최고 기온(°C)         -0.364320       -0.727896
# 평년 최저 기온(°C)         -0.382965       -0.747826
# 평균 강수량(mm)           -0.178851       -0.307408
# 전년 강수량(mm)            0.000281       -0.315567
# 평년 강수량(mm)           -0.281391       -0.538197
# 평균 일조시간(hr)           0.093467        0.135039
# 전년 일조시간(hr)           0.117230        0.137393
# 평년 일조시간(hr)           0.164611        0.217015
# 평균 일사량(MJ/㎡)         -0.059696       -0.160380
# 전년 일사량(MJ/㎡)         -0.057684       -0.157157
# 평균 습도(%)             -0.407047       -0.682117
# 전년 습도(%)             -0.493394       -0.664212
# 평년 습도(%)             -0.456372       -0.824643
# 평균 운량(1/10)          -0.143429       -0.240530
# 전년 운량(1/10)          -0.173643       -0.240608
# 평년 운량(1/10)          -0.069286       -0.094941
# 평균 적설량(cm)            0.178817        0.215615
# 전년 적설량(cm)            0.320157        0.219535
# 평균 순간최대풍속(m/s)        0.302390        0.514350
# 전년 순간최대풍속(m/s)        1.000000        0.509164
# 평년 순간최대풍속(m/s)        0.509164        1.000000
#
# [26 rows x 26 columns]

# %%
# 경로가 'C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터'인 '일별_기상데이터_주간평균_날씨파생변수.xlsx' 
#파일에서 '조회일자' 열 값이 '20151020-20151026'인 열부터만 남겨두고 그 위의 열은 삭제하기(단, 첫번째 행에 있는
#열 이름은 제외하고 삭제하기). 그렇게 해서 '기상데이터_주간평균_날씨파생변수_열삭제.csv'라는 csv 형식의 파일로
#같은 경로에 저장해두기.

import pandas as pd
import os

# 파일 경로 설정
base_path = r'C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터'
input_file = os.path.join(base_path, '일별_기상데이터_주간평균_날씨파생변수.xlsx')
output_file = os.path.join(base_path, '기상데이터_주간평균_날씨파생변수_열삭제.csv')

# 엑셀 파일 불러오기
df = pd.read_excel(input_file)

# '조회일자' 기준 인덱스 찾기
start_index = df[df['조회일자'] == '20151020-20151026'].index[0]

# 해당 인덱스부터 데이터 남기기 (열 이름은 유지됨)
df_filtered = df.loc[start_index:].reset_index(drop=True)

# CSV로 저장
df_filtered.to_csv(output_file, index=False, encoding='utf-8-sig')

print("완료! 필터링된 데이터가 저장되었습니다:", output_file)
# Out:
# 완료! 필터링된 데이터가 저장되었습니다: C:\Users\henaj\Downloads\파이널 프로젝트\기상데이터\기상데이터_주간평균_날씨파생변수_열삭제.csv
