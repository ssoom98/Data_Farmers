# %% [markdown]
# 1

# %%
import pandas as pd
from io import StringIO
# 파일 읽기 (인코딩 지정)
carrot_price = pd.read_csv('당근.csv', encoding='cp949')
bigpa_price = pd.read_csv('대파.csv', encoding='cp949')
galic_price = pd.read_csv('마늘.csv', encoding='cp949')
onion_price = pd.read_csv('양파.csv', encoding='cp949')
greenpeper_price = pd.read_csv('청고추.csv', encoding='cp949')
paprica_price = pd.read_csv('파프리카.csv', encoding='cp949')
allpeemang_price = pd.read_csv('피망전체.csv', encoding='cp949')
redpeper_price = pd.read_csv('홍고추.csv', encoding='cp949')

# %%
from io import StringIO
# 1) 매핑 - 맨 앞에 공백 없이 작성
data_dict = {
    "당근": carrot_price,
    "대파": bigpa_price,
    "마늘": galic_price,
    "양파": onion_price,
    "청고추": greenpeper_price,
    "파프리카": paprica_price,
    "피망전체": allpeemang_price,
    "홍고추": redpeper_price,
}
    # 2) 루프 돌며 요약 출력
for name, df in data_dict.items():
    print("="*80)
    print(f"{name} 데이터 요약")
    print("="*80)
    
    # --- info() 출력 ---
    buf = StringIO()
    df.info(buf=buf)
    info_str = buf.getvalue()
    print("\n[info()]")
    print(info_str)
    
    # --- describe() 출력 ---
    print("\n[describe()]")
    print(df.describe(include='all'))
    
    # --- value_counts() (상위 10개) ---
    print("\n[value_counts()]")
    for col in df.columns:
        try:
            vc = df[col].value_counts(dropna=False).head(10)
            print(f"\n{col} (Top 10)")
            print(vc)
        except Exception as e:
            print(f"{col}: value_counts 불가 ({e})")
    print("\n\n")
# Out:
# ================================================================================
# 당근 데이터 요약
# ================================================================================
#
# [info()]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7308 entries, 0 to 7307
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   거래일자           7308 non-null   object
#  1   품목명            7308 non-null   object
#  2   반입량            6047 non-null   float64
#  3   금액             6050 non-null   float64
#  4   전년 반입량         6055 non-null   float64
#  5   전년 반입량 증감률(%)  7308 non-null   float64
#  6   전년 금액          6058 non-null   float64
#  7   전년 금액 증감률(%)   7308 non-null   float64
#  8   평년 반입량         7308 non-null   int64
#  9   평년 반입량 증감률(%)  7308 non-null   float64
#  10  평년 금액          7308 non-null   int64
#  11  평년 금액 증감률(%)   7308 non-null   float64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 685.3+ KB
#
#
# [describe()]
#               거래일자     품목명            반입량            금액         전년 반입량  \
# count         7308    7308    6047.000000  6.050000e+03    6055.000000
# unique        3654       2            NaN           NaN            NaN
# top     2025-06-30  당근(수입)            NaN           NaN            NaN
# freq             2    3654            NaN           NaN            NaN
# mean           NaN     NaN   78567.502067  9.367688e+07   78863.021635
# std            NaN     NaN   38974.473941  7.398484e+07   41593.752343
# min            NaN     NaN       2.000000 -4.765000e+06       2.000000
# 25%            NaN     NaN   53810.000000  4.523730e+07   51641.000000
# 50%            NaN     NaN   73530.000000  6.785480e+07   72785.000000
# 75%            NaN     NaN   97392.500000  1.204681e+08   98979.500000
# max            NaN     NaN  405840.000000  7.021883e+08  405840.000000
#
#         전년 반입량 증감률(%)         전년 금액   전년 금액 증감률(%)         평년 반입량  \
# count     7308.000000  6.058000e+03    7308.000000    7308.000000
# unique            NaN           NaN            NaN            NaN
# top               NaN           NaN            NaN            NaN
# freq              NaN           NaN            NaN            NaN
# mean       125.926300  8.883742e+07     177.180172   74001.178161
# std       3874.765256  7.241794e+07    6408.836629   23310.199346
# min       -100.000000 -4.765000e+06  -81273.000000   28082.000000
# 25%        -23.800000  4.190940e+07     -21.500000   56718.750000
# 50%          0.000000  6.455775e+07       0.000000   70000.000000
# 75%          6.400000  1.132476e+08      11.500000   89462.750000
# max     224050.000000  7.021883e+08  452357.000000  158100.000000
#
#         평년 반입량 증감률(%)         평년 금액  평년 금액 증감률(%)
# count     7308.000000  7.308000e+03   7308.000000
# unique            NaN           NaN           NaN
# top               NaN           NaN           NaN
# freq              NaN           NaN           NaN
# mean         9.507033  7.882152e+07     18.006582
# std         46.482316  4.079650e+07     55.861140
# min       -100.000000  2.571765e+07   -104.100000
# 25%        -14.700000  4.417910e+07     -9.725000
# 50%          0.000000  6.192685e+07      1.500000
# 75%         31.525000  1.085140e+08     41.925000
# max        546.100000  2.472588e+08    419.800000
#
# [value_counts()]
#
# 거래일자 (Top 10)
# 거래일자
# 2025-06-30    2
# 2018-11-07    2
# 2018-11-05    2
# 2018-11-04    2
# 2018-11-03    2
# 2018-11-02    2
# 2018-11-01    2
# 2018-10-31    2
# 2018-10-30    2
# 2018-10-29    2
# Name: count, dtype: int64
#
# 품목명 (Top 10)
# 품목명
# 당근(수입)    3654
# 당근(일반)    3654
# Name: count, dtype: int64
#
# 반입량 (Top 10)
# 반입량
# NaN        1261
# 82000.0      15
# 71000.0      14
# 67000.0      14
# 63000.0      13
# 62000.0      12
# 73000.0      12
# 50000.0      11
# 79000.0      11
# 59000.0      11
# Name: count, dtype: int64
#
# 금액 (Top 10)
# 금액
# NaN           1258
# 55980000.0       3
# 48130000.0       3
# 120000.0         2
# 98710000.0       2
# 34110000.0       2
# 61820000.0       2
# 85726000.0       2
# 44880000.0       2
# 60170000.0       2
# Name: count, dtype: int64
#
# 전년 반입량 (Top 10)
# 전년 반입량
# NaN        1253
# 63000.0      12
# 62000.0      11
# 71000.0      11
# 67000.0      11
# 43000.0      10
# 59000.0      10
# 82000.0      10
# 72000.0       9
# 44000.0       9
# Name: count, dtype: int64
#
# 전년 반입량 증감률(%) (Top 10)
# 전년 반입량 증감률(%)
#  0.0     2396
# -7.6       11
# -19.8      10
# -16.9      10
# -34.7      10
# -16.1      10
# -8.5       10
# -5.8        9
# -35.0       9
# -21.7       9
# Name: count, dtype: int64
#
# 전년 금액 (Top 10)
# 전년 금액
# NaN            1250
# 48130000.0        3
# 22160000.0        3
# 43292000.0        2
# 15480000.0        2
# 52493500.0        2
# 119956800.0       2
# 40075000.0        2
# 23530000.0        2
# 101967000.0       2
# Name: count, dtype: int64
#
# 전년 금액 증감률(%) (Top 10)
# 전년 금액 증감률(%)
#  0.0     2389
# -14.5      10
# -39.9      10
# -28.5      10
# -54.0      10
# -22.8      10
#  20.5      10
# -25.5      10
# -18.8       9
#  7.8        9
# Name: count, dtype: int64
#
# 평년 반입량 (Top 10)
# 평년 반입량
# 94598     4
# 63247     4
# 77078     4
# 74889     4
# 47151     4
# 87346     4
# 114031    3
# 84539     3
# 43475     3
# 82443     3
# Name: count, dtype: int64
#
# 평년 반입량 증감률(%) (Top 10)
# 평년 반입량 증감률(%)
#  0.0     1264
#  24.2      14
#  8.2       13
# -10.8      13
# -4.0       12
#  3.8       12
# -7.5       12
# -9.2       11
# -14.5      11
#  13.4      11
# Name: count, dtype: int64
#
# 평년 금액 (Top 10)
# 평년 금액
# 51424637     3
# 42549843     3
# 46423347     3
# 47269727     3
# 71975650     3
# 47818793     3
# 115566904    3
# 39010147     3
# 43366867     3
# 43543033     3
# Name: count, dtype: int64
#
# 평년 금액 증감률(%) (Top 10)
# 평년 금액 증감률(%)
#  0.0     1260
#  13.8      14
#  2.6       14
#  12.7      12
# -4.7       12
#  7.5       12
#  10.0      11
# -8.8       11
#  0.5       11
#  11.2      10
# Name: count, dtype: int64
#
#
#
# ================================================================================
# 대파 데이터 요약
# ================================================================================
#
# [info()]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10962 entries, 0 to 10961
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   거래일자           10962 non-null  object
#  1   품목명            10962 non-null  object
#  2   반입량            5213 non-null   float64
#  3   금액             5218 non-null   float64
#  4   전년 반입량         4363 non-null   float64
#  5   전년 반입량 증감률(%)  10962 non-null  float64
#  6   전년 금액          4367 non-null   float64
#  7   전년 금액 증감률(%)   10962 non-null  float64
#  8   평년 반입량         4945 non-null   float64
#  9   평년 반입량 증감률(%)  10962 non-null  float64
#  10  평년 금액          4945 non-null   float64
#  11  평년 금액 증감률(%)   10962 non-null  float64
# dtypes: float64(10), object(2)
# memory usage: 1.0+ MB
#
#
# [describe()]
#               거래일자    품목명            반입량            금액         전년 반입량  \
# count        10962  10962    5213.000000  5.218000e+03    4363.000000
# unique        3654      3            NaN           NaN            NaN
# top     2025-06-30    깐대파            NaN           NaN            NaN
# freq             3   3654            NaN           NaN            NaN
# mean           NaN    NaN  180444.408978  2.873120e+08  213099.699748
# std            NaN    NaN  153311.360067  2.956130e+08  142735.825074
# min            NaN    NaN      10.000000 -2.707500e+06      10.000000
# 25%            NaN    NaN    3000.000000  3.892500e+06   14515.000000
# 50%            NaN    NaN  248294.000000  2.751026e+08  269146.000000
# 75%            NaN    NaN  309219.000000  4.757996e+08  316067.500000
# max            NaN    NaN  630093.000000  1.821195e+09  630093.000000
#
#         전년 반입량 증감률(%)         전년 금액  전년 금액 증감률(%)         평년 반입량  \
# count    10962.000000  4.367000e+03  10962.000000    4945.000000
# unique            NaN           NaN           NaN            NaN
# top               NaN           NaN           NaN            NaN
# freq              NaN           NaN           NaN            NaN
# mean        11.596698  3.313999e+08     30.171866  215484.675430
# std        228.741536  2.878556e+08    965.147760  130938.975168
# min        -99.700000 -2.707500e+06   -200.900000     330.000000
# 25%          0.000000  1.587750e+07      0.000000   20034.000000
# 50%          0.000000  3.288346e+08      0.000000  266653.000000
# 75%          0.000000  4.903383e+08      0.000000  308886.000000
# max      16200.000000  1.821195e+09  74775.000000  480674.000000
#
#         평년 반입량 증감률(%)         평년 금액  평년 금액 증감률(%)
# count    10962.000000  4.945000e+03  10962.000000
# unique            NaN           NaN           NaN
# top               NaN           NaN           NaN
# freq              NaN           NaN           NaN
# mean         3.143012  2.966610e+08      9.710080
# std         39.394723  1.968597e+08     54.535996
# min        -99.300000  4.332000e+05   -136.300000
# 25%          0.000000  1.808820e+07      0.000000
# 50%          0.000000  3.366593e+08      0.000000
# 75%          0.000000  4.417675e+08      0.000000
# max        751.100000  8.324215e+08    890.800000
#
# [value_counts()]
#
# 거래일자 (Top 10)
# 거래일자
# 2025-06-30    3
# 2018-11-07    3
# 2018-11-05    3
# 2018-11-04    3
# 2018-11-03    3
# 2018-11-02    3
# 2018-11-01    3
# 2018-10-31    3
# 2018-10-30    3
# 2018-10-29    3
# Name: count, dtype: int64
#
# 품목명 (Top 10)
# 품목명
# 깐대파       3654
# 대파(수입)    3654
# 대파(일반)    3654
# Name: count, dtype: int64
#
# 반입량 (Top 10)
# 반입량
# NaN       5749
# 2000.0     161
# 1000.0     157
# 500.0      138
# 3000.0     118
# 1500.0      99
# 2500.0      76
# 4000.0      71
# 5000.0      53
# 750.0       40
# Name: count, dtype: int64
#
# 금액 (Top 10)
# 금액
# NaN          5744
# 1800000.0      47
# 1500000.0      29
# 3000000.0      19
# 1400000.0      19
# 2800000.0      18
# 800000.0       17
# 1000000.0      17
# 2000000.0      17
# 750000.0       16
# Name: count, dtype: int64
#
# 전년 반입량 (Top 10)
# 전년 반입량
# NaN       6599
# 3000.0      84
# 1000.0      75
# 2000.0      72
# 500.0       71
# 1500.0      48
# 2500.0      47
# 4000.0      43
# 5000.0      33
# 400.0       29
# Name: count, dtype: int64
#
# 전년 반입량 증감률(%) (Top 10)
# 전년 반입량 증감률(%)
#  0.0      7628
# -50.0       26
# -33.3       18
#  25.0       18
# -75.0       15
#  5.9        14
#  50.0       14
#  100.0      14
# -66.7       14
# -13.2       13
# Name: count, dtype: int64
#
# 전년 금액 (Top 10)
# 전년 금액
# NaN          6595
# 1500000.0      18
# 800000.0       17
# 1800000.0      14
# 3000000.0      13
# 2600000.0      12
# 1200000.0      11
# 3600000.0      11
# 945000.0       10
# 4200000.0      10
# Name: count, dtype: int64
#
# 전년 금액 증감률(%) (Top 10)
# 전년 금액 증감률(%)
#  0.0     7604
#  1.6        7
# -29.9       7
# -62.5       7
# -25.9       7
# -55.6       7
# -10.3       6
# -2.7        6
# -70.8       6
# -47.5       6
# Name: count, dtype: int64
#
# 평년 반입량 (Top 10)
# 평년 반입량
# NaN       6017
# 1200.0      13
# 2800.0       6
# 3600.0       6
# 5000.0       6
# 2450.0       6
# 2350.0       6
# 2919.0       6
# 3650.0       5
# 570.0        5
# Name: count, dtype: int64
#
# 평년 반입량 증감률(%) (Top 10)
# 평년 반입량 증감률(%)
#  0.0     7086
#  9.4       14
#  2.1       13
# -2.4       12
# -2.8       12
#  20.7      12
# -2.1       12
# -13.9      12
#  6.9       12
#  4.1       12
# Name: count, dtype: int64
#
# 평년 금액 (Top 10)
# 평년 금액
# NaN            6017
# 287147417.0       3
# 2030000.0         3
# 411464383.0       3
# 395445806.0       3
# 3586000.0         3
# 491582814.0       3
# 493597742.0       3
# 511968883.0       3
# 317031019.0       3
# Name: count, dtype: int64
#
# 평년 금액 증감률(%) (Top 10)
# 평년 금액 증감률(%)
#  0.0     7079
# -12.3      11
# -21.7       9
# -1.5        8
# -11.7       8
#  6.6        8
# -55.8       7
# -14.9       7
# -0.1        7
# -21.5       7
# Name: count, dtype: int64
#
#
#
# ================================================================================
# 마늘 데이터 요약
# ================================================================================
#
# [info()]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58464 entries, 0 to 58463
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   거래일자           58464 non-null  object
#  1   품목명            58464 non-null  object
#  2   반입량            15943 non-null  float64
#  3   금액             15972 non-null  float64
#  4   전년 반입량         13842 non-null  float64
#  5   전년 반입량 증감률(%)  58464 non-null  float64
#  6   전년 금액          13875 non-null  float64
#  7   전년 금액 증감률(%)   58464 non-null  float64
#  8   평년 반입량         18204 non-null  float64
#  9   평년 반입량 증감률(%)  58464 non-null  float64
#  10  평년 금액          18231 non-null  float64
#  11  평년 금액 증감률(%)   58464 non-null  float64
# dtypes: float64(10), object(2)
# memory usage: 5.4+ MB
#
#
# [describe()]
#               거래일자    품목명           반입량            금액         전년 반입량  \
# count        58464  58464  1.594300e+04  1.597200e+04   13842.000000
# unique        3654     16           NaN           NaN            NaN
# top     2025-06-30     기타           NaN           NaN            NaN
# freq            16   3654           NaN           NaN            NaN
# mean           NaN    NaN  1.009681e+04  4.640613e+07   11362.887300
# std            NaN    NaN  2.819970e+04  1.197165e+08   28100.823483
# min            NaN    NaN -4.525800e+05 -4.096496e+08     -56.000000
# 25%            NaN    NaN  3.360000e+02  1.128000e+06     559.250000
# 50%            NaN    NaN  1.640000e+03  4.513750e+06    2122.000000
# 75%            NaN    NaN  9.130000e+03  4.454833e+07   10550.000000
# max            NaN    NaN  1.260920e+06  1.646176e+09  986279.000000
#
#         전년 반입량 증감률(%)         전년 금액   전년 금액 증감률(%)         평년 반입량  \
# count    58464.000000  1.387500e+04   58464.000000   18204.000000
# unique            NaN           NaN            NaN            NaN
# top               NaN           NaN            NaN            NaN
# freq              NaN           NaN            NaN            NaN
# mean        92.246352  4.811063e+07      70.632666    9233.485113
# std       3816.690032  1.166932e+08    2042.714354   18733.625925
# min      -1528.600000 -4.096496e+08  -18600.000000       3.000000
# 25%          0.000000  1.688800e+06       0.000000    1038.000000
# 50%          0.000000  6.477500e+06       0.000000    2362.500000
# 75%          0.000000  5.042376e+07       0.000000   10555.500000
# max     457100.000000  1.646176e+09  270838.600000  205536.000000
#
#         평년 반입량 증감률(%)         평년 금액  평년 금액 증감률(%)
# count    58464.000000  1.823100e+04  58464.000000
# unique            NaN           NaN           NaN
# top               NaN           NaN           NaN
# freq              NaN           NaN           NaN
# mean        29.522335  3.281827e+07     19.880506
# std       2343.018825  6.478603e+07    646.717650
# min       -406.000000  1.202400e+04  -1134.400000
# 25%          0.000000  2.637978e+06      0.000000
# 50%          0.000000  6.040833e+06      0.000000
# 75%          0.000000  3.848079e+07      0.000000
# max     342800.000000  5.958820e+08  69470.500000
#
# [value_counts()]
#
# 거래일자 (Top 10)
# 거래일자
# 2025-06-30    16
# 2018-11-07    16
# 2018-11-05    16
# 2018-11-04    16
# 2018-11-03    16
# 2018-11-02    16
# 2018-11-01    16
# 2018-10-31    16
# 2018-10-30    16
# 2018-10-29    16
# Name: count, dtype: int64
#
# 품목명 (Top 10)
# 품목명
# 기타         3654
# 깐마늘        3654
# 깐마늘 남도     3654
# 깐마늘 대서     3654
# 깐마늘(수입)    3654
# 마늘(수입)     3654
# 마늘(일반)     3654
# 마늘쫑        3654
# 마늘쫑(수입)    3654
# 저장형 난지     3654
# Name: count, dtype: int64
#
# 반입량 (Top 10)
# 반입량
# NaN       42521
# 160.0       226
# 120.0       221
# 1900.0      199
# 2700.0      193
# 1200.0      171
# 500.0       143
# 2000.0      137
# 1000.0      137
# 400.0       132
# Name: count, dtype: int64
#
# 금액 (Top 10)
# 금액
# NaN          42492
# 4320000.0      152
# 3230000.0      109
# 3780000.0      109
# 3420000.0       81
# 850000.0        76
# 3720000.0       58
# 936000.0        52
# 1328000.0       50
# 3400000.0       49
# Name: count, dtype: int64
#
# 전년 반입량 (Top 10)
# 전년 반입량
# NaN       44622
# 1900.0      197
# 2700.0      194
# 1200.0      178
# 40.0        126
# 2000.0      115
# 160.0       113
# 500.0       110
# 120.0       104
# 1000.0       97
# Name: count, dtype: int64
#
# 전년 반입량 증감률(%) (Top 10)
# 전년 반입량 증감률(%)
#  0.0      48712
# -29.6       138
# -16.0        48
#  100.0       48
#  35.0        46
# -76.2        45
# -47.4        40
# -50.0        39
#  12.5        37
# -99.4        31
# Name: count, dtype: int64
#
# 전년 금액 (Top 10)
# 전년 금액
# NaN          44589
# 4320000.0      153
# 3780000.0      110
# 3230000.0      108
# 3420000.0       81
# 850000.0        62
# 60000.0         57
# 3720000.0       56
# 3400000.0       46
# 936000.0        40
# Name: count, dtype: int64
#
# 전년 금액 증감률(%) (Top 10)
# 전년 금액 증감률(%)
#  0.0     48604
# -25.2       57
# -77.5       41
#  5.6        32
#  8.0        31
# -20.8       26
#  5.9        26
# -99.3       26
# -39.5       24
#  27.1       22
# Name: count, dtype: int64
#
# 평년 반입량 (Top 10)
# 평년 반입량
# NaN        40260
# 4.0           31
# 34.0          26
# 10000.0       25
# 43.0          21
# 25.0          20
# 20.0          19
# 40.0          19
# 49.0          18
# 35.0          18
# Name: count, dtype: int64
#
# 평년 반입량 증감률(%) (Top 10)
# 평년 반입량 증감률(%)
#  0.0     46094
# -99.3       80
# -99.2       77
# -99.0       69
# -98.9       50
# -99.9       48
# -99.1       43
# -99.5       43
# -99.6       42
# -99.8       37
# Name: count, dtype: int64
#
# 평년 금액 (Top 10)
# 평년 금액
# NaN           40233
# 3949500.0        10
# 3070000.0         7
# 3818500.0         6
# 3388667.0         6
# 2350000.0         6
# 3496500.0         6
# 3514000.0         5
# 4500000.0         5
# 26210000.0        5
# Name: count, dtype: int64
#
# 평년 금액 증감률(%) (Top 10)
# 평년 금액 증감률(%)
#  0.0     46062
# -98.7       47
# -98.6       47
# -98.3       46
# -99.9       44
# -99.8       43
# -98.5       41
# -98.2       41
# -99.7       40
# -99.3       34
# Name: count, dtype: int64
#
#
#
# ================================================================================
# 양파 데이터 요약
# ================================================================================
#
# [info()]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36540 entries, 0 to 36539
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   거래일자           36540 non-null  object
#  1   품목명            36540 non-null  object
#  2   반입량            17177 non-null  float64
#  3   금액             17190 non-null  float64
#  4   전년 반입량         15761 non-null  float64
#  5   전년 반입량 증감률(%)  36540 non-null  float64
#  6   전년 금액          15769 non-null  float64
#  7   전년 금액 증감률(%)   36540 non-null  float64
#  8   평년 반입량         17820 non-null  float64
#  9   평년 반입량 증감률(%)  36540 non-null  float64
#  10  평년 금액          17820 non-null  float64
#  11  평년 금액 증감률(%)   36540 non-null  float64
# dtypes: float64(10), object(2)
# memory usage: 3.3+ MB
#
#
# [describe()]
#               거래일자    품목명           반입량            금액        전년 반입량  \
# count        36540  36540  1.717700e+04  1.719000e+04  1.576100e+04
# unique        3654     10           NaN           NaN           NaN
# top     2025-06-30     기타           NaN           NaN           NaN
# freq            10   3654           NaN           NaN           NaN
# mean           NaN    NaN  1.328427e+05  1.206349e+08  1.371209e+05
# std            NaN    NaN  1.875951e+05  1.725855e+08  1.877849e+05
# min            NaN    NaN -3.655500e+04 -4.481095e+07 -3.655500e+04
# 25%            NaN    NaN  6.460000e+03  6.454662e+06  6.790000e+03
# 50%            NaN    NaN  6.003600e+04  5.121352e+07  7.252500e+04
# 75%            NaN    NaN  1.726230e+05  1.631379e+08  1.815150e+05
# max            NaN    NaN  1.571571e+06  1.401064e+09  1.571571e+06
#
#         전년 반입량 증감률(%)         전년 금액  전년 금액 증감률(%)        평년 반입량  \
# count    3.654000e+04  1.576900e+04  3.654000e+04  1.782000e+04
# unique            NaN           NaN           NaN           NaN
# top               NaN           NaN           NaN           NaN
# freq              NaN           NaN           NaN           NaN
# mean     2.403756e+02  1.182176e+08  2.054929e+02  1.197476e+05
# std      1.252270e+04  1.669062e+08  1.032481e+04  1.600720e+05
# min     -4.121000e+02 -4.481095e+07 -4.624189e+05  4.910000e+02
# 25%      0.000000e+00  6.577000e+06  0.000000e+00  9.511750e+03
# 50%      0.000000e+00  5.639005e+07  0.000000e+00  7.250500e+04
# 75%      0.000000e+00  1.611779e+08  0.000000e+00  1.501612e+05
# max      1.528475e+06  1.401064e+09  1.044279e+06  1.049971e+06
#
#         평년 반입량 증감률(%)         평년 금액  평년 금액 증감률(%)
# count    36540.000000  1.782000e+04  36540.000000
# unique            NaN           NaN           NaN
# top               NaN           NaN           NaN
# freq              NaN           NaN           NaN
# mean        45.217575  9.446395e+07     61.331286
# std        368.310964  1.225025e+08    524.642112
# min       -137.500000  3.456000e+05   -528.600000
# 25%          0.000000  7.491031e+06      0.000000
# 50%          0.000000  5.562318e+07      0.000000
# 75%          0.000000  1.208892e+08      0.000000
# max      13259.300000  7.683925e+08  26582.200000
#
# [value_counts()]
#
# 거래일자 (Top 10)
# 거래일자
# 2025-06-30    10
# 2018-11-07    10
# 2018-11-05    10
# 2018-11-04    10
# 2018-11-03    10
# 2018-11-02    10
# 2018-11-01    10
# 2018-10-31    10
# 2018-10-30    10
# 2018-10-29    10
# Name: count, dtype: int64
#
# 품목명 (Top 10)
# 품목명
# 기타        3654
# 깐양파       3654
# 만생양파      3654
# 양파(수입)    3654
# 양파(일반)    3654
# 자주양파      3654
# 저장양파      3654
# 조생양파      3654
# 중생양파      3654
# 포장양파      3654
# Name: count, dtype: int64
#
# 반입량 (Top 10)
# 반입량
# NaN       19363
# 500.0        83
# 1200.0       73
# 1000.0       67
# 1100.0       66
# 1400.0       65
# 600.0        61
# 900.0        59
# 800.0        57
# 700.0        49
# Name: count, dtype: int64
#
# 금액 (Top 10)
# 금액
# NaN          19350
# 1260000.0       15
# 650000.0        13
# 1380000.0       13
# 1480000.0       13
# 1160000.0       11
# 1100000.0       11
# 780000.0        10
# 600000.0        10
# 1200000.0       10
# Name: count, dtype: int64
#
# 전년 반입량 (Top 10)
# 전년 반입량
# NaN       20779
# 1200.0       73
# 1000.0       71
# 500.0        68
# 1400.0       64
# 1100.0       58
# 600.0        54
# 900.0        53
# 800.0        53
# 1500.0       45
# Name: count, dtype: int64
#
# 전년 반입량 증감률(%) (Top 10)
# 전년 반입량 증감률(%)
#  0.0      24310
#  100.0       25
#  16.7        18
# -42.8        17
#  33.3        17
# -31.3        16
# -29.0        16
#  50.0        16
# -38.9        16
# -20.0        15
# Name: count, dtype: int64
#
# 전년 금액 (Top 10)
# 전년 금액
# NaN          20771
# 1260000.0       15
# 650000.0        13
# 1480000.0       12
# 1380000.0       12
# 1100000.0       11
# 2200000.0       10
# 600000.0        10
# 1850000.0       10
# 780000.0         9
# Name: count, dtype: int64
#
# 전년 금액 증감률(%) (Top 10)
# 전년 금액 증감률(%)
#  0.0     24266
# -32.5       17
# -23.1       16
# -28.6       15
# -49.3       15
# -56.4       15
# -43.5       14
#  15.9       14
# -19.2       14
# -36.5       14
# Name: count, dtype: int64
#
# 평년 반입량 (Top 10)
# 평년 반입량
# NaN        18720
# 15000.0       11
# 1280.0        10
# 1040.0         7
# 1360.0         7
# 1220.0         7
# 1260.0         7
# 13050.0        6
# 940.0          6
# 3326.0         6
# Name: count, dtype: int64
#
# 평년 반입량 증감률(%) (Top 10)
# 평년 반입량 증감률(%)
#  0.0      22705
# -100.0       25
# -99.9        24
# -99.7        23
# -99.6        22
# -99.8        22
# -99.5        19
#  1.2         18
# -99.2        18
# -99.4        17
# Name: count, dtype: int64
#
# 평년 금액 (Top 10)
# 평년 금액
# NaN            18720
# 157342850.0        3
# 101261740.0        3
# 81020670.0         3
# 92777880.0         3
# 70929338.0         3
# 98563440.0         3
# 95766520.0         3
# 7548262.0          3
# 8169647.0          3
# Name: count, dtype: int64
#
# 평년 금액 증감률(%) (Top 10)
# 평년 금액 증감률(%)
#  0.0      22691
# -99.9        24
# -99.8        23
# -99.7        19
# -99.5        18
#  6.1         17
# -5.7         16
# -99.6        16
# -100.0       15
# -99.3        15
# Name: count, dtype: int64
#
#
#
# ================================================================================
# 청고추 데이터 요약
# ================================================================================
#
# [info()]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25578 entries, 0 to 25577
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   거래일자           25578 non-null  object
#  1   품목명            25578 non-null  object
#  2   반입량            15812 non-null  float64
#  3   금액             15812 non-null  float64
#  4   전년 반입량         15564 non-null  float64
#  5   전년 반입량 증감률(%)  25578 non-null  float64
#  6   전년 금액          15564 non-null  float64
#  7   전년 금액 증감률(%)   25578 non-null  float64
#  8   평년 반입량         17646 non-null  float64
#  9   평년 반입량 증감률(%)  25578 non-null  float64
#  10  평년 금액          17646 non-null  float64
#  11  평년 금액 증감률(%)   25578 non-null  float64
# dtypes: float64(10), object(2)
# memory usage: 2.3+ MB
#
#
# [describe()]
#               거래일자    품목명            반입량            금액         전년 반입량  \
# count        25578  25578   15812.000000  1.581200e+04   15564.000000
# unique        3654      7            NaN           NaN            NaN
# top     2025-06-30     녹광            NaN           NaN            NaN
# freq             7   3654            NaN           NaN            NaN
# mean           NaN    NaN   23080.222742  8.653319e+07   23645.878502
# std            NaN    NaN   28454.122188  1.269138e+08   28381.805609
# min            NaN    NaN       2.000000  1.000000e+03       2.000000
# 25%            NaN    NaN    3448.000000  1.125268e+07    3859.500000
# 50%            NaN    NaN    7425.500000  2.640725e+07    8345.000000
# 75%            NaN    NaN   35834.750000  1.094767e+08   36677.500000
# max            NaN    NaN  171851.000000  1.143328e+09  171851.000000
#
#         전년 반입량 증감률(%)         전년 금액   전년 금액 증감률(%)        평년 반입량  \
# count    25578.000000  1.556400e+04   25578.000000  17646.000000
# unique            NaN           NaN            NaN           NaN
# top               NaN           NaN            NaN           NaN
# freq              NaN           NaN            NaN           NaN
# mean         8.006236  8.906748e+07      16.481379  24615.516208
# std        481.853359  1.319044e+08     863.004060  27188.053384
# min        -99.900000  4.000000e+03     -99.900000     38.000000
# 25%         -9.700000  1.234168e+07      -9.500000   4616.250000
# 50%          0.000000  2.859302e+07       0.000000   9898.000000
# 75%          0.000000  1.076211e+08       0.000000  38394.250000
# max      55011.100000  1.274475e+09  111516.800000  96744.000000
#
#         평년 반입량 증감률(%)         평년 금액  평년 금액 증감률(%)
# count    25578.000000  1.764600e+04  25578.000000
# unique            NaN           NaN           NaN
# top               NaN           NaN           NaN
# freq              NaN           NaN           NaN
# mean        -9.191321  8.764489e+07     -5.110286
# std         31.538799  1.133396e+08     38.605457
# min       -100.000000  5.362500e+04   -100.000000
# 25%        -21.300000  1.494681e+07    -19.300000
# 50%          0.000000  3.311702e+07      0.000000
# 75%          0.000000  9.983279e+07      0.000000
# max        260.200000  7.030256e+08    480.400000
#
# [value_counts()]
#
# 거래일자 (Top 10)
# 거래일자
# 2025-06-30    7
# 2018-11-07    7
# 2018-11-05    7
# 2018-11-04    7
# 2018-11-03    7
# 2018-11-02    7
# 2018-11-01    7
# 2018-10-31    7
# 2018-10-30    7
# 2018-10-29    7
# Name: count, dtype: int64
#
# 품목명 (Top 10)
# 품목명
# 녹광         3654
# 롱그린        3654
# 오이맛고추      3654
# 청양         3654
# 청초(일반)     3654
# 청홍         3654
# 풋고추(일반)    3654
# Name: count, dtype: int64
#
# 반입량 (Top 10)
# 반입량
# NaN     9766
# 20.0      37
# 40.0      32
# 10.0      30
# 4.0       27
# 80.0      20
# 12.0      18
# 32.0      17
# 50.0      17
# 2.0       15
# Name: count, dtype: int64
#
# 금액 (Top 10)
# 금액
# NaN         9766
# 20000.0       13
# 23000.0        8
# 80000.0        8
# 160000.0       7
# 150000.0       7
# 4000.0         6
# 30000.0        6
# 8000.0         6
# 180000.0       5
# Name: count, dtype: int64
#
# 전년 반입량 (Top 10)
# 전년 반입량
# NaN       10014
# 20.0         21
# 40.0         16
# 80.0         13
# 50.0         13
# 32.0         12
# 10.0         10
# 3883.0        9
# 120.0         9
# 160.0         8
# Name: count, dtype: int64
#
# 전년 반입량 증감률(%) (Top 10)
# 전년 반입량 증감률(%)
#  0.0     13011
# -5.1        27
# -13.7       25
# -13.5       23
# -29.6       23
# -9.9        23
# -10.8       22
# -14.5       22
# -7.7        21
# -16.4       21
# Name: count, dtype: int64
#
# 전년 금액 (Top 10)
# 전년 금액
# NaN          10014
# 20000.0          8
# 160000.0         5
# 150000.0         4
# 18000.0          4
# 30000.0          4
# 192000.0         4
# 7003400.0        3
# 119000.0         3
# 80000.0          3
# Name: count, dtype: int64
#
# 전년 금액 증감률(%) (Top 10)
# 전년 금액 증감률(%)
#  0.0     13002
# -26.2       24
# -16.5       20
# -13.0       20
# -12.2       19
# -24.7       19
# -30.3       18
# -9.5        18
# -20.0       18
# -18.0       18
# Name: count, dtype: int64
#
# 평년 반입량 (Top 10)
# 평년 반입량
# NaN       7932
# 3934.0       9
# 4543.0       7
# 4408.0       7
# 4445.0       7
# 4218.0       7
# 4061.0       6
# 3775.0       6
# 3339.0       6
# 3598.0       6
# Name: count, dtype: int64
#
# 평년 반입량 증감률(%) (Top 10)
# 평년 반입량 증감률(%)
#  0.0     11122
# -19.4       31
# -30.6       27
# -5.8        27
# -7.1        26
# -23.3       26
# -9.7        26
# -99.8       25
# -10.6       25
# -11.7       25
# Name: count, dtype: int64
#
# 평년 금액 (Top 10)
# 평년 금액
# NaN            7932
# 10828907.0        3
# 486504936.0       3
# 22057113.0        3
# 12868678.0        3
# 12888634.0        3
# 57808803.0        3
# 55992380.0        3
# 439411574.0       3
# 240139041.0       3
# Name: count, dtype: int64
#
# 평년 금액 증감률(%) (Top 10)
# 평년 금액 증감률(%)
#  0.0     11123
# -99.9       34
# -99.7       29
# -99.6       24
# -29.5       24
# -17.0       23
# -99.8       23
# -19.0       23
# -16.9       23
# -34.7       22
# Name: count, dtype: int64
#
#
#
# ================================================================================
# 파프리카 데이터 요약
# ================================================================================
#
# [info()]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18270 entries, 0 to 18269
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   거래일자           18270 non-null  object
#  1   품목명            18270 non-null  object
#  2   반입량            11853 non-null  float64
#  3   금액             11853 non-null  float64
#  4   전년 반입량         11081 non-null  float64
#  5   전년 반입량 증감률(%)  18270 non-null  float64
#  6   전년 금액          11081 non-null  float64
#  7   전년 금액 증감률(%)   18270 non-null  float64
#  8   평년 반입량         12180 non-null  float64
#  9   평년 반입량 증감률(%)  18270 non-null  float64
#  10  평년 금액          12180 non-null  float64
#  11  평년 금액 증감률(%)   18270 non-null  float64
# dtypes: float64(10), object(2)
# memory usage: 1.7+ MB
#
#
# [describe()]
#               거래일자     품목명            반입량            금액         전년 반입량  \
# count        18270   18270   11853.000000  1.185300e+04   11081.000000
# unique        3654       5            NaN           NaN            NaN
# top     2025-06-30  노랑파프리카            NaN           NaN            NaN
# freq             5    3654            NaN           NaN            NaN
# mean           NaN     NaN   21599.863073  7.499145e+07   23022.883765
# std            NaN     NaN   21493.733395  7.773617e+07   21558.645646
# min            NaN     NaN       5.000000  2.000000e+03       5.000000
# 25%            NaN     NaN    1875.000000  6.243000e+06    2270.000000
# 50%            NaN     NaN   16356.000000  5.809600e+07   21180.000000
# 75%            NaN     NaN   37645.000000  1.276998e+08   38870.000000
# max            NaN     NaN  126915.000000  7.417420e+08  126915.000000
#
#         전년 반입량 증감률(%)         전년 금액   전년 금액 증감률(%)        평년 반입량  \
# count    18270.000000  1.108100e+04   18270.000000  12180.000000
# unique            NaN           NaN            NaN           NaN
# top               NaN           NaN            NaN           NaN
# freq              NaN           NaN            NaN           NaN
# mean        30.692748  7.802441e+07      43.385041  22950.204926
# std        391.481445  7.600851e+07    1249.770456  18431.109256
# min       -100.000000  2.000000e+03    -100.000000     48.000000
# 25%         -0.800000  7.200000e+06       0.000000   3060.250000
# 50%          0.000000  7.217250e+07       0.000000  25971.000000
# 75%          0.000000  1.297015e+08       0.000000  37191.500000
# max      27275.000000  7.417420e+08  145317.500000  74316.000000
#
#         평년 반입량 증감률(%)         평년 금액  평년 금액 증감률(%)
# count    18270.000000  1.218000e+04  18270.000000
# unique            NaN           NaN           NaN
# top               NaN           NaN           NaN
# freq              NaN           NaN           NaN
# mean         7.303339  7.640177e+07     14.006842
# std         74.127874  6.216272e+07    112.831446
# min        -99.900000  8.856300e+04   -100.000000
# 25%         -7.100000  8.672023e+06      0.000000
# 50%          0.000000  8.973524e+07      0.000000
# 75%          2.600000  1.239739e+08     10.400000
# max       2112.200000  2.868816e+08   6288.800000
#
# [value_counts()]
#
# 거래일자 (Top 10)
# 거래일자
# 2025-06-30    5
# 2018-11-07    5
# 2018-11-05    5
# 2018-11-04    5
# 2018-11-03    5
# 2018-11-02    5
# 2018-11-01    5
# 2018-10-31    5
# 2018-10-30    5
# 2018-10-29    5
# Name: count, dtype: int64
#
# 품목명 (Top 10)
# 품목명
# 노랑파프리카     3654
# 녹색파프리카     3654
# 빨강파프리카     3654
# 오렌지파프리카    3654
# 청색파프리카     3654
# Name: count, dtype: int64
#
# 반입량 (Top 10)
# 반입량
# NaN      6417
# 100.0      74
# 150.0      34
# 200.0      33
# 500.0      32
# 50.0       28
# 450.0      22
# 300.0      21
# 600.0      20
# 10.0       20
# Name: count, dtype: int64
#
# 금액 (Top 10)
# 금액
# NaN          6417
# 600000.0        9
# 6000.0          7
# 430000.0        6
# 180000.0        5
# 2000.0          5
# 480000.0        5
# 1362000.0       4
# 570000.0        4
# 1340000.0       4
# Name: count, dtype: int64
#
# 전년 반입량 (Top 10)
# 전년 반입량
# NaN      7189
# 100.0      32
# 150.0      30
# 200.0      26
# 450.0      22
# 500.0      20
# 300.0      20
# 475.0      19
# 460.0      15
# 600.0      15
# Name: count, dtype: int64
#
# 전년 반입량 증감률(%) (Top 10)
# 전년 반입량 증감률(%)
#  0.0     9293
#  12.5      16
# -20.7      14
# -10.8      14
# -17.8      13
# -22.5      13
# -26.1      13
#  21.8      13
# -5.7       13
# -1.2       13
# Name: count, dtype: int64
#
# 전년 금액 (Top 10)
# 전년 금액
# NaN          7189
# 180000.0        5
# 600000.0        5
# 2380000.0       4
# 1045000.0       4
# 2165000.0       4
# 6000.0          4
# 700000.0        3
# 1440000.0       3
# 800000.0        3
# Name: count, dtype: int64
#
# 전년 금액 증감률(%) (Top 10)
# 전년 금액 증감률(%)
#  0.0     9290
# -4.3       17
# -13.9      13
# -15.4      13
# -25.0      13
# -37.6      13
# -26.2      12
# -16.9      12
# -8.3       12
# -10.4      12
# Name: count, dtype: int64
#
# 평년 반입량 (Top 10)
# 평년 반입량
# NaN        6090
# 1045.0        7
# 864.0         6
# 872.0         6
# 579.0         6
# 33385.0       6
# 1433.0        6
# 418.0         6
# 429.0         6
# 30945.0       6
# Name: count, dtype: int64
#
# 평년 반입량 증감률(%) (Top 10)
# 평년 반입량 증감률(%)
#  0.0     8329
#  4.6       18
# -0.3       17
# -24.1      16
# -26.1      16
# -16.4      16
#  2.6       15
# -4.9       15
# -4.0       15
# -32.3      15
# Name: count, dtype: int64
#
# 평년 금액 (Top 10)
# 평년 금액
# NaN            6090
# 101670953.0       3
# 140549141.0       3
# 93820249.0        3
# 94750550.0        3
# 97138190.0        3
# 124004829.0       3
# 135872293.0       3
# 129115330.0       3
# 138070308.0       3
# Name: count, dtype: int64
#
# 평년 금액 증감률(%) (Top 10)
# 평년 금액 증감률(%)
#  0.0     8331
#  6.8       19
# -10.1      19
#  9.0       18
# -2.0       17
# -0.1       17
# -13.7      17
#  14.5      17
# -13.5      16
# -3.9       16
# Name: count, dtype: int64
#
#
#
# ================================================================================
# 피망전체 데이터 요약
# ================================================================================
#
# [info()]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14616 entries, 0 to 14615
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   거래일자           14616 non-null  object
#  1   품목명            14616 non-null  object
#  2   반입량            8732 non-null   float64
#  3   금액             8733 non-null   float64
#  4   전년 반입량         8545 non-null   float64
#  5   전년 반입량 증감률(%)  14616 non-null  float64
#  6   전년 금액          8545 non-null   float64
#  7   전년 금액 증감률(%)   14616 non-null  float64
#  8   평년 반입량         10081 non-null  float64
#  9   평년 반입량 증감률(%)  14616 non-null  float64
#  10  평년 금액          10081 non-null  float64
#  11  평년 금액 증감률(%)   14616 non-null  float64
# dtypes: float64(10), object(2)
# memory usage: 1.3+ MB
#
#
# [describe()]
#               거래일자    품목명           반입량            금액        전년 반입량  \
# count        14616  14616   8732.000000  8.733000e+03   8545.000000
# unique        3654      4           NaN           NaN           NaN
# top     2025-06-30     기타           NaN           NaN           NaN
# freq             4   3654           NaN           NaN           NaN
# mean           NaN    NaN   9664.971713  3.163454e+07  10303.597074
# std            NaN    NaN  10101.395564  3.517060e+07  10478.778134
# min            NaN    NaN      2.000000  2.000000e+03      2.000000
# 25%            NaN    NaN   2002.750000  9.497700e+06   2167.000000
# 50%            NaN    NaN   4477.000000  1.777640e+07   4975.000000
# 75%            NaN    NaN  17889.250000  4.150775e+07  19160.000000
# max            NaN    NaN  72700.000000  3.123267e+08  72700.000000
#
#         전년 반입량 증감률(%)         전년 금액  전년 금액 증감률(%)        평년 반입량  \
# count    14616.000000  8.545000e+03   14616.00000  10081.000000
# unique            NaN           NaN           NaN           NaN
# top               NaN           NaN           NaN           NaN
# freq              NaN           NaN           NaN           NaN
# mean        43.482492  3.214065e+07      65.61681  10969.658367
# std        617.692002  3.583500e+07    1021.01936  10439.245926
# min        -99.600000  2.000000e+03     -99.90000     40.000000
# 25%         -0.625000  9.180000e+06       0.00000   2111.000000
# 50%          0.000000  1.839500e+07       0.00000   5701.000000
# 75%          0.000000  4.233950e+07       0.00000  21814.000000
# max      35700.000000  3.123267e+08   63204.50000  38399.000000
#
#         평년 반입량 증감률(%)         평년 금액  평년 금액 증감률(%)
# count    14616.000000  1.008100e+04  14616.000000
# unique            NaN           NaN           NaN
# top               NaN           NaN           NaN
# freq              NaN           NaN           NaN
# mean        12.898296  3.207288e+07     30.313177
# std         99.026964  3.197476e+07    158.369682
# min        -99.800000  5.400000e+04    -99.800000
# 25%        -13.500000  9.510770e+06     -3.700000
# 50%          0.000000  1.967916e+07      0.000000
# 75%          0.000000  4.632735e+07     14.900000
# max       3244.400000  1.484266e+08   6534.800000
#
# [value_counts()]
#
# 거래일자 (Top 10)
# 거래일자
# 2025-06-30    4
# 2018-11-07    4
# 2018-11-05    4
# 2018-11-04    4
# 2018-11-03    4
# 2018-11-02    4
# 2018-11-01    4
# 2018-10-31    4
# 2018-10-30    4
# 2018-10-29    4
# Name: count, dtype: int64
#
# 품목명 (Top 10)
# 품목명
# 기타      3654
# 반홍피망    3654
# 청피망     3654
# 홍피망     3654
# Name: count, dtype: int64
#
# 반입량 (Top 10)
# 반입량
# NaN       5884
# 10.0        12
# 30.0        11
# 50.0         9
# 44.0         9
# 1000.0       8
# 56.0         8
# 4.0          8
# 24.0         8
# 18.0         7
# Name: count, dtype: int64
#
# 금액 (Top 10)
# 금액
# NaN           5883
# 102000.0         4
# 6000.0           4
# 10590000.0       3
# 15000.0          3
# 124000.0         3
# 8914000.0        3
# 6225000.0        3
# 4000.0           3
# 18000.0          3
# Name: count, dtype: int64
#
# 전년 반입량 (Top 10)
# 전년 반입량
# NaN       6071
# 30.0        11
# 50.0         9
# 10.0         9
# 44.0         9
# 1000.0       8
# 4.0          8
# 24.0         8
# 56.0         8
# 36.0         7
# Name: count, dtype: int64
#
# 전년 반입량 증감률(%) (Top 10)
# 전년 반입량 증감률(%)
#  0.0     7703
# -24.0      14
# -23.6      13
# -13.8      13
# -16.9      13
# -18.1      12
# -18.2      12
# -1.2       12
# -18.4      12
# -7.7       12
# Name: count, dtype: int64
#
# 전년 금액 (Top 10)
# 전년 금액
# NaN           6071
# 102000.0         4
# 6000.0           4
# 15000.0          3
# 14170000.0       3
# 8914000.0        3
# 13200.0          3
# 6460000.0        3
# 4000.0           3
# 4590000.0        3
# Name: count, dtype: int64
#
# 전년 금액 증감률(%) (Top 10)
# 전년 금액 증감률(%)
#  0.0     7701
# -10.7      13
# -12.6      13
# -4.0       13
# -1.7       12
# -32.1      12
# -37.7      11
#  13.6      11
# -44.3      10
# -39.9      10
# Name: count, dtype: int64
#
# 평년 반입량 (Top 10)
# 평년 반입량
# NaN      4535
# 409.0      10
# 469.0       9
# 392.0       8
# 196.0       8
# 329.0       8
# 320.0       7
# 199.0       7
# 421.0       7
# 410.0       7
# Name: count, dtype: int64
#
# 평년 반입량 증감률(%) (Top 10)
# 평년 반입량 증감률(%)
#  0.0     6243
# -16.5      20
# -2.1       19
# -8.3       17
# -18.8      17
# -27.5      17
# -11.6      17
# -17.4      17
# -18.2      16
# -18.9      16
# Name: count, dtype: int64
#
# 평년 금액 (Top 10)
# 평년 금액
# NaN            4535
# 68237975.0        3
# 12455710.0        3
# 126616600.0       3
# 45890485.0        3
# 43806961.0        3
# 44016439.0        3
# 43574607.0        3
# 97982673.0        3
# 45818609.0        3
# Name: count, dtype: int64
#
# 평년 금액 증감률(%) (Top 10)
# 평년 금액 증감률(%)
#  0.0     6239
# -5.9       16
# -3.4       14
# -17.0      13
# -8.3       13
# -17.5      12
# -35.7      12
# -36.6      12
# -40.9      12
# -37.9      12
# Name: count, dtype: int64
#
#
#
# ================================================================================
# 홍고추 데이터 요약
# ================================================================================
#
# [info()]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7308 entries, 0 to 7307
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   거래일자           7308 non-null   object
#  1   품목명            7308 non-null   object
#  2   반입량            6102 non-null   float64
#  3   금액             6102 non-null   float64
#  4   전년 반입량         6110 non-null   float64
#  5   전년 반입량 증감률(%)  7308 non-null   float64
#  6   전년 금액          6110 non-null   float64
#  7   전년 금액 증감률(%)   7308 non-null   float64
#  8   평년 반입량         6787 non-null   float64
#  9   평년 반입량 증감률(%)  7308 non-null   float64
#  10  평년 금액          6787 non-null   float64
#  11  평년 금액 증감률(%)   7308 non-null   float64
# dtypes: float64(10), object(2)
# memory usage: 685.3+ KB
#
#
# [describe()]
#               거래일자      품목명            반입량            금액         전년 반입량  \
# count         7308     7308    6102.000000  6.102000e+03    6110.000000
# unique        3654        2            NaN           NaN            NaN
# top     2025-06-30  홍고추(일반)            NaN           NaN            NaN
# freq             2     3654            NaN           NaN            NaN
# mean           NaN      NaN    8684.965585  3.649751e+07    8803.986088
# std            NaN      NaN   11877.272851  3.857004e+07   12326.370403
# min            NaN      NaN      68.000000  1.102000e+05       4.000000
# 25%            NaN      NaN    2402.500000  8.887412e+06    2307.250000
# 50%            NaN      NaN    5625.000000  2.185455e+07    5542.000000
# 75%            NaN      NaN   10228.250000  5.456241e+07   10265.750000
# max            NaN      NaN  147638.000000  3.419051e+08  147638.000000
#
#         전년 반입량 증감률(%)         전년 금액  전년 금액 증감률(%)        평년 반입량  \
# count     7308.000000  6.110000e+03   7308.000000   6787.000000
# unique            NaN           NaN           NaN           NaN
# top               NaN           NaN           NaN           NaN
# freq              NaN           NaN           NaN           NaN
# mean        25.072879  3.606148e+07     19.637698   9420.889347
# std        198.222456  3.875302e+07    200.266292  11881.006406
# min        -93.800000  1.000000e+04    -97.500000    160.000000
# 25%        -18.525000  8.258612e+06    -17.700000   2363.000000
# 50%          0.000000  2.176702e+07      0.000000   6045.000000
# 75%         18.900000  5.338642e+07     20.750000  10371.000000
# max      10100.000000  3.419051e+08  14600.000000  85981.000000
#
#         평년 반입량 증감률(%)         평년 금액  평년 금액 증감률(%)
# count     7308.000000  6.787000e+03   7308.000000
# unique            NaN           NaN           NaN
# top               NaN           NaN           NaN
# freq              NaN           NaN           NaN
# mean        12.745991  3.524360e+07     19.922345
# std         98.167407  3.287934e+07     64.037076
# min        -90.600000  9.190400e+05    -94.700000
# 25%        -20.700000  7.769042e+06    -12.400000
# 50%          0.000000  2.622686e+07      0.000000
# 75%         17.825000  5.588294e+07     36.700000
# max       3892.500000  2.155934e+08    670.000000
#
# [value_counts()]
#
# 거래일자 (Top 10)
# 거래일자
# 2025-06-30    2
# 2018-11-07    2
# 2018-11-05    2
# 2018-11-04    2
# 2018-11-03    2
# 2018-11-02    2
# 2018-11-01    2
# 2018-10-31    2
# 2018-10-30    2
# 2018-10-29    2
# Name: count, dtype: int64
#
# 품목명 (Top 10)
# 품목명
# 홍고추(일반)    3654
# 홍청양        3654
# Name: count, dtype: int64
#
# 반입량 (Top 10)
# 반입량
# NaN       1206
# 1834.0       6
# 1168.0       6
# 1112.0       6
# 835.0        5
# 1923.0       4
# 469.0        4
# 727.0        4
# 1461.0       4
# 1630.0       4
# Name: count, dtype: int64
#
# 금액 (Top 10)
# 금액
# NaN          1206
# 5056000.0       2
# 2376300.0       2
# 4361000.0       2
# 9916300.0       2
# 3719500.0       2
# 6407000.0       2
# 2080600.0       2
# 5675500.0       2
# 8871300.0       2
# Name: count, dtype: int64
#
# 전년 반입량 (Top 10)
# 전년 반입량
# NaN       1198
# 1112.0       6
# 1168.0       6
# 1525.0       5
# 1461.0       4
# 794.0        4
# 1402.0       4
# 1202.0       4
# 3979.0       4
# 1923.0       4
# Name: count, dtype: int64
#
# 전년 반입량 증감률(%) (Top 10)
# 전년 반입량 증감률(%)
#  0.0     2314
# -20.1      14
# -8.8       11
# -15.0      11
# -20.9      10
# -29.7      10
# -18.8      10
# -14.5      10
# -29.5      10
# -39.4       9
# Name: count, dtype: int64
#
# 전년 금액 (Top 10)
# 전년 금액
# NaN           1198
# 5056000.0        2
# 30684200.0       2
# 26422400.0       2
# 2080600.0        2
# 2770500.0        2
# 8871300.0        2
# 3130500.0        2
# 4361000.0        2
# 6407000.0        2
# Name: count, dtype: int64
#
# 전년 금액 증감률(%) (Top 10)
# 전년 금액 증감률(%)
#  0.0     2316
# -34.4      11
# -25.9      11
# -24.7      10
# -13.5      10
# -38.4      10
# -16.1      10
# -24.5      10
# -11.4       9
# -16.9       9
# Name: count, dtype: int64
#
# 평년 반입량 (Top 10)
# 평년 반입량
# NaN       521
# 1354.0      7
# 6306.0      7
# 1016.0      6
# 1604.0      6
# 1391.0      6
# 1258.0      6
# 1356.0      6
# 6487.0      6
# 1430.0      6
# Name: count, dtype: int64
#
# 평년 반입량 증감률(%) (Top 10)
# 평년 반입량 증감률(%)
#  0.0     1648
# -20.2      14
# -21.4      13
# -25.7      13
#  5.0       12
# -11.8      12
# -3.1       11
# -14.0      11
#  2.7       11
# -9.1       10
# Name: count, dtype: int64
#
# 평년 금액 (Top 10)
# 평년 금액
# NaN           521
# 96720196.0      3
# 17203958.0      3
# 19275720.0      3
# 21123609.0      3
# 22380623.0      3
# 50271033.0      3
# 37736435.0      3
# 23499731.0      3
# 22608403.0      3
# Name: count, dtype: int64
#
# 평년 금액 증감률(%) (Top 10)
# 평년 금액 증감률(%)
#  0.0     1646
# -1.1       12
# -2.9       12
# -18.6      10
# -34.2      10
# -9.5       10
# -3.6       10
# -22.7      10
# -23.8       9
#  4.0        9
# Name: count, dtype: int64

# %%
# 필요한 모듈 import
import warnings
import logging
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 1. 모든 경고 무시
warnings.filterwarnings('ignore')

# 2. matplotlib 로깅 끄기
matplotlib.set_loglevel('ERROR')
logging.getLogger('matplotlib').setLevel(logging.ERROR)
logging.getLogger('matplotlib.font_manager').setLevel(logging.ERROR)

# 3. 안전한 폰트 설정 (시스템에 확실히 있는 폰트만)
plt.rcParams['font.family'] = 'DejaVu Sans'
plt.rcParams['axes.unicode_minus'] = False

# 4. 기타 matplotlib 설정
plt.rcParams.update({'figure.max_open_warning': 0})

print("✅ 모든 경고 메시지 제거 완료!")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from math import ceil

# 한글 폰트 설정 (선택사항)
plt.rcParams['font.family'] = ['Apple SD Gothic Neo', 'Malgun Gothic', 'NanumGothic', 'sans-serif']
plt.rcParams['axes.unicode_minus'] = False
# Out:
# ✅ 모든 경고 메시지 제거 완료!

# %%
# =========================================================
# 1) 데이터 로딩 (질문에서 주신 경로 그대로)
# =========================================================

name_map = {
    "당근": carrot_price,
    "대파": bigpa_price,
    "마늘": galic_price,
    "양파": onion_price,
    "청고추": greenpeper_price,
    "파프리카": paprica_price,
    "피망전체": allpeemang_price,
    "홍고추": redpeper_price,
}

# =========================================================
# 2) Long 결합 (품목명 보존)
# =========================================================
long_list = []
for item, df in name_map.items():
    tmp = df.copy()
    assert '거래일자' in tmp.columns, f"{item}: '거래일자' 컬럼 필요"
    tmp['거래일자'] = pd.to_datetime(tmp['거래일자'], errors='coerce')

    # 숫자형 변환
    for col in ['금액','반입량','전년 금액','전년 반입량','평년 금액','평년 반입량']:
        if col in tmp.columns:
            tmp[col] = pd.to_numeric(tmp[col], errors='coerce')

    # 품목/품목명 보존
    tmp['품목'] = item
    if '품목명' not in tmp.columns:
        tmp['품목명'] = item

    long_list.append(tmp)

long_df = pd.concat(long_list, ignore_index=True)

# 사용 컬럼
use_cols = ['거래일자','품목','품목명'] + [c for c in ['금액','반입량'] if c in long_df.columns]
df_use = long_df[use_cols].dropna(subset=['거래일자']).copy()
df_use['연도'] = df_use['거래일자'].dt.year

# =========================================================
# 3) 시각화 유틸 (모든 품목 재활용 가능)
#    - 히트맵: 검정=결측률 낮음 / 흰=결측률 높음  (cmap='Greys')
# =========================================================
def _prep_item(df_all, target_item):
    assert {'거래일자','품목','품목명','연도'}.issubset(df_all.columns)
    return df_all[df_all['품목'] == target_item].copy()

def plot_subitem_year_missing_heatmap_for_item(
    df_all, target_item, value_col, last_n_years=10, cmap='Greys'
):
    df = _prep_item(df_all, target_item)
    if value_col not in df.columns:
        print(f"⚠ '{value_col}' 없음 → 히트맵 생략")
        return

    grp = (df.assign(결측=lambda x: x[value_col].isna().astype(int))
             .groupby(['품목명','연도'], as_index=False)['결측'].mean())
    grp['결측률(%)'] = grp['결측'] * 100

    years = sorted(grp['연도'].dropna().unique())
    if last_n_years and len(years) > last_n_years:
        years = years[-last_n_years:]
    grp = grp[grp['연도'].isin(years)]

    pivot_tbl = (grp.pivot(index='품목명', columns='연도', values='결측률(%)')
                   .loc[sorted(grp['품목명'].unique()), years])

    fig, ax = plt.subplots(figsize=(1.0 + 0.35*len(years), 1.0 + 0.4*len(pivot_tbl.index)))
    c = ax.pcolor(pivot_tbl.values, cmap=cmap)  # Greys: 낮음=검정, 높음=흰
    fig.colorbar(c, ax=ax, label='결측률(%)')
    ax.set_xticks(np.arange(pivot_tbl.shape[1]) + 0.5)
    ax.set_yticks(np.arange(pivot_tbl.shape[0]) + 0.5)
    ax.set_xticklabels(pivot_tbl.columns, rotation=45, ha='right')
    ax.set_yticklabels(pivot_tbl.index)
    ax.set_title(f"[{target_item}] 세부 품목명 × 연도 결측률 히트맵 - {value_col} (검정=낮음, 흰=높음)")
    plt.tight_layout(); plt.show()

def plot_subitem_year_bars_for_item(
    df_all, target_item, value_col, last_n_years=10
):
    df = _prep_item(df_all, target_item)
    if value_col not in df.columns:
        print(f"⚠ '{value_col}' 없음 → 막대그래프 생략")
        return

    sub_items = sorted(df['품목명'].dropna().unique())
    if not sub_items:
        print("⚠ 세부 품목명이 없습니다."); return

    n = len(sub_items)
    ncols = 3 if n >= 7 else (2 if n >= 3 else 1)
    nrows = ceil(n / ncols)

    fig, axes = plt.subplots(nrows=nrows, ncols=ncols,
                             figsize=(4.2*ncols, 3.6*nrows), squeeze=False)
    axes = axes.flatten()

    for i, sub_name in enumerate(sub_items):
        ax = axes[i]
        sub = df[df['품목명'] == sub_name]
        ser = sub.groupby('연도')[value_col].apply(lambda x: x.isna().mean()*100).sort_index()
        if last_n_years and len(ser.index) > last_n_years:
            ser = ser.iloc[-last_n_years:]
        ax.bar(ser.index.astype(str), ser.values)
        ax.set_title(f"{sub_name} - {value_col} 결측률(%)")
        ax.set_ylim(0, 100)
        ax.set_ylabel("결측률(%)"); ax.set_xlabel("연도")
        ax.set_xticklabels(ser.index.astype(str), rotation=45, ha='right')

    for j in range(i+1, len(axes)): fig.delaxes(axes[j])
    fig.suptitle(f"[{target_item}] 세부 품목명별 연도 결측률 - {value_col}", y=1.02, fontsize=13)
    plt.tight_layout(); plt.show()

def plot_year_matrix_by_subitem_for_item(
    df_all, target_item, cols=('금액','반입량'), last_n_years=10, max_rows_per_year=4000
):
    df = _prep_item(df_all, target_item)
    cols = [c for c in cols if c in df.columns]
    if not cols:
        print("⚠ 표시할 수 있는 수치 컬럼이 없습니다."); return

    for sub_name in sorted(df['품목명'].dropna().unique()):
        df_sub = df[df['품목명'] == sub_name]
        years = sorted(df_sub['연도'].dropna().unique())
        if last_n_years and len(years) > last_n_years: years = years[-last_n_years:]
        for yr in years:
            sub = df_sub[df_sub['연도'] == yr].sort_values('거래일자')
            if len(sub) == 0: continue
            mat = sub[cols].isna().astype(int).values.T
            if mat.shape[1] > max_rows_per_year:
                idx = np.linspace(0, mat.shape[1]-1, max_rows_per_year).astype(int)
                mat = mat[:, idx]

            fig, ax = plt.subplots(figsize=(10, 1.0 + 0.4*len(cols)))
            ax.imshow(mat, aspect='auto', interpolation='nearest', cmap='Greys')
            ax.set_title(f"[{target_item}] {sub_name} - {yr}년 결측 패턴 (흰=정상, 검=결측)")
            ax.set_yticks(np.arange(len(cols))); ax.set_yticklabels(cols); ax.set_xticks([])
            plt.tight_layout(); plt.show()

def run_missing_visuals_for_item(
    df_all, target_item, cols=("금액","반입량"), last_n_years=10, show_matrix=False
):
    for col in cols:
        plot_subitem_year_missing_heatmap_for_item(df_all, target_item, col, last_n_years, cmap='Greys')
    for col in cols:
        plot_subitem_year_bars_for_item(df_all, target_item, col, last_n_years)
    if show_matrix:
        plot_year_matrix_by_subitem_for_item(df_all, target_item, cols, last_n_years)

# =========================================================
# 4) (옵션) 주간 평균가격(월~일, 일요일 종료) 계산 유틸
#     - 주간총금액 / 주간총반입량
#     - 금액/반입량 둘 다 존재하는 날만 집계(왜곡 방지)
# =========================================================
def weekly_price_for_item(
    df_all, target_item, by='품목명', week='W-SUN'  # 월요일 시작~일요일 종료
):
    assert by in ('품목','품목명')
    df = _prep_item(df_all, target_item)
    df_valid = df.dropna(subset=['금액','반입량']).set_index('거래일자')

    grp_cols = [by]
    weekly = (df_valid
              .groupby(grp_cols)
              .resample(week, label='right', closed='right')
              .agg(주간총금액=('금액','sum'), 주간총반입량=('반입량','sum'))
              .reset_index())
    weekly['주간단가'] = weekly['주간총금액'] / weekly['주간총반입량']
    return weekly  # 필요 시 pivot도 가능

# =========================================================
# 5) 실행: 모든 품목 동일 루틴
# =========================================================
items_to_run = list(name_map.keys())   # 전 품목
# items_to_run = ["감자","고구마","토마토"]  # 일부만 테스트할 때

for it in items_to_run:
    print(f"\n=== {it} 결측 시각화 ===")
    run_missing_visuals_for_item(df_use, it, cols=("금액","반입량"), last_n_years=10, show_matrix=False)

# (옵션) 주간단가 예시: 감자 세부품목별
# weekly_potato = weekly_price_for_item(df_use, "감자", by='품목명', week='W-SUN')
# display(weekly_potato.head())
# Out:
# === 당근 결측 시각화 ===
# === 대파 결측 시각화 ===
# === 마늘 결측 시각화 ===
# === 양파 결측 시각화 ===
# === 청고추 결측 시각화 ===
# === 파프리카 결측 시각화 ===
# === 피망전체 결측 시각화 ===
# === 홍고추 결측 시각화 ===
