# %%
# -*- coding: utf-8 -*-
"""
4개 품목(마늘, 생강, 양배추, 양파) 기초통계량 일괄 출력
"""

import pandas as pd
from io import StringIO

# ---------- 1) CSV 로더 ----------
def load_csv_safe(path: str) -> pd.DataFrame:
    encodings = ["utf-8-sig", "cp949", "utf-8"]
    last_err = None
    for enc in encodings:
        try:
            df = pd.read_csv(path, encoding=enc)
            break
        except Exception as e:
            last_err = e
            df = None
    if df is None:
        raise RuntimeError(f"CSV 로딩 실패: {path} (마지막 에러: {last_err})")

    # 컬럼명 정리
    df.columns = (
        df.columns.astype(str)
        .str.replace(r"\s+", " ", regex=True)
        .str.strip()
    )

    # '거래일자' 같은 날짜 컬럼 자동 변환
    date_cols = [c for c in df.columns if "거래일자" in c]
    for dc in date_cols:
        df[dc] = pd.to_datetime(df[dc], errors="coerce")

    return df

# ---------- 2) 파일 불러오기 ----------
garlic  = load_csv_safe("garlic.csv")
ginger  = load_csv_safe("ginger.csv")
cabbage = load_csv_safe("cabbage.csv")
onion   = load_csv_safe("onion.csv")

data_dict = {
    "마늘(garlic)": garlic,
    "생강(ginger)": ginger,
    "양배추(cabbage)": cabbage,
    "양파(onion)": onion,
}

# ---------- 3) 결측치 요약 함수 ----------
def na_summary(df: pd.DataFrame) -> pd.DataFrame:
    na_cnt = df.isna().sum()
    na_ratio = (na_cnt / len(df)) * 100 if len(df) > 0 else 0
    return pd.DataFrame({
        "na_count": na_cnt,
        "na_ratio_%": na_ratio
    }).sort_values(by="na_count", ascending=False)

# ---------- 4) 루프 실행 ----------
for name, df in data_dict.items():
    print("=" * 100)
    print(f"[{name}] 데이터 요약")
    print("=" * 100)

    # info() 출력
    buf = StringIO()
    df.info(buf=buf)
    info_str = buf.getvalue()
    print("\n[info()]")
    print(info_str)

    # describe(all)
    print("\n[describe(include='all')]")
    try:
        desc = df.describe(include="all", datetime_is_numeric=True)
    except TypeError:
        desc = df.describe(include="all")
    print(desc)

    # 결측치 요약
    print("\n[결측치 요약]")
    print(na_summary(df))

    # 각 컬럼 value_counts Top10
    print("\n[value_counts(Top 10 by column)]")
    for col in df.columns:
        try:
            vc = df[col].value_counts(dropna=False).head(10)
            print(f"\n- {col} (Top 10)")
            print(vc)
        except Exception as e:
            print(f"- {col}: value_counts 불가 ({e})")

    print("\n\n")
# Out:
# ====================================================================================================
# [마늘(garlic)] 데이터 요약
# ====================================================================================================
#
# [info()]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10962 entries, 0 to 10961
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   거래일자           10962 non-null  datetime64[ns]
#  1   품목명            10962 non-null  object
#  2   반입량            1193 non-null   float64
#  3   금액             1200 non-null   float64
#  4   전년 반입량         677 non-null    float64
#  5   전년 반입량 증감률(%)  10962 non-null  float64
#  6   전년 금액          693 non-null    float64
#  7   전년 금액 증감률(%)   10962 non-null  float64
#  8   평년 반입량         1106 non-null   float64
#  9   평년 반입량 증감률(%)  10962 non-null  float64
#  10  평년 금액          1127 non-null   float64
#  11  평년 금액 증감률(%)   10962 non-null  float64
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 1.0+ MB
#
#
# [describe(include='all')]
#                        거래일자     품목명           반입량            금액         전년 반입량  전년 반입량 증감률(%)         전년 금액  \
# count                 10962   10962  1.193000e+03  1.200000e+03     677.000000   10962.000000  6.930000e+02
# unique                  NaN       3           NaN           NaN            NaN            NaN           NaN
# top                     NaN  저장형 난지           NaN           NaN            NaN            NaN           NaN
# freq                    NaN    3654           NaN           NaN            NaN            NaN           NaN
# mean    2020-06-29 12:00:00     NaN  6.379848e+03  1.764893e+07    6363.813885     121.718290  1.910272e+07
# min     2015-06-30 00:00:00     NaN -4.525800e+05 -2.522400e+08       1.000000    -100.000000 -6.320000e+05
# 25%     2017-12-29 00:00:00     NaN  2.400000e+01  9.287500e+04      36.000000       0.000000  1.425000e+05
# 50%     2020-06-29 12:00:00     NaN  4.800000e+02  1.447000e+06     514.000000       0.000000  2.111400e+06
# 75%     2022-12-30 00:00:00     NaN  2.655000e+03  9.800000e+06    3500.000000       0.000000  1.376800e+07
# max     2025-06-30 00:00:00     NaN  1.260920e+06  6.694500e+08  425000.000000  457100.000000  6.323400e+08
# std                     NaN     NaN  4.442048e+04  5.977460e+07   22786.427642    6267.180275  5.740671e+07
#
#          전년 금액 증감률(%)        평년 반입량  평년 반입량 증감률(%)         평년 금액  평년 금액 증감률(%)
# count    10962.000000   1106.000000   10962.000000  1.127000e+03  10962.000000
# unique            NaN           NaN            NaN           NaN           NaN
# top               NaN           NaN            NaN           NaN           NaN
# freq              NaN           NaN            NaN           NaN           NaN
# mean        40.750821   3886.869801     114.876409  1.238173e+07     33.344171
# min     -18600.000000      3.000000    -406.000000  1.909200e+04   -452.400000
# 25%          0.000000    217.000000       0.000000  5.439515e+05      0.000000
# 50%          0.000000   1186.000000       0.000000  4.737500e+06      0.000000
# 75%          0.000000   4302.000000       0.000000  1.473006e+07      0.000000
# max     135435.100000  85326.000000  342800.000000  1.879558e+08  69470.500000
# std       1774.433185   7814.573272    5344.396242  2.094647e+07   1177.151743
#
# [결측치 요약]
#                na_count  na_ratio_%
# 전년 반입량            10285   93.824120
# 전년 금액             10269   93.678161
# 평년 반입량             9856   89.910600
# 평년 금액              9835   89.719029
# 반입량                9769   89.116949
# 금액                 9762   89.053093
# 거래일자                  0    0.000000
# 품목명                   0    0.000000
# 전년 반입량 증감률(%)         0    0.000000
# 전년 금액 증감률(%)          0    0.000000
# 평년 반입량 증감률(%)         0    0.000000
# 평년 금액 증감률(%)          0    0.000000
#
# [value_counts(Top 10 by column)]
#
# - 거래일자 (Top 10)
# 거래일자
# 2025-06-30    3
# 2018-11-07    3
# 2018-11-05    3
# 2018-11-04    3
# 2018-11-03    3
# 2018-11-02    3
# 2018-11-01    3
# 2018-10-31    3
# 2018-10-30    3
# 2018-10-29    3
# Name: count, dtype: int64
#
# - 품목명 (Top 10)
# 품목명
# 저장형 난지    3654
# 저장형 대서    3654
# 저장형 한지    3654
# Name: count, dtype: int64
#
# - 반입량 (Top 10)
# 반입량
# NaN       9769
# 1000.0      50
# 3.0         47
# 1.0         35
# 2.0         31
# 5.0         25
# 4.0         25
# 500.0       23
# 2000.0      22
# 6.0         22
# Name: count, dtype: int64
#
# - 금액 (Top 10)
# 금액
# NaN           9762
# 17760.0         43
# 5920.0          28
# 11840.0         27
# 29600.0         24
# 23680.0         22
# 35520.0         17
# 5000000.0       12
# 10000000.0      10
# 6500000.0        9
# Name: count, dtype: int64
#
# - 전년 반입량 (Top 10)
# 전년 반입량
# NaN       10285
# 1000.0       24
# 1.0          24
# 3.0          22
# 2.0          17
# 5.0          13
# 4.0          12
# 500.0        12
# 2000.0       11
# 24.0          9
# Name: count, dtype: int64
#
# - 전년 반입량 증감률(%) (Top 10)
# 전년 반입량 증감률(%)
#  0.0      10642
#  100.0        8
#  200.0        4
# -50.0         4
# -98.8         3
# -99.6         3
# -99.9         3
# -100.0        3
# -99.7         3
# -99.5         3
# Name: count, dtype: int64
#
# - 전년 금액 (Top 10)
# 전년 금액
# NaN          10269
# 17760.0         21
# 5920.0          17
# 11840.0         13
# 29600.0         11
# 23680.0         10
# 35520.0          8
# 5980.0           7
# 5000000.0        4
# 11960.0          4
# Name: count, dtype: int64
#
# - 전년 금액 증감률(%) (Top 10)
# 전년 금액 증감률(%)
#  0.0      10634
# -99.9         5
# -70.0         3
# -99.5         3
# -99.2         3
#  100.0        3
# -88.9         2
# -97.8         2
# -97.5         2
#  197.0        2
# Name: count, dtype: int64
#
# - 평년 반입량 (Top 10)
# 평년 반입량
# NaN      9856
# 4.0        31
# 5.0        11
# 62.0        6
# 20.0        6
# 220.0       6
# 33.0        5
# 34.0        4
# 3.0         4
# 213.0       4
# Name: count, dtype: int64
#
# - 평년 반입량 증감률(%) (Top 10)
# 평년 반입량 증감률(%)
#  0.0      10463
# -99.9        15
# -99.7         9
# -100.0        9
# -99.3         8
# -99.5         7
# -99.8         6
# -99.6         5
# -97.0         4
# -98.5         4
# Name: count, dtype: int64
#
# - 평년 금액 (Top 10)
# 평년 금액
# NaN           9835
# 21904.0          4
# 26048.0          4
# 8366445.0        3
# 560000.0         3
# 617500.0         3
# 7000000.0        3
# 20891000.0       3
# 13248000.0       2
# 1627645.0        2
# Name: count, dtype: int64
#
# - 평년 금액 증감률(%) (Top 10)
# 평년 금액 증감률(%)
#  0.0      10454
# -99.7        14
# -99.9        12
# -99.8         9
# -100.0        8
# -99.5         8
# -99.4         6
# -99.6         5
# -98.0         5
# -98.5         5
# Name: count, dtype: int64
#
#
#
# ====================================================================================================
# [생강(ginger)] 데이터 요약
# ====================================================================================================
#
# [info()]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7308 entries, 0 to 7307
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   거래일자           7308 non-null   datetime64[ns]
#  1   품목명            7308 non-null   object
#  2   반입량            1753 non-null   float64
#  3   금액             1753 non-null   float64
#  4   전년 반입량         949 non-null    float64
#  5   전년 반입량 증감률(%)  7308 non-null   float64
#  6   전년 금액          949 non-null    float64
#  7   전년 금액 증감률(%)   7308 non-null   float64
#  8   평년 반입량         943 non-null    float64
#  9   평년 반입량 증감률(%)  7308 non-null   float64
#  10  평년 금액          943 non-null    float64
#  11  평년 금액 증감률(%)   7308 non-null   float64
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 685.3+ KB
#
#
# [describe(include='all')]
#                        거래일자   품목명          반입량            금액       전년 반입량  전년 반입량 증감률(%)         전년 금액  전년 금액 증감률(%)  \
# count                  7308  7308  1753.000000  1.753000e+03   949.000000    7308.000000  9.490000e+02   7308.000000
# unique                  NaN     2          NaN           NaN          NaN            NaN           NaN           NaN
# top                     NaN    구강          NaN           NaN          NaN            NaN           NaN           NaN
# freq                    NaN  3654          NaN           NaN          NaN            NaN           NaN           NaN
# mean    2020-06-29 12:00:00   NaN   420.255562  8.738527e+05   494.160169      11.712822  7.469198e+05     38.321045
# min     2015-06-30 00:00:00   NaN     2.000000  1.600000e+03     2.000000     -99.400000  1.600000e+03    -99.600000
# 25%     2017-12-29 00:00:00   NaN    40.000000  5.500000e+04    50.000000       0.000000  4.500000e+04      0.000000
# 50%     2020-06-29 12:00:00   NaN   110.000000  1.914000e+05   150.000000       0.000000  1.662500e+05      0.000000
# 75%     2022-12-30 00:00:00   NaN   388.000000  7.341000e+05   503.000000       0.000000  7.122000e+05      0.000000
# max     2025-06-30 00:00:00   NaN  6908.000000  1.608335e+07  6908.000000    9666.700000  1.608335e+07  26633.300000
# std                     NaN   NaN   765.912598  1.790346e+06   848.285322     190.382586  1.543790e+06    521.651661
#
#              평년 반입량  평년 반입량 증감률(%)         평년 금액  평년 금액 증감률(%)
# count    943.000000    7308.000000  9.430000e+02   7308.000000
# unique          NaN            NaN           NaN           NaN
# top             NaN            NaN           NaN           NaN
# freq            NaN            NaN           NaN           NaN
# mean     353.119830       6.951546  5.756663e+05     10.183347
# min       15.000000     -98.600000  1.743600e+04    -98.100000
# 25%       67.500000       0.000000  9.155150e+04      0.000000
# 50%      118.000000       0.000000  1.771420e+05      0.000000
# 75%      369.500000       0.000000  5.603750e+05      0.000000
# max     3278.000000    2847.400000  4.443928e+06   3271.200000
# std      539.866404      67.382542  9.147914e+05    100.890338
#
# [결측치 요약]
#                na_count  na_ratio_%
# 평년 반입량             6365   87.096333
# 평년 금액              6365   87.096333
# 전년 반입량             6359   87.014231
# 전년 금액              6359   87.014231
# 반입량                5555   76.012589
# 금액                 5555   76.012589
# 거래일자                  0    0.000000
# 품목명                   0    0.000000
# 전년 반입량 증감률(%)         0    0.000000
# 전년 금액 증감률(%)          0    0.000000
# 평년 반입량 증감률(%)         0    0.000000
# 평년 금액 증감률(%)          0    0.000000
#
# [value_counts(Top 10 by column)]
#
# - 거래일자 (Top 10)
# 거래일자
# 2025-06-30    2
# 2018-11-07    2
# 2018-11-05    2
# 2018-11-04    2
# 2018-11-03    2
# 2018-11-02    2
# 2018-11-01    2
# 2018-10-31    2
# 2018-10-30    2
# 2018-10-29    2
# Name: count, dtype: int64
#
# - 품목명 (Top 10)
# 품목명
# 구강    3654
# 재강    3654
# Name: count, dtype: int64
#
# - 반입량 (Top 10)
# 반입량
# NaN      5555
# 20.0      163
# 40.0      113
# 10.0       80
# 60.0       68
# 30.0       54
# 80.0       37
# 70.0       31
# 50.0       31
# 100.0      31
# Name: count, dtype: int64
#
# - 금액 (Top 10)
# 금액
# NaN        5555
# 60000.0      22
# 20000.0      18
# 30000.0      17
# 40000.0      16
# 48000.0      14
# 10000.0      14
# 52000.0      13
# 56000.0      12
# 24000.0      12
# Name: count, dtype: int64
#
# - 전년 반입량 (Top 10)
# 전년 반입량
# NaN      6359
# 20.0       73
# 40.0       44
# 60.0       34
# 80.0       23
# 120.0      21
# 10.0       20
# 140.0      19
# 30.0       17
# 100.0      17
# Name: count, dtype: int64
#
# - 전년 반입량 증감률(%) (Top 10)
# 전년 반입량 증감률(%)
#  0.0      6700
# -50.0        7
# -83.3        7
# -66.7        6
#  50.0        6
#  100.0       5
#  133.3       5
# -42.9        4
# -75.0        4
#  400.0       4
# Name: count, dtype: int64
#
# - 전년 금액 (Top 10)
# 전년 금액
# NaN        6359
# 10000.0      13
# 60000.0      12
# 30000.0      10
# 6000.0        9
# 4000.0        9
# 40000.0       9
# 3000.0        9
# 15000.0       8
# 12000.0       8
# Name: count, dtype: int64
#
# - 전년 금액 증감률(%) (Top 10)
# 전년 금액 증감률(%)
#  0.0      6689
# -90.9        4
# -94.1        4
# -80.0        3
# -46.7        3
# -91.3        3
# -71.4        3
# -77.5        3
# -51.3        3
#  200.0       3
# Name: count, dtype: int64
#
# - 평년 반입량 (Top 10)
# 평년 반입량
# NaN     6365
# 84.0      16
# 67.0      14
# 55.0      14
# 50.0      13
# 63.0      12
# 70.0      11
# 52.0      10
# 73.0       9
# 42.0       9
# Name: count, dtype: int64
#
# - 평년 반입량 증감률(%) (Top 10)
# 평년 반입량 증감률(%)
#  0.0     6657
# -60.0       5
#  6.3        4
#  39.5       4
# -83.1       3
# -78.3       3
# -38.3       3
# -18.4       3
# -67.2       3
# -32.2       3
# Name: count, dtype: int64
#
# - 평년 금액 (Top 10)
# 평년 금액
# NaN          6365
# 486580.0        2
# 2904000.0       2
# 2429477.0       2
# 2050635.0       2
# 1657245.0       2
# 1506015.0       2
# 1244108.0       2
# 1064198.0       2
# 1048510.0       2
# Name: count, dtype: int64
#
# - 평년 금액 증감률(%) (Top 10)
# 평년 금액 증감률(%)
#  0.0     6653
# -68.4       3
# -48.0       2
#  27.3       2
# -62.1       2
#  88.5       2
# -87.6       2
# -86.0       2
# -87.9       2
# -96.7       2
# Name: count, dtype: int64
#
#
#
# ====================================================================================================
# [양배추(cabbage)] 데이터 요약
# ====================================================================================================
#
# [info()]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3654 entries, 0 to 3653
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   거래일자           3654 non-null   datetime64[ns]
#  1   품목명            3654 non-null   object
#  2   반입량            236 non-null    float64
#  3   금액             236 non-null    float64
#  4   전년 반입량         135 non-null    float64
#  5   전년 반입량 증감률(%)  3654 non-null   float64
#  6   전년 금액          135 non-null    float64
#  7   전년 금액 증감률(%)   3654 non-null   float64
#  8   평년 반입량         101 non-null    float64
#  9   평년 반입량 증감률(%)  3654 non-null   float64
#  10  평년 금액          101 non-null    float64
#  11  평년 금액 증감률(%)   3654 non-null   float64
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 342.7+ KB
#
#
# [describe(include='all')]
#                        거래일자    품목명           반입량            금액         전년 반입량  전년 반입량 증감률(%)         전년 금액  \
# count                  3654   3654     236.00000  2.360000e+02     135.000000    3654.000000  1.350000e+02
# unique                  NaN      1           NaN           NaN            NaN            NaN           NaN
# top                     NaN  저장양배추           NaN           NaN            NaN            NaN           NaN
# freq                    NaN   3654           NaN           NaN            NaN            NaN           NaN
# mean    2020-06-29 12:00:00    NaN   73801.59322  7.789762e+07  100178.370370       0.268172  1.066436e+08
# min     2015-06-30 00:00:00    NaN    2352.00000  8.982000e+05    6144.000000     -96.800000  2.255000e+06
# 25%     2017-12-29 06:00:00    NaN   16188.00000  8.433075e+06   55036.000000       0.000000  3.192210e+07
# 50%     2020-06-29 12:00:00    NaN   61932.00000  4.038680e+07   94496.000000       0.000000  6.878800e+07
# 75%     2022-12-29 18:00:00    NaN  109952.00000  9.712692e+07  133248.000000       0.000000  1.336934e+08
# max     2025-06-30 00:00:00    NaN  243312.00000  4.974305e+08  243312.000000    1105.700000  4.974305e+08
# std                     NaN    NaN   62811.89844  1.005084e+08   58667.671914      28.933775  1.134631e+08
#
#         전년 금액 증감률(%)         평년 반입량  평년 반입량 증감률(%)         평년 금액  평년 금액 증감률(%)
# count    3654.000000     101.000000    3654.000000  1.010000e+02   3654.000000
# unique           NaN            NaN            NaN           NaN           NaN
# top              NaN            NaN            NaN           NaN           NaN
# freq             NaN            NaN            NaN           NaN           NaN
# mean        2.213684   89078.217822      -0.070170  7.252241e+07      1.890038
# min       -99.300000   27618.000000     -95.000000  1.728292e+07    -92.900000
# 25%         0.000000   73526.000000       0.000000  5.411137e+07      0.000000
# 50%         0.000000   86390.000000       0.000000  6.957229e+07      0.000000
# 75%         0.000000  112313.000000       0.000000  8.819470e+07      0.000000
# max      3350.100000  144974.000000     220.100000  1.885400e+08    829.200000
# std        62.972168   29453.901656      10.435969  3.457042e+07     30.241687
#
# [결측치 요약]
#                na_count  na_ratio_%
# 평년 반입량             3553   97.235906
# 평년 금액              3553   97.235906
# 전년 반입량             3519   96.305419
# 전년 금액              3519   96.305419
# 반입량                3418   93.541325
# 금액                 3418   93.541325
# 거래일자                  0    0.000000
# 품목명                   0    0.000000
# 전년 반입량 증감률(%)         0    0.000000
# 전년 금액 증감률(%)          0    0.000000
# 평년 반입량 증감률(%)         0    0.000000
# 평년 금액 증감률(%)          0    0.000000
#
# [value_counts(Top 10 by column)]
#
# - 거래일자 (Top 10)
# 거래일자
# 2025-06-30    1
# 2018-11-07    1
# 2018-11-05    1
# 2018-11-04    1
# 2018-11-03    1
# 2018-11-02    1
# 2018-11-01    1
# 2018-10-31    1
# 2018-10-30    1
# 2018-10-29    1
# Name: count, dtype: int64
#
# - 품목명 (Top 10)
# 품목명
# 저장양배추    3654
# Name: count, dtype: int64
#
# - 반입량 (Top 10)
# 반입량
# NaN        3418
# 8640.0        7
# 28800.0       4
# 5760.0        3
# 12320.0       2
# 6160.0        2
# 17760.0       2
# 98592.0       2
# 11520.0       2
# 11488.0       2
# Name: count, dtype: int64
#
# - 금액 (Top 10)
# 금액
# NaN           3418
# 1722000.0        2
# 9240000.0        2
# 3114000.0        2
# 22290000.0       1
# 17903000.0       1
# 25512000.0       1
# 33226000.0       1
# 18086000.0       1
# 27065000.0       1
# Name: count, dtype: int64
#
# - 전년 반입량 (Top 10)
# 전년 반입량
# NaN         3519
# 28800.0        2
# 98592.0        2
# 17760.0        2
# 143712.0       1
# 83920.0        1
# 150208.0       1
# 126912.0       1
# 97344.0        1
# 74080.0        1
# Name: count, dtype: int64
#
# - 전년 반입량 증감률(%) (Top 10)
# 전년 반입량 증감률(%)
#  0.0     3551
# -47.4       2
# -67.7       2
# -19.3       2
# -33.7       1
# -22.0       1
# -19.0       1
# -1.9        1
#  3.2        1
#  3.5        1
# Name: count, dtype: int64
#
# - 전년 금액 (Top 10)
# 전년 금액
# NaN           3519
# 20718000.0       1
# 18086000.0       1
# 27065000.0       1
# 21955500.0       1
# 22333500.0       1
# 15849000.0       1
# 23357000.0       1
# 22290000.0       1
# 36204000.0       1
# Name: count, dtype: int64
#
# - 전년 금액 증감률(%) (Top 10)
# 전년 금액 증감률(%)
# 0.0      3552
# 179.4       1
# 379.4       1
# 268.1       1
# 269.8       1
# 196.5       1
# 134.2       1
# 130.5       1
# 72.7        1
# 275.6       1
# Name: count, dtype: int64
#
# - 평년 반입량 (Top 10)
# 평년 반입량
# NaN         3553
# 138342.0       2
# 74316.0        2
# 77179.0        2
# 66228.0        2
# 74246.0        2
# 80910.0        2
# 85725.0        2
# 114583.0       2
# 124336.0       2
# Name: count, dtype: int64
#
# - 평년 반입량 증감률(%) (Top 10)
# 평년 반입량 증감률(%)
#  0.0     3576
#  11.4       2
# -55.2       2
# -19.1       1
# -21.6       1
#  72.0       1
#  25.3       1
#  57.1       1
#  23.6       1
#  15.2       1
# Name: count, dtype: int64
#
# - 평년 금액 (Top 10)
# 평년 금액
# NaN           3553
# 32131180.0       1
# 54111367.0       1
# 68877760.0       1
# 70952300.0       1
# 69572290.0       1
# 61906570.0       1
# 59796610.0       1
# 55205850.0       1
# 50712750.0       1
# Name: count, dtype: int64
#
# - 평년 금액 증감률(%) (Top 10)
# 평년 금액 증감률(%)
# 0.0      3576
# 79.5        1
# 111.1       1
# 113.6       1
# 54.2        1
# 20.5        1
# 46.4        1
# 46.3        1
# 15.8        1
# 108.8       1
# Name: count, dtype: int64
#
#
#
# ====================================================================================================
# [양파(onion)] 데이터 요약
# ====================================================================================================
#
# [info()]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3654 entries, 0 to 3653
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   거래일자           3654 non-null   datetime64[ns]
#  1   품목명            3654 non-null   object
#  2   반입량            2432 non-null   float64
#  3   금액             2434 non-null   float64
#  4   전년 반입량         2321 non-null   float64
#  5   전년 반입량 증감률(%)  3654 non-null   float64
#  6   전년 금액          2323 non-null   float64
#  7   전년 금액 증감률(%)   3654 non-null   float64
#  8   평년 반입량         2962 non-null   float64
#  9   평년 반입량 증감률(%)  3654 non-null   float64
#  10  평년 금액          2962 non-null   float64
#  11  평년 금액 증감률(%)   3654 non-null   float64
# dtypes: datetime64[ns](1), float64(10), object(1)
# memory usage: 342.7+ KB
#
#
# [describe(include='all')]
#                        거래일자   품목명           반입량            금액        전년 반입량  전년 반입량 증감률(%)         전년 금액  \
# count                  3654  3654  2.432000e+03  2.434000e+03  2.321000e+03    3654.000000  2.323000e+03
# unique                  NaN     1           NaN           NaN           NaN            NaN           NaN
# top                     NaN  저장양파           NaN           NaN           NaN            NaN           NaN
# freq                    NaN  3654           NaN           NaN           NaN            NaN           NaN
# mean    2020-06-29 12:00:00   NaN  3.222713e+05  3.120874e+08  3.228624e+05      35.662562  2.912548e+08
# min     2015-06-30 00:00:00   NaN -3.655500e+04 -4.481095e+07 -3.655500e+04    -412.100000 -4.481095e+07
# 25%     2017-12-29 06:00:00   NaN  1.730610e+05  1.505427e+08  1.895860e+05      -0.975000  1.546674e+08
# 50%     2020-06-29 12:00:00   NaN  3.224450e+05  2.776530e+08  3.256420e+05       0.000000  2.526604e+08
# 75%     2022-12-29 18:00:00   NaN  4.504578e+05  4.486628e+08  4.290180e+05       0.000000  3.919164e+08
# max     2025-06-30 00:00:00   NaN  1.035534e+06  1.037578e+09  1.035534e+06   47129.200000  9.729728e+08
# std                     NaN   NaN  1.763234e+05  2.018060e+08  1.655901e+05     829.848396  1.858685e+08
#
#         전년 금액 증감률(%)         평년 반입량  평년 반입량 증감률(%)         평년 금액  평년 금액 증감률(%)
# count    3654.000000    2962.000000    3654.000000  2.962000e+03   3654.000000
# unique           NaN            NaN            NaN           NaN           NaN
# top              NaN            NaN            NaN           NaN           NaN
# freq             NaN            NaN            NaN           NaN           NaN
# mean       28.421483  266001.175895      20.848851  2.198512e+08     34.927367
# min     -7476.900000   11198.000000    -137.500000  9.578700e+06   -162.100000
# 25%         0.000000  188303.500000       0.000000  1.527588e+08      0.000000
# 50%         0.000000  262364.000000       0.000000  2.041695e+08      0.000000
# 75%         4.300000  345821.750000      30.050000  2.817412e+08     47.700000
# max      9458.200000  547343.000000    1230.800000  5.393069e+08    915.300000
# std       312.143790  109971.352279      76.000224  1.081484e+08     92.500470
#
# [결측치 요약]
#                na_count  na_ratio_%
# 전년 반입량             1333   36.480569
# 전년 금액              1331   36.425835
# 반입량                1222   33.442802
# 금액                 1220   33.388068
# 평년 반입량              692   18.938150
# 평년 금액               692   18.938150
# 거래일자                  0    0.000000
# 품목명                   0    0.000000
# 전년 반입량 증감률(%)         0    0.000000
# 전년 금액 증감률(%)          0    0.000000
# 평년 반입량 증감률(%)         0    0.000000
# 평년 금액 증감률(%)          0    0.000000
#
# [value_counts(Top 10 by column)]
#
# - 거래일자 (Top 10)
# 거래일자
# 2025-06-30    1
# 2018-11-07    1
# 2018-11-05    1
# 2018-11-04    1
# 2018-11-03    1
# 2018-11-02    1
# 2018-11-01    1
# 2018-10-31    1
# 2018-10-30    1
# 2018-10-29    1
# Name: count, dtype: int64
#
# - 품목명 (Top 10)
# 품목명
# 저장양파    3654
# Name: count, dtype: int64
#
# - 반입량 (Top 10)
# 반입량
# NaN         1222
# 250000.0       5
# 100000.0       3
# 18000.0        2
# 17265.0        2
# 60000.0        2
# 474775.0       2
# 458357.0       2
# 125970.0       2
# 15750.0        2
# Name: count, dtype: int64
#
# - 금액 (Top 10)
# 금액
# NaN            1220
# 100000000.0       5
# 65000000.0        2
# 59995200.0        1
# 80846000.0        1
# 94186650.0        1
# 55642300.0        1
# 104867900.0       1
# 68945800.0        1
# 40643000.0        1
# Name: count, dtype: int64
#
# - 전년 반입량 (Top 10)
# 전년 반입량
# NaN         1333
# 250000.0       3
# 100000.0       3
# 17265.0        2
# 382856.0       2
# 346278.0       2
# 125970.0       2
# 474775.0       2
# 674452.0       2
# 453319.0       2
# Name: count, dtype: int64
#
# - 전년 반입량 증감률(%) (Top 10)
# 전년 반입량 증감률(%)
#  0.0     1849
#  15.0       6
# -50.0       5
# -19.6       5
# -38.9       5
#  1.5        5
# -34.1       5
#  4.4        5
# -29.3       5
# -42.2       5
# Name: count, dtype: int64
#
# - 전년 금액 (Top 10)
# 전년 금액
# NaN            1331
# 100000000.0       3
# 658774550.0       2
# 267323050.0       2
# 65000000.0        2
# 316262250.0       2
# 119701900.0       1
# 88209350.0        1
# 127482300.0       1
# 101501800.0       1
# Name: count, dtype: int64
#
# - 전년 금액 증감률(%) (Top 10)
# 전년 금액 증감률(%)
#  0.0     1843
# -18.5       5
# -24.2       5
# -23.1       5
# -10.5       5
# -62.1       4
# -16.5       4
# -37.1       4
#  38.6       4
# -38.8       4
# Name: count, dtype: int64
#
# - 평년 반입량 (Top 10)
# 평년 반입량
# NaN         692
# 209528.0      3
# 328391.0      3
# 301401.0      3
# 250276.0      2
# 446162.0      2
# 435937.0      2
# 203662.0      2
# 202493.0      2
# 204999.0      2
# Name: count, dtype: int64
#
# - 평년 반입량 증감률(%) (Top 10)
# 평년 반입량 증감률(%)
#  0.0     1292
#  24.5       7
# -13.8       7
#  17.2       7
#  20.5       6
#  6.8        6
#  8.9        6
#  21.6       6
#  4.4        6
# -8.6        6
# Name: count, dtype: int64
#
# - 평년 금액 (Top 10)
# 평년 금액
# NaN            692
# 153163387.0      3
# 186573488.0      3
# 160477993.0      3
# 156711527.0      3
# 150045145.0      3
# 154596605.0      3
# 159959323.0      3
# 166928920.0      3
# 170097230.0      3
# Name: count, dtype: int64
#
# - 평년 금액 증감률(%) (Top 10)
# 평년 금액 증감률(%)
#  0.0     1290
#  30.3       7
#  1.6        7
# -19.5       6
#  13.1       6
#  16.0       6
# -18.3       6
#  12.3       6
# -17.8       5
#  46.7       5
# Name: count, dtype: int64

# %%
# -*- coding: utf-8 -*-
import pandas as pd
from io import StringIO
from pathlib import Path

pd.set_option("display.max_columns", 100)
pd.set_option("display.width", 120)

def load_csv_safe(path: str) -> pd.DataFrame:
    encodings = ["utf-8-sig", "cp949", "utf-8"]
    last_err = None
    for enc in encodings:
        try:
            df = pd.read_csv(path, encoding=enc)
            break
        except Exception as e:
            last_err = e
            df = None
    if df is None:
        raise RuntimeError(f"CSV 로딩 실패: {path} (마지막 에러: {last_err})")
    df.columns = df.columns.astype(str).str.replace(r"\s+", " ", regex=True).str.strip()
    for c in [c for c in df.columns if "거래일자" in c]:
        df[c] = pd.to_datetime(df[c], errors="coerce")
    return df

# 1) 파일 불러오기 (코드 실행 폴더와 같은 위치)
garlic  = load_csv_safe("garlic.csv")
ginger  = load_csv_safe("ginger.csv")
cabbage = load_csv_safe("cabbage.csv")
onion   = load_csv_safe("onion.csv")

data_dict = {
    "마늘(garlic)": garlic,
    "생강(ginger)": ginger,
    "양배추(cabbage)": cabbage,
    "양파(onion)": onion,
}

# 2) 유틸
def na_summary(df: pd.DataFrame) -> pd.DataFrame:
    na_cnt = df.isna().sum()
    na_ratio = (na_cnt / len(df) * 100) if len(df) > 0 else 0
    return pd.DataFrame({"na_count": na_cnt, "na_ratio_%": na_ratio}).sort_values("na_count", ascending=False)

# 3) 출력 제어
MAX_VC_COLS = 20   # value_counts 돌릴 최대 컬럼 수 (많으면 상위 일부만)
TOPN = 10          # value_counts 상위 N

report_dir = Path("./reports_basic_stats")
report_dir.mkdir(exist_ok=True)

print("=== 대상 품목:", list(data_dict.keys()))
for name, df in data_dict.items():
    print("\n" + "="*100)
    print(f"[START] {name} 요약 생성 (rows={len(df)}, cols={df.shape[1]})")
    print("="*100)

    try:
        # info 캡처
        buf = StringIO(); df.info(buf=buf); info_str = buf.getvalue()

        # describe (가벼운 콘솔용 요약)
        try:
            desc = df.describe(include="all", datetime_is_numeric=True)
        except TypeError:
            desc = df.describe(include="all")

        # 결측치 요약
        nas = na_summary(df)

        # value_counts: 콘솔은 상위 몇 개 컬럼만, 파일에는 전체
        cols_for_console = list(df.columns)[:MAX_VC_COLS]

        # 콘솔 요약 출력 (가볍게)
        print("[info()]")
        print(info_str.splitlines()[0])  # 첫 줄만
        print("[columns]", list(df.columns))
        print("[describe] (head)")
        print(desc.head(8))  # 너무 길면 head만
        print("[결측치 요약] (상위 10)")
        print(nas.head(10))

        print(f"[value_counts] (콘솔은 앞 {len(cols_for_console)}개 컬럼만, 각 Top{TOPN})")
        for col in cols_for_console:
            try:
                vc = df[col].value_counts(dropna=False).head(TOPN)
                print(f"\n- {col} (Top {TOPN})")
                print(vc)
            except Exception as e:
                print(f"- {col}: value_counts 불가 ({e})")

        # 파일 리포트(자세한 내용)
        report_path = report_dir / f"{name}_basic_report.txt"
        with report_path.open("w", encoding="utf-8") as f:
            f.write(f"[{name}] 데이터 요약\n")
            f.write("="*80 + "\n\n[info()]\n")
            f.write(info_str + "\n\n[describe(include='all')]\n")
            f.write(desc.to_string() + "\n\n[결측치 요약]\n")
            f.write(nas.to_string() + "\n\n[value_counts(Top {TOPN} by column)]\n")
            for col in df.columns:
                try:
                    vc = df[col].value_counts(dropna=False).head(TOPN)
                    f.write(f"\n- {col} (Top {TOPN})\n{vc.to_string()}\n")
                except Exception as e:
                    f.write(f"- {col}: value_counts 불가 ({e})\n")
        print(f"[DONE] {name} 리포트 저장: {report_path.resolve()}")

    except Exception as e:
        print(f"[ERROR] {name} 처리 중 에러: {e}")

print("\n=== 전체 완료 ===")
# Out:
# === 대상 품목: ['마늘(garlic)', '생강(ginger)', '양배추(cabbage)', '양파(onion)']
#
# ====================================================================================================
# [START] 마늘(garlic) 요약 생성 (rows=10962, cols=12)
# ====================================================================================================
# [info()]
# <class 'pandas.core.frame.DataFrame'>
# [columns] ['거래일자', '품목명', '반입량', '금액', '전년 반입량', '전년 반입량 증감률(%)', '전년 금액', '전년 금액 증감률(%)', '평년 반입량', '평년 반입량 증감률(%)', '평년 금액', '평년 금액 증감률(%)']
# [describe] (head)
#                        거래일자     품목명            반입량            금액       전년 반입량  전년 반입량 증감률(%)         전년 금액  \
# count                 10962   10962    1193.000000  1.200000e+03   677.000000    10962.00000  6.930000e+02
# unique                  NaN       3            NaN           NaN          NaN            NaN           NaN
# top                     NaN  저장형 난지            NaN           NaN          NaN            NaN           NaN
# freq                    NaN    3654            NaN           NaN          NaN            NaN           NaN
# mean    2020-06-29 12:00:00     NaN    6379.848282  1.764893e+07  6363.813885      121.71829  1.910272e+07
# min     2015-06-30 00:00:00     NaN -452580.000000 -2.522400e+08     1.000000     -100.00000 -6.320000e+05
# 25%     2017-12-29 00:00:00     NaN      24.000000  9.287500e+04    36.000000        0.00000  1.425000e+05
# 50%     2020-06-29 12:00:00     NaN     480.000000  1.447000e+06   514.000000        0.00000  2.111400e+06
#
#         전년 금액 증감률(%)       평년 반입량  평년 반입량 증감률(%)         평년 금액  평년 금액 증감률(%)
# count   10962.000000  1106.000000   10962.000000  1.127000e+03  10962.000000
# unique           NaN          NaN            NaN           NaN           NaN
# top              NaN          NaN            NaN           NaN           NaN
# freq             NaN          NaN            NaN           NaN           NaN
# mean       40.750821  3886.869801     114.876409  1.238173e+07     33.344171
# min    -18600.000000     3.000000    -406.000000  1.909200e+04   -452.400000
# 25%         0.000000   217.000000       0.000000  5.439515e+05      0.000000
# 50%         0.000000  1186.000000       0.000000  4.737500e+06      0.000000
# [결측치 요약] (상위 10)
#                na_count  na_ratio_%
# 전년 반입량            10285   93.824120
# 전년 금액             10269   93.678161
# 평년 반입량             9856   89.910600
# 평년 금액              9835   89.719029
# 반입량                9769   89.116949
# 금액                 9762   89.053093
# 거래일자                  0    0.000000
# 품목명                   0    0.000000
# 전년 반입량 증감률(%)         0    0.000000
# 전년 금액 증감률(%)          0    0.000000
# [value_counts] (콘솔은 앞 12개 컬럼만, 각 Top10)
#
# - 거래일자 (Top 10)
# 거래일자
# 2025-06-30    3
# 2018-11-07    3
# 2018-11-05    3
# 2018-11-04    3
# 2018-11-03    3
# 2018-11-02    3
# 2018-11-01    3
# 2018-10-31    3
# 2018-10-30    3
# 2018-10-29    3
# Name: count, dtype: int64
#
# - 품목명 (Top 10)
# 품목명
# 저장형 난지    3654
# 저장형 대서    3654
# 저장형 한지    3654
# Name: count, dtype: int64
#
# - 반입량 (Top 10)
# 반입량
# NaN       9769
# 1000.0      50
# 3.0         47
# 1.0         35
# 2.0         31
# 5.0         25
# 4.0         25
# 500.0       23
# 2000.0      22
# 6.0         22
# Name: count, dtype: int64
#
# - 금액 (Top 10)
# 금액
# NaN           9762
# 17760.0         43
# 5920.0          28
# 11840.0         27
# 29600.0         24
# 23680.0         22
# 35520.0         17
# 5000000.0       12
# 10000000.0      10
# 6500000.0        9
# Name: count, dtype: int64
#
# - 전년 반입량 (Top 10)
# 전년 반입량
# NaN       10285
# 1000.0       24
# 1.0          24
# 3.0          22
# 2.0          17
# 5.0          13
# 4.0          12
# 500.0        12
# 2000.0       11
# 24.0          9
# Name: count, dtype: int64
#
# - 전년 반입량 증감률(%) (Top 10)
# 전년 반입량 증감률(%)
#  0.0      10642
#  100.0        8
#  200.0        4
# -50.0         4
# -98.8         3
# -99.6         3
# -99.9         3
# -100.0        3
# -99.7         3
# -99.5         3
# Name: count, dtype: int64
#
# - 전년 금액 (Top 10)
# 전년 금액
# NaN          10269
# 17760.0         21
# 5920.0          17
# 11840.0         13
# 29600.0         11
# 23680.0         10
# 35520.0          8
# 5980.0           7
# 5000000.0        4
# 11960.0          4
# Name: count, dtype: int64
#
# - 전년 금액 증감률(%) (Top 10)
# 전년 금액 증감률(%)
#  0.0      10634
# -99.9         5
# -70.0         3
# -99.5         3
# -99.2         3
#  100.0        3
# -88.9         2
# -97.8         2
# -97.5         2
#  197.0        2
# Name: count, dtype: int64
#
# - 평년 반입량 (Top 10)
# 평년 반입량
# NaN      9856
# 4.0        31
# 5.0        11
# 62.0        6
# 20.0        6
# 220.0       6
# 33.0        5
# 34.0        4
# 3.0         4
# 213.0       4
# Name: count, dtype: int64
#
# - 평년 반입량 증감률(%) (Top 10)
# 평년 반입량 증감률(%)
#  0.0      10463
# -99.9        15
# -99.7         9
# -100.0        9
# -99.3         8
# -99.5         7
# -99.8         6
# -99.6         5
# -97.0         4
# -98.5         4
# Name: count, dtype: int64
#
# - 평년 금액 (Top 10)
# 평년 금액
# NaN           9835
# 21904.0          4
# 26048.0          4
# 8366445.0        3
# 560000.0         3
# 617500.0         3
# 7000000.0        3
# 20891000.0       3
# 13248000.0       2
# 1627645.0        2
# Name: count, dtype: int64
#
# - 평년 금액 증감률(%) (Top 10)
# 평년 금액 증감률(%)
#  0.0      10454
# -99.7        14
# -99.9        12
# -99.8         9
# -100.0        8
# -99.5         8
# -99.4         6
# -99.6         5
# -98.0         5
# -98.5         5
# Name: count, dtype: int64
# [DONE] 마늘(garlic) 리포트 저장: /Users/sojinjung/Documents/GitHub/GDF_Final_G3/sojin/reports_basic_stats/마늘(garlic)_basic_report.txt
#
# ====================================================================================================
# [START] 생강(ginger) 요약 생성 (rows=7308, cols=12)
# ====================================================================================================
# [info()]
# <class 'pandas.core.frame.DataFrame'>
# [columns] ['거래일자', '품목명', '반입량', '금액', '전년 반입량', '전년 반입량 증감률(%)', '전년 금액', '전년 금액 증감률(%)', '평년 반입량', '평년 반입량 증감률(%)', '평년 금액', '평년 금액 증감률(%)']
# [describe] (head)
#                        거래일자   품목명          반입량             금액      전년 반입량  전년 반입량 증감률(%)          전년 금액  전년 금액 증감률(%)  \
# count                  7308  7308  1753.000000    1753.000000  949.000000    7308.000000     949.000000   7308.000000
# unique                  NaN     2          NaN            NaN         NaN            NaN            NaN           NaN
# top                     NaN    구강          NaN            NaN         NaN            NaN            NaN           NaN
# freq                    NaN  3654          NaN            NaN         NaN            NaN            NaN           NaN
# mean    2020-06-29 12:00:00   NaN   420.255562  873852.674843  494.160169      11.712822  746919.815595     38.321045
# min     2015-06-30 00:00:00   NaN     2.000000    1600.000000    2.000000     -99.400000    1600.000000    -99.600000
# 25%     2017-12-29 00:00:00   NaN    40.000000   55000.000000   50.000000       0.000000   45000.000000      0.000000
# 50%     2020-06-29 12:00:00   NaN   110.000000  191400.000000  150.000000       0.000000  166250.000000      0.000000
#
#            평년 반입량  평년 반입량 증감률(%)          평년 금액  평년 금액 증감률(%)
# count   943.00000    7308.000000     943.000000   7308.000000
# unique        NaN            NaN            NaN           NaN
# top           NaN            NaN            NaN           NaN
# freq          NaN            NaN            NaN           NaN
# mean    353.11983       6.951546  575666.264051     10.183347
# min      15.00000     -98.600000   17436.000000    -98.100000
# 25%      67.50000       0.000000   91551.500000      0.000000
# 50%     118.00000       0.000000  177142.000000      0.000000
# [결측치 요약] (상위 10)
#                na_count  na_ratio_%
# 평년 반입량             6365   87.096333
# 평년 금액              6365   87.096333
# 전년 반입량             6359   87.014231
# 전년 금액              6359   87.014231
# 반입량                5555   76.012589
# 금액                 5555   76.012589
# 거래일자                  0    0.000000
# 품목명                   0    0.000000
# 전년 반입량 증감률(%)         0    0.000000
# 전년 금액 증감률(%)          0    0.000000
# [value_counts] (콘솔은 앞 12개 컬럼만, 각 Top10)
#
# - 거래일자 (Top 10)
# 거래일자
# 2025-06-30    2
# 2018-11-07    2
# 2018-11-05    2
# 2018-11-04    2
# 2018-11-03    2
# 2018-11-02    2
# 2018-11-01    2
# 2018-10-31    2
# 2018-10-30    2
# 2018-10-29    2
# Name: count, dtype: int64
#
# - 품목명 (Top 10)
# 품목명
# 구강    3654
# 재강    3654
# Name: count, dtype: int64
#
# - 반입량 (Top 10)
# 반입량
# NaN      5555
# 20.0      163
# 40.0      113
# 10.0       80
# 60.0       68
# 30.0       54
# 80.0       37
# 70.0       31
# 50.0       31
# 100.0      31
# Name: count, dtype: int64
#
# - 금액 (Top 10)
# 금액
# NaN        5555
# 60000.0      22
# 20000.0      18
# 30000.0      17
# 40000.0      16
# 48000.0      14
# 10000.0      14
# 52000.0      13
# 56000.0      12
# 24000.0      12
# Name: count, dtype: int64
#
# - 전년 반입량 (Top 10)
# 전년 반입량
# NaN      6359
# 20.0       73
# 40.0       44
# 60.0       34
# 80.0       23
# 120.0      21
# 10.0       20
# 140.0      19
# 30.0       17
# 100.0      17
# Name: count, dtype: int64
#
# - 전년 반입량 증감률(%) (Top 10)
# 전년 반입량 증감률(%)
#  0.0      6700
# -50.0        7
# -83.3        7
# -66.7        6
#  50.0        6
#  100.0       5
#  133.3       5
# -42.9        4
# -75.0        4
#  400.0       4
# Name: count, dtype: int64
#
# - 전년 금액 (Top 10)
# 전년 금액
# NaN        6359
# 10000.0      13
# 60000.0      12
# 30000.0      10
# 6000.0        9
# 4000.0        9
# 40000.0       9
# 3000.0        9
# 15000.0       8
# 12000.0       8
# Name: count, dtype: int64
#
# - 전년 금액 증감률(%) (Top 10)
# 전년 금액 증감률(%)
#  0.0      6689
# -90.9        4
# -94.1        4
# -80.0        3
# -46.7        3
# -91.3        3
# -71.4        3
# -77.5        3
# -51.3        3
#  200.0       3
# Name: count, dtype: int64
#
# - 평년 반입량 (Top 10)
# 평년 반입량
# NaN     6365
# 84.0      16
# 67.0      14
# 55.0      14
# 50.0      13
# 63.0      12
# 70.0      11
# 52.0      10
# 73.0       9
# 42.0       9
# Name: count, dtype: int64
#
# - 평년 반입량 증감률(%) (Top 10)
# 평년 반입량 증감률(%)
#  0.0     6657
# -60.0       5
#  6.3        4
#  39.5       4
# -83.1       3
# -78.3       3
# -38.3       3
# -18.4       3
# -67.2       3
# -32.2       3
# Name: count, dtype: int64
#
# - 평년 금액 (Top 10)
# 평년 금액
# NaN          6365
# 486580.0        2
# 2904000.0       2
# 2429477.0       2
# 2050635.0       2
# 1657245.0       2
# 1506015.0       2
# 1244108.0       2
# 1064198.0       2
# 1048510.0       2
# Name: count, dtype: int64
#
# - 평년 금액 증감률(%) (Top 10)
# 평년 금액 증감률(%)
#  0.0     6653
# -68.4       3
# -48.0       2
#  27.3       2
# -62.1       2
#  88.5       2
# -87.6       2
# -86.0       2
# -87.9       2
# -96.7       2
# Name: count, dtype: int64
# [DONE] 생강(ginger) 리포트 저장: /Users/sojinjung/Documents/GitHub/GDF_Final_G3/sojin/reports_basic_stats/생강(ginger)_basic_report.txt
#
# ====================================================================================================
# [START] 양배추(cabbage) 요약 생성 (rows=3654, cols=12)
# ====================================================================================================
# [info()]
# <class 'pandas.core.frame.DataFrame'>
# [columns] ['거래일자', '품목명', '반입량', '금액', '전년 반입량', '전년 반입량 증감률(%)', '전년 금액', '전년 금액 증감률(%)', '평년 반입량', '평년 반입량 증감률(%)', '평년 금액', '평년 금액 증감률(%)']
# [describe] (head)
#                        거래일자    품목명          반입량            금액        전년 반입량  전년 반입량 증감률(%)         전년 금액  \
# count                  3654   3654    236.00000  2.360000e+02     135.00000    3654.000000  1.350000e+02
# unique                  NaN      1          NaN           NaN           NaN            NaN           NaN
# top                     NaN  저장양배추          NaN           NaN           NaN            NaN           NaN
# freq                    NaN   3654          NaN           NaN           NaN            NaN           NaN
# mean    2020-06-29 12:00:00    NaN  73801.59322  7.789762e+07  100178.37037       0.268172  1.066436e+08
# min     2015-06-30 00:00:00    NaN   2352.00000  8.982000e+05    6144.00000     -96.800000  2.255000e+06
# 25%     2017-12-29 06:00:00    NaN  16188.00000  8.433075e+06   55036.00000       0.000000  3.192210e+07
# 50%     2020-06-29 12:00:00    NaN  61932.00000  4.038680e+07   94496.00000       0.000000  6.878800e+07
#
#         전년 금액 증감률(%)        평년 반입량  평년 반입량 증감률(%)         평년 금액  평년 금액 증감률(%)
# count    3654.000000    101.000000     3654.00000  1.010000e+02   3654.000000
# unique           NaN           NaN            NaN           NaN           NaN
# top              NaN           NaN            NaN           NaN           NaN
# freq             NaN           NaN            NaN           NaN           NaN
# mean        2.213684  89078.217822       -0.07017  7.252241e+07      1.890038
# min       -99.300000  27618.000000      -95.00000  1.728292e+07    -92.900000
# 25%         0.000000  73526.000000        0.00000  5.411137e+07      0.000000
# 50%         0.000000  86390.000000        0.00000  6.957229e+07      0.000000
# [결측치 요약] (상위 10)
#                na_count  na_ratio_%
# 평년 반입량             3553   97.235906
# 평년 금액              3553   97.235906
# 전년 반입량             3519   96.305419
# 전년 금액              3519   96.305419
# 반입량                3418   93.541325
# 금액                 3418   93.541325
# 거래일자                  0    0.000000
# 품목명                   0    0.000000
# 전년 반입량 증감률(%)         0    0.000000
# 전년 금액 증감률(%)          0    0.000000
# [value_counts] (콘솔은 앞 12개 컬럼만, 각 Top10)
#
# - 거래일자 (Top 10)
# 거래일자
# 2025-06-30    1
# 2018-11-07    1
# 2018-11-05    1
# 2018-11-04    1
# 2018-11-03    1
# 2018-11-02    1
# 2018-11-01    1
# 2018-10-31    1
# 2018-10-30    1
# 2018-10-29    1
# Name: count, dtype: int64
#
# - 품목명 (Top 10)
# 품목명
# 저장양배추    3654
# Name: count, dtype: int64
#
# - 반입량 (Top 10)
# 반입량
# NaN        3418
# 8640.0        7
# 28800.0       4
# 5760.0        3
# 12320.0       2
# 6160.0        2
# 17760.0       2
# 98592.0       2
# 11520.0       2
# 11488.0       2
# Name: count, dtype: int64
#
# - 금액 (Top 10)
# 금액
# NaN           3418
# 1722000.0        2
# 9240000.0        2
# 3114000.0        2
# 22290000.0       1
# 17903000.0       1
# 25512000.0       1
# 33226000.0       1
# 18086000.0       1
# 27065000.0       1
# Name: count, dtype: int64
#
# - 전년 반입량 (Top 10)
# 전년 반입량
# NaN         3519
# 28800.0        2
# 98592.0        2
# 17760.0        2
# 143712.0       1
# 83920.0        1
# 150208.0       1
# 126912.0       1
# 97344.0        1
# 74080.0        1
# Name: count, dtype: int64
#
# - 전년 반입량 증감률(%) (Top 10)
# 전년 반입량 증감률(%)
#  0.0     3551
# -47.4       2
# -67.7       2
# -19.3       2
# -33.7       1
# -22.0       1
# -19.0       1
# -1.9        1
#  3.2        1
#  3.5        1
# Name: count, dtype: int64
#
# - 전년 금액 (Top 10)
# 전년 금액
# NaN           3519
# 20718000.0       1
# 18086000.0       1
# 27065000.0       1
# 21955500.0       1
# 22333500.0       1
# 15849000.0       1
# 23357000.0       1
# 22290000.0       1
# 36204000.0       1
# Name: count, dtype: int64
#
# - 전년 금액 증감률(%) (Top 10)
# 전년 금액 증감률(%)
# 0.0      3552
# 179.4       1
# 379.4       1
# 268.1       1
# 269.8       1
# 196.5       1
# 134.2       1
# 130.5       1
# 72.7        1
# 275.6       1
# Name: count, dtype: int64
#
# - 평년 반입량 (Top 10)
# 평년 반입량
# NaN         3553
# 138342.0       2
# 74316.0        2
# 77179.0        2
# 66228.0        2
# 74246.0        2
# 80910.0        2
# 85725.0        2
# 114583.0       2
# 124336.0       2
# Name: count, dtype: int64
#
# - 평년 반입량 증감률(%) (Top 10)
# 평년 반입량 증감률(%)
#  0.0     3576
#  11.4       2
# -55.2       2
# -19.1       1
# -21.6       1
#  72.0       1
#  25.3       1
#  57.1       1
#  23.6       1
#  15.2       1
# Name: count, dtype: int64
#
# - 평년 금액 (Top 10)
# 평년 금액
# NaN           3553
# 32131180.0       1
# 54111367.0       1
# 68877760.0       1
# 70952300.0       1
# 69572290.0       1
# 61906570.0       1
# 59796610.0       1
# 55205850.0       1
# 50712750.0       1
# Name: count, dtype: int64
#
# - 평년 금액 증감률(%) (Top 10)
# 평년 금액 증감률(%)
# 0.0      3576
# 79.5        1
# 111.1       1
# 113.6       1
# 54.2        1
# 20.5        1
# 46.4        1
# 46.3        1
# 15.8        1
# 108.8       1
# Name: count, dtype: int64
# [DONE] 양배추(cabbage) 리포트 저장: /Users/sojinjung/Documents/GitHub/GDF_Final_G3/sojin/reports_basic_stats/양배추(cabbage)_basic_report.txt
#
# ====================================================================================================
# [START] 양파(onion) 요약 생성 (rows=3654, cols=12)
# ====================================================================================================
# [info()]
# <class 'pandas.core.frame.DataFrame'>
# [columns] ['거래일자', '품목명', '반입량', '금액', '전년 반입량', '전년 반입량 증감률(%)', '전년 금액', '전년 금액 증감률(%)', '평년 반입량', '평년 반입량 증감률(%)', '평년 금액', '평년 금액 증감률(%)']
# [describe] (head)
#                        거래일자   품목명           반입량            금액         전년 반입량  전년 반입량 증감률(%)         전년 금액  \
# count                  3654  3654    2432.00000  2.434000e+03    2321.000000    3654.000000  2.323000e+03
# unique                  NaN     1           NaN           NaN            NaN            NaN           NaN
# top                     NaN  저장양파           NaN           NaN            NaN            NaN           NaN
# freq                    NaN  3654           NaN           NaN            NaN            NaN           NaN
# mean    2020-06-29 12:00:00   NaN  322271.31949  3.120874e+08  322862.396812      35.662562  2.912548e+08
# min     2015-06-30 00:00:00   NaN  -36555.00000 -4.481095e+07  -36555.000000    -412.100000 -4.481095e+07
# 25%     2017-12-29 06:00:00   NaN  173061.00000  1.505427e+08  189586.000000      -0.975000  1.546674e+08
# 50%     2020-06-29 12:00:00   NaN  322445.00000  2.776530e+08  325642.000000       0.000000  2.526604e+08
#
#         전년 금액 증감률(%)         평년 반입량  평년 반입량 증감률(%)         평년 금액  평년 금액 증감률(%)
# count    3654.000000    2962.000000    3654.000000  2.962000e+03   3654.000000
# unique           NaN            NaN            NaN           NaN           NaN
# top              NaN            NaN            NaN           NaN           NaN
# freq             NaN            NaN            NaN           NaN           NaN
# mean       28.421483  266001.175895      20.848851  2.198512e+08     34.927367
# min     -7476.900000   11198.000000    -137.500000  9.578700e+06   -162.100000
# 25%         0.000000  188303.500000       0.000000  1.527588e+08      0.000000
# 50%         0.000000  262364.000000       0.000000  2.041695e+08      0.000000
# [결측치 요약] (상위 10)
#                na_count  na_ratio_%
# 전년 반입량             1333   36.480569
# 전년 금액              1331   36.425835
# 반입량                1222   33.442802
# 금액                 1220   33.388068
# 평년 반입량              692   18.938150
# 평년 금액               692   18.938150
# 거래일자                  0    0.000000
# 품목명                   0    0.000000
# 전년 반입량 증감률(%)         0    0.000000
# 전년 금액 증감률(%)          0    0.000000
# [value_counts] (콘솔은 앞 12개 컬럼만, 각 Top10)
#
# - 거래일자 (Top 10)
# 거래일자
# 2025-06-30    1
# 2018-11-07    1
# 2018-11-05    1
# 2018-11-04    1
# 2018-11-03    1
# 2018-11-02    1
# 2018-11-01    1
# 2018-10-31    1
# 2018-10-30    1
# 2018-10-29    1
# Name: count, dtype: int64
#
# - 품목명 (Top 10)
# 품목명
# 저장양파    3654
# Name: count, dtype: int64
#
# - 반입량 (Top 10)
# 반입량
# NaN         1222
# 250000.0       5
# 100000.0       3
# 18000.0        2
# 17265.0        2
# 60000.0        2
# 474775.0       2
# 458357.0       2
# 125970.0       2
# 15750.0        2
# Name: count, dtype: int64
#
# - 금액 (Top 10)
# 금액
# NaN            1220
# 100000000.0       5
# 65000000.0        2
# 59995200.0        1
# 80846000.0        1
# 94186650.0        1
# 55642300.0        1
# 104867900.0       1
# 68945800.0        1
# 40643000.0        1
# Name: count, dtype: int64
#
# - 전년 반입량 (Top 10)
# 전년 반입량
# NaN         1333
# 250000.0       3
# 100000.0       3
# 17265.0        2
# 382856.0       2
# 346278.0       2
# 125970.0       2
# 474775.0       2
# 674452.0       2
# 453319.0       2
# Name: count, dtype: int64
#
# - 전년 반입량 증감률(%) (Top 10)
# 전년 반입량 증감률(%)
#  0.0     1849
#  15.0       6
# -50.0       5
# -19.6       5
# -38.9       5
#  1.5        5
# -34.1       5
#  4.4        5
# -29.3       5
# -42.2       5
# Name: count, dtype: int64
#
# - 전년 금액 (Top 10)
# 전년 금액
# NaN            1331
# 100000000.0       3
# 658774550.0       2
# 267323050.0       2
# 65000000.0        2
# 316262250.0       2
# 119701900.0       1
# 88209350.0        1
# 127482300.0       1
# 101501800.0       1
# Name: count, dtype: int64
#
# - 전년 금액 증감률(%) (Top 10)
# 전년 금액 증감률(%)
#  0.0     1843
# -18.5       5
# -24.2       5
# -23.1       5
# -10.5       5
# -62.1       4
# -16.5       4
# -37.1       4
#  38.6       4
# -38.8       4
# Name: count, dtype: int64
#
# - 평년 반입량 (Top 10)
# 평년 반입량
# NaN         692
# 209528.0      3
# 328391.0      3
# 301401.0      3
# 250276.0      2
# 446162.0      2
# 435937.0      2
# 203662.0      2
# 202493.0      2
# 204999.0      2
# Name: count, dtype: int64
#
# - 평년 반입량 증감률(%) (Top 10)
# 평년 반입량 증감률(%)
#  0.0     1292
#  24.5       7
# -13.8       7
#  17.2       7
#  20.5       6
#  6.8        6
#  8.9        6
#  21.6       6
#  4.4        6
# -8.6        6
# Name: count, dtype: int64
#
# - 평년 금액 (Top 10)
# 평년 금액
# NaN            692
# 153163387.0      3
# 186573488.0      3
# 160477993.0      3
# 156711527.0      3
# 150045145.0      3
# 154596605.0      3
# 159959323.0      3
# 166928920.0      3
# 170097230.0      3
# Name: count, dtype: int64
#
# - 평년 금액 증감률(%) (Top 10)
# 평년 금액 증감률(%)
#  0.0     1290
#  30.3       7
#  1.6        7
# -19.5       6
#  13.1       6
#  16.0       6
# -18.3       6
#  12.3       6
# -17.8       5
#  46.7       5
# Name: count, dtype: int64
# [DONE] 양파(onion) 리포트 저장: /Users/sojinjung/Documents/GitHub/GDF_Final_G3/sojin/reports_basic_stats/양파(onion)_basic_report.txt
#
# === 전체 완료 ===
